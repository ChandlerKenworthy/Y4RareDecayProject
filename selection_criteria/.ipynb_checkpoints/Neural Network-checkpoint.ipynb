# %% [markdown]
# # Complex Selection Criteria
# For our project we will have to have crteria or a model/function which can distinguish between signal and background event with some probability. Where evidently we want a model that is more likely to remove only background and no signal. There are likely some physical motivations behind this. We can find this out by for example looking at how quickly in terms of time or distance a certain decay should happen and narrowing down.
#
# ## Neural Networks & Machine Learning
# Firstly in this notebook we present a more computationally complex but less physically motivated technique using TensorFlow to create some primitive machine learning and neural networks.

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import uproot as up
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
# %matplotlib inline

# %%
fName="/disk/moose/lhcb/djdt/Lb2L1520mueTuples/MC/2016MD/100FilesCheck/job185-CombDVntuple-15314000-MC2016MD_100F-pKmue-MC.root"

# %%
with up.open(fName + ":DTT1520me/DecayTree") as f:
    features = ['L1_PX', 'L1_PY', 'L1_PZ', 'L2_PX', 'L2_PY', 'L2_PZ', 'L1_PT', 'L2_PT', 'p_PX', 'p_PY', 'p_PZ',
                'p_PT', 'Lb_TRUEID', 'Lb_ID']
    df = f.arrays(features, library="pd")

# %% [markdown]
# It is likely we need far more features to accurately train any neural network or ML algorithm. However, I have not added any yet because I do not have a clue what most of the variable names mean. Also note that the PID cannot be inlcuded as a feature since this is not realistic and the model will obviously learn immedeately to select via PID.

# %% [markdown]
# ## Getting the Data Ready & Feature Engineering

# %%
df['category'] = np.where(df['Lb_TRUEID'] == df['Lb_ID'], 1, 0)
# We have defined '1' as a signal event and '0' as a background event, the model needs this kind of binary 
# classification column to train on, remove the PID colunns as well!
df.drop(labels=['Lb_TRUEID', 'Lb_ID'], axis='columns', inplace=True)
# And drop duplicate data
df.drop_duplicates(keep='first', inplace=True)
df.head()
# Out:
#      L1_PX   L1_PY     L1_PZ    L2_PX   L2_PY     L2_PZ        L1_PT  \
# 0  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
# 1  2191.14  398.49  11076.01  -876.76  502.63   8333.52  2227.080775
# 2  2191.14  398.49  11076.01  -876.76  502.63   8333.52  2227.080775
# 3  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
# 4  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
#
#          L2_PT     p_PX    p_PY      p_PZ         p_PT  category
# 0  1031.105163  -876.76  502.63   8333.52  1010.616156         1
# 1  1010.616156 -1030.59  -32.59  10660.77  1031.105163         1
# 2  1010.616156    58.61 -311.02   7873.21   316.494190         0
# 3  1031.105163    58.61 -311.02   7873.21   316.494190         0
# 4  1031.105163  -810.04  229.96   5628.81   842.048932         0

# %%
# Now engineer some more features that could be useful - the obvious being the angle relative to beam axis and |p|
df['L1_P'] = np.sqrt(df['L1_PX']**2 + df['L1_PY']**2 + df['L1_PZ']**2)
df['L2_P'] = np.sqrt(df['L2_PX']**2 + df['L2_PY']**2 + df['L2_PZ']**2)
df['p_P'] = np.sqrt(df['p_PX']**2 + df['p_PY']**2 + df['p_PZ']**2)

df['L1_Angle'] = np.arcsin(df['L1_PT']/df['L1_P'])
df['L2_Angle'] = np.arcsin(df['L2_PT']/df['L2_P'])
df['p_Angle'] = np.arcsin(df['p_PT']/df['p_P'])

df.head()
# Out:
#      L1_PX   L1_PY     L1_PZ    L2_PX   L2_PY     L2_PZ        L1_PT  \
# 0  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
# 1  2191.14  398.49  11076.01  -876.76  502.63   8333.52  2227.080775
# 2  2191.14  398.49  11076.01  -876.76  502.63   8333.52  2227.080775
# 3  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
# 4  2191.14  398.49  11076.01 -1030.59  -32.59  10660.77  2227.080775
#
#          L2_PT     p_PX    p_PY      p_PZ         p_PT  category  \
# 0  1031.105163  -876.76  502.63   8333.52  1010.616156         1
# 1  1010.616156 -1030.59  -32.59  10660.77  1031.105163         1
# 2  1010.616156    58.61 -311.02   7873.21   316.494190         0
# 3  1031.105163    58.61 -311.02   7873.21   316.494190         0
# 4  1031.105163  -810.04  229.96   5628.81   842.048932         0
#
#            L1_P          L2_P           p_P  L1_Angle  L2_Angle   p_Angle
# 0  11297.693849  10710.517954   8394.575666  0.198427  0.096420  0.120682
# 1  11297.693849   8394.575666  10710.517954  0.198427  0.120682  0.096420
# 2  11297.693849   8394.575666   7879.568787  0.198427  0.120682  0.040177
# 3  11297.693849  10710.517954   7879.568787  0.198427  0.096420  0.040177
# 4  11297.693849  10710.517954   5691.445196  0.198427  0.096420  0.148495

# %% [markdown]
# ## Creating a Model and Training
# The next step is now to define the model and the problem. This is a binary classification problem. We want the model to classify each event, given some set of features whether the event is a signal or background event. We begin by using a - albeit simple - dense connected neural network.

# %%
df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)

df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)
df_train.dropna(axis=1, inplace=True)
df_valid.dropna(axis=1, inplace=True)

X_train = df_train.drop('category', axis=1)
X_valid = df_valid.drop('category', axis=1)
y_train = df_train['category']
y_valid = df_valid['category']

X_train.head()
# Out:
#           L1_PX     L1_PY     L1_PZ     L2_PX     L2_PY     L2_PZ     L1_PT  \
# 15758  0.379824  0.461493  0.061404  0.449725  0.437740  0.026516  0.018769
# 28284  0.330364  0.397278  0.254631  0.430449  0.489715  0.020213  0.140484
# 10735  0.388833  0.499570  0.014910  0.472100  0.486365  0.028095  0.016581
# 282    0.390901  0.465449  0.001347  0.449684  0.425807  0.051489  0.007915
# 27044  0.388672  0.469314  0.019749  0.446115  0.564473  0.162680  0.002642
#
#           L2_PT      p_PX      p_PY      p_PZ      p_PT      L1_P      L2_P  \
# 15758  0.057565  0.492923  0.517705  0.015903  0.017181  0.061095  0.026602
# 28284  0.026469  0.462261  0.486431  0.080741  0.063186  0.254405  0.020163
# 10735  0.016404  0.605368  0.492507  0.095003  0.189997  0.014637  0.027990
# 282    0.071761  0.504206  0.534579  0.098393  0.037145  0.001103  0.051515
# 27044  0.069468  0.476982  0.494337  0.059029  0.045218  0.019436  0.162546
#
#             p_P  L1_Angle  L2_Angle   p_Angle
# 15758  0.015730  0.027681  0.304935  0.208826
# 28284  0.080607  0.043108  0.209211  0.126020
# 10735  0.095618  0.154350  0.101925  0.340842
# 282    0.098162  0.378602  0.186620  0.051010
# 27044  0.058869  0.045321  0.037598  0.127582

# %%
# A simple model made of 3 layers each with 8 nodes apart from the last layer. The sigmoid activation function
# has to be used when doing a binary classification problem
model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[18]),
    layers.Dense(6, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=['binary_accuracy']
)

early_stopping = keras.callbacks.EarlyStopping(
    patience=20,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=100,
    callbacks=[early_stopping]
)

history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 11ms/step - loss: 0.6908 - binary_accuracy: 0.5317 - val_loss: 0.6832 - val_binary_accuracy: 0.5798
# Epoch 2/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6822 - binary_accuracy: 0.5723 - val_loss: 0.6789 - val_binary_accuracy: 0.5796
# Epoch 3/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6803 - binary_accuracy: 0.5723 - val_loss: 0.6774 - val_binary_accuracy: 0.5794
# Epoch 4/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6778 - binary_accuracy: 0.5724 - val_loss: 0.6736 - val_binary_accuracy: 0.5793
# Epoch 5/100
# 46/46 [==============================] - 0s 8ms/step - loss: 0.6718 - binary_accuracy: 0.5724 - val_loss: 0.6667 - val_binary_accuracy: 0.5796
# Epoch 6/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6655 - binary_accuracy: 0.5728 - val_loss: 0.6601 - val_binary_accuracy: 0.5811
# Epoch 7/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6584 - binary_accuracy: 0.5812 - val_loss: 0.6528 - val_binary_accuracy: 0.6065
# Epoch 8/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6504 - binary_accuracy: 0.6112 - val_loss: 0.6437 - val_binary_accuracy: 0.6097
# Epoch 9/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6414 - binary_accuracy: 0.6378 - val_loss: 0.6347 - val_binary_accuracy: 0.6392
# Epoch 10/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.6323 - binary_accuracy: 0.6722 - val_loss: 0.6258 - val_binary_accuracy: 0.7074
# Epoch 11/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6230 - binary_accuracy: 0.7075 - val_loss: 0.6166 - val_binary_accuracy: 0.7125
# Epoch 12/100
# 46/46 [==============================] - 0s 8ms/step - loss: 0.6142 - binary_accuracy: 0.7152 - val_loss: 0.6089 - val_binary_accuracy: 0.7176
# Epoch 13/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6068 - binary_accuracy: 0.7199 - val_loss: 0.6019 - val_binary_accuracy: 0.7218
# Epoch 14/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6003 - binary_accuracy: 0.7211 - val_loss: 0.5964 - val_binary_accuracy: 0.7202
# Epoch 15/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5943 - binary_accuracy: 0.7209 - val_loss: 0.5915 - val_binary_accuracy: 0.7245
# Epoch 16/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5895 - binary_accuracy: 0.7217 - val_loss: 0.5868 - val_binary_accuracy: 0.7240
# Epoch 17/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5851 - binary_accuracy: 0.7225 - val_loss: 0.5834 - val_binary_accuracy: 0.7201
# Epoch 18/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5813 - binary_accuracy: 0.7208 - val_loss: 0.5799 - val_binary_accuracy: 0.7212
# Epoch 19/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5780 - binary_accuracy: 0.7243 - val_loss: 0.5771 - val_binary_accuracy: 0.7277
# Epoch 20/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5753 - binary_accuracy: 0.7243 - val_loss: 0.5749 - val_binary_accuracy: 0.7212
# Epoch 21/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5728 - binary_accuracy: 0.7231 - val_loss: 0.5721 - val_binary_accuracy: 0.7251
# Epoch 22/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5701 - binary_accuracy: 0.7250 - val_loss: 0.5704 - val_binary_accuracy: 0.7239
# Epoch 23/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5682 - binary_accuracy: 0.7240 - val_loss: 0.5683 - val_binary_accuracy: 0.7252
# Epoch 24/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5661 - binary_accuracy: 0.7256 - val_loss: 0.5683 - val_binary_accuracy: 0.7193
# Epoch 25/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5653 - binary_accuracy: 0.7247 - val_loss: 0.5651 - val_binary_accuracy: 0.7260
# Epoch 26/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5631 - binary_accuracy: 0.7275 - val_loss: 0.5641 - val_binary_accuracy: 0.7249
# Epoch 27/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5617 - binary_accuracy: 0.7269 - val_loss: 0.5626 - val_binary_accuracy: 0.7281
# Epoch 28/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5607 - binary_accuracy: 0.7272 - val_loss: 0.5615 - val_binary_accuracy: 0.7283
# Epoch 29/100
# 46/46 [==============================] - 0s 8ms/step - loss: 0.5593 - binary_accuracy: 0.7275 - val_loss: 0.5606 - val_binary_accuracy: 0.7267
# Epoch 30/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5583 - binary_accuracy: 0.7286 - val_loss: 0.5599 - val_binary_accuracy: 0.7299
# Epoch 31/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5577 - binary_accuracy: 0.7298 - val_loss: 0.5595 - val_binary_accuracy: 0.7267
# Epoch 32/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5567 - binary_accuracy: 0.7288 - val_loss: 0.5584 - val_binary_accuracy: 0.7274
# Epoch 33/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5560 - binary_accuracy: 0.7294 - val_loss: 0.5584 - val_binary_accuracy: 0.7268
# Epoch 34/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5556 - binary_accuracy: 0.7296 - val_loss: 0.5586 - val_binary_accuracy: 0.7255
# Epoch 35/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5555 - binary_accuracy: 0.7285 - val_loss: 0.5571 - val_binary_accuracy: 0.7298
# Epoch 36/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5547 - binary_accuracy: 0.7305 - val_loss: 0.5572 - val_binary_accuracy: 0.7264
# Epoch 37/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5543 - binary_accuracy: 0.7303 - val_loss: 0.5566 - val_binary_accuracy: 0.7306
# Epoch 38/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5540 - binary_accuracy: 0.7303 - val_loss: 0.5566 - val_binary_accuracy: 0.7270
# Epoch 39/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5537 - binary_accuracy: 0.7308 - val_loss: 0.5569 - val_binary_accuracy: 0.7269
# Epoch 40/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5534 - binary_accuracy: 0.7302 - val_loss: 0.5559 - val_binary_accuracy: 0.7285
# Epoch 41/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5535 - binary_accuracy: 0.7300 - val_loss: 0.5555 - val_binary_accuracy: 0.7312
# Epoch 42/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5528 - binary_accuracy: 0.7307 - val_loss: 0.5554 - val_binary_accuracy: 0.7295
# Epoch 43/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5527 - binary_accuracy: 0.7308 - val_loss: 0.5554 - val_binary_accuracy: 0.7328
# Epoch 44/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5526 - binary_accuracy: 0.7299 - val_loss: 0.5550 - val_binary_accuracy: 0.7295
# Epoch 45/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5523 - binary_accuracy: 0.7316 - val_loss: 0.5553 - val_binary_accuracy: 0.7275
# Epoch 46/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5523 - binary_accuracy: 0.7304 - val_loss: 0.5549 - val_binary_accuracy: 0.7331
# Epoch 47/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5520 - binary_accuracy: 0.7322 - val_loss: 0.5543 - val_binary_accuracy: 0.7323
# Epoch 48/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5516 - binary_accuracy: 0.7316 - val_loss: 0.5541 - val_binary_accuracy: 0.7328
# Epoch 49/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5513 - binary_accuracy: 0.7328 - val_loss: 0.5539 - val_binary_accuracy: 0.7320
# Epoch 50/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5512 - binary_accuracy: 0.7308 - val_loss: 0.5537 - val_binary_accuracy: 0.7334
# Epoch 51/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5513 - binary_accuracy: 0.7316 - val_loss: 0.5535 - val_binary_accuracy: 0.7314
# Epoch 52/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5508 - binary_accuracy: 0.7314 - val_loss: 0.5533 - val_binary_accuracy: 0.7331
# Epoch 53/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5505 - binary_accuracy: 0.7327 - val_loss: 0.5532 - val_binary_accuracy: 0.7315
# Epoch 54/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5503 - binary_accuracy: 0.7322 - val_loss: 0.5529 - val_binary_accuracy: 0.7321
# Epoch 55/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5501 - binary_accuracy: 0.7320 - val_loss: 0.5530 - val_binary_accuracy: 0.7302
# Epoch 56/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5499 - binary_accuracy: 0.7325 - val_loss: 0.5525 - val_binary_accuracy: 0.7322
# Epoch 57/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5500 - binary_accuracy: 0.7315 - val_loss: 0.5539 - val_binary_accuracy: 0.7287
# Epoch 58/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5499 - binary_accuracy: 0.7311 - val_loss: 0.5521 - val_binary_accuracy: 0.7332
# Epoch 59/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5496 - binary_accuracy: 0.7311 - val_loss: 0.5519 - val_binary_accuracy: 0.7326
# Epoch 60/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5493 - binary_accuracy: 0.7319 - val_loss: 0.5517 - val_binary_accuracy: 0.7338
# Epoch 61/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5491 - binary_accuracy: 0.7324 - val_loss: 0.5515 - val_binary_accuracy: 0.7338
# Epoch 62/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5490 - binary_accuracy: 0.7319 - val_loss: 0.5513 - val_binary_accuracy: 0.7331
# Epoch 63/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5486 - binary_accuracy: 0.7327 - val_loss: 0.5512 - val_binary_accuracy: 0.7334
# Epoch 64/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5484 - binary_accuracy: 0.7322 - val_loss: 0.5516 - val_binary_accuracy: 0.7335
# Epoch 65/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5488 - binary_accuracy: 0.7328 - val_loss: 0.5508 - val_binary_accuracy: 0.7339
# Epoch 66/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5484 - binary_accuracy: 0.7318 - val_loss: 0.5510 - val_binary_accuracy: 0.7338
# Epoch 67/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5480 - binary_accuracy: 0.7325 - val_loss: 0.5508 - val_binary_accuracy: 0.7327
# Epoch 68/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5480 - binary_accuracy: 0.7331 - val_loss: 0.5506 - val_binary_accuracy: 0.7334
# Epoch 69/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5480 - binary_accuracy: 0.7324 - val_loss: 0.5510 - val_binary_accuracy: 0.7331
# Epoch 70/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5476 - binary_accuracy: 0.7325 - val_loss: 0.5500 - val_binary_accuracy: 0.7343
# Epoch 71/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5475 - binary_accuracy: 0.7319 - val_loss: 0.5498 - val_binary_accuracy: 0.7343
# Epoch 72/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5474 - binary_accuracy: 0.7333 - val_loss: 0.5511 - val_binary_accuracy: 0.7299
# Epoch 73/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5472 - binary_accuracy: 0.7340 - val_loss: 0.5495 - val_binary_accuracy: 0.7347
# Epoch 74/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5471 - binary_accuracy: 0.7322 - val_loss: 0.5494 - val_binary_accuracy: 0.7343
# Epoch 75/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5471 - binary_accuracy: 0.7333 - val_loss: 0.5494 - val_binary_accuracy: 0.7341
# Epoch 76/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5477 - binary_accuracy: 0.7320 - val_loss: 0.5492 - val_binary_accuracy: 0.7344
# Epoch 77/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5465 - binary_accuracy: 0.7334 - val_loss: 0.5490 - val_binary_accuracy: 0.7346
# Epoch 78/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5466 - binary_accuracy: 0.7332 - val_loss: 0.5492 - val_binary_accuracy: 0.7336
# Epoch 79/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5468 - binary_accuracy: 0.7326 - val_loss: 0.5489 - val_binary_accuracy: 0.7342
# Epoch 80/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5475 - binary_accuracy: 0.7326 - val_loss: 0.5488 - val_binary_accuracy: 0.7340
# Epoch 81/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5461 - binary_accuracy: 0.7326 - val_loss: 0.5486 - val_binary_accuracy: 0.7342
# Epoch 82/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5460 - binary_accuracy: 0.7333 - val_loss: 0.5485 - val_binary_accuracy: 0.7356
# Epoch 83/100
# 46/46 [==============================] - 0s 11ms/step - loss: 0.5460 - binary_accuracy: 0.7329 - val_loss: 0.5498 - val_binary_accuracy: 0.7295
# Epoch 84/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5462 - binary_accuracy: 0.7333 - val_loss: 0.5491 - val_binary_accuracy: 0.7328
# Epoch 85/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5459 - binary_accuracy: 0.7326 - val_loss: 0.5482 - val_binary_accuracy: 0.7342
# Epoch 86/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5454 - binary_accuracy: 0.7332 - val_loss: 0.5483 - val_binary_accuracy: 0.7340
# Epoch 87/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5453 - binary_accuracy: 0.7335 - val_loss: 0.5482 - val_binary_accuracy: 0.7338
# Epoch 88/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5458 - binary_accuracy: 0.7323 - val_loss: 0.5478 - val_binary_accuracy: 0.7359
# Epoch 89/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5451 - binary_accuracy: 0.7337 - val_loss: 0.5477 - val_binary_accuracy: 0.7352
# Epoch 90/100
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5450 - binary_accuracy: 0.7331 - val_loss: 0.5485 - val_binary_accuracy: 0.7335
# Epoch 91/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5450 - binary_accuracy: 0.7330 - val_loss: 0.5477 - val_binary_accuracy: 0.7341
# Epoch 92/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5448 - binary_accuracy: 0.7336 - val_loss: 0.5483 - val_binary_accuracy: 0.7332
# Epoch 93/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5447 - binary_accuracy: 0.7334 - val_loss: 0.5480 - val_binary_accuracy: 0.7340
# Epoch 94/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5448 - binary_accuracy: 0.7341 - val_loss: 0.5473 - val_binary_accuracy: 0.7352
# Epoch 95/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5448 - binary_accuracy: 0.7331 - val_loss: 0.5474 - val_binary_accuracy: 0.7344
# Epoch 96/100
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5447 - binary_accuracy: 0.7336 - val_loss: 0.5471 - val_binary_accuracy: 0.7360
# Epoch 97/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5445 - binary_accuracy: 0.7335 - val_loss: 0.5474 - val_binary_accuracy: 0.7340
# Epoch 98/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5443 - binary_accuracy: 0.7337 - val_loss: 0.5474 - val_binary_accuracy: 0.7334
# Epoch 99/100
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5444 - binary_accuracy: 0.7336 - val_loss: 0.5479 - val_binary_accuracy: 0.7336
# Epoch 100/100
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5442 - binary_accuracy: 0.7334 - val_loss: 0.5470 - val_binary_accuracy: 0.7350
# Best Validation Loss: 0.5470
# Best Validation Accuracy: 0.7360
