# %% [markdown]
# # Rough Data Cuts
# other shit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import uproot as up
import seaborn as sns

FNAME = "/disk/moose/lhcb/djdt/Lb2L1520mueTuples/realData/2016MD/halfSampleOct2021/blindedTriggeredL1520Selec-collision-firstHalf2016MD-pKmue_Full.root"
SUFFIX = ":DTT1520me/DecayTree"

# %%
def get_particles_data(particles, features, fName, suffix):
    """
    Get the features specified in features from the ROOT tuples. Can be specified
    for multiple particles. 

    Parameters:
        particles (list): A list of particles using the ROOT naming convention
        to be interrorgated. For example ['L1', 'K']

    Returns: 
        data (dict): A dictionary of pd.DataFrame for each particle with columns
        labelled according to FEATURES. Keys are particle tuple names.
    """

    data = {}
    for particle in particles:
        fts = [particle + "_" + feature for feature in features]
        with up.open(fName + suffix) as f:
            df = f.arrays(fts, library="pd")
            df.drop_duplicates(keep='first', inplace=True)
            df.columns = features
            data[particle] = df
    return data

# %%
with up.open(FNAME + SUFFIX) as f:
    print(f.keys())
# Out:
# ['Lb_MINIP', 'Lb_MINIPCHI2', 'Lb_MINIPNEXTBEST', 'Lb_MINIPCHI2NEXTBEST', 'Lb_ENDVERTEX_X', 'Lb_ENDVERTEX_Y', 'Lb_ENDVERTEX_Z', 'Lb_ENDVERTEX_XERR', 'Lb_ENDVERTEX_YERR', 'Lb_ENDVERTEX_ZERR', 'Lb_ENDVERTEX_CHI2', 'Lb_ENDVERTEX_NDOF', 'Lb_ENDVERTEX_COV_', 'Lb_OWNPV_X', 'Lb_OWNPV_Y', 'Lb_OWNPV_Z', 'Lb_OWNPV_XERR', 'Lb_OWNPV_YERR', 'Lb_OWNPV_ZERR', 'Lb_OWNPV_CHI2', 'Lb_OWNPV_NDOF', 'Lb_OWNPV_COV_', 'Lb_IP_OWNPV', 'Lb_IPCHI2_OWNPV', 'Lb_FD_OWNPV', 'Lb_FDCHI2_OWNPV', 'Lb_DIRA_OWNPV', 'Lb_TOPPV_X', 'Lb_TOPPV_Y', 'Lb_TOPPV_Z', 'Lb_TOPPV_XERR', 'Lb_TOPPV_YERR', 'Lb_TOPPV_ZERR', 'Lb_TOPPV_CHI2', 'Lb_TOPPV_NDOF', 'Lb_TOPPV_COV_', 'Lb_IP_TOPPV', 'Lb_IPCHI2_TOPPV', 'Lb_FD_TOPPV', 'Lb_FDCHI2_TOPPV', 'Lb_DIRA_TOPPV', 'Lb_HOP', 'Lb_HOP_MASS', 'Lb_HOP_ELECTRON_MASS', 'Lb_P', 'Lb_PT', 'Lb_PE', 'Lb_PX', 'Lb_PY', 'Lb_PZ', 'Lb_REFPX', 'Lb_REFPY', 'Lb_REFPZ', 'Lb_MM', 'Lb_MMERR', 'Lb_M', 'Lb_ID', 'Lb_TAU', 'Lb_TAUERR', 'Lb_TAUCHI2', 'Lb_DTF_PV_JPs_M012', 'Lb_DTF_PV_JPs_M013', 'Lb_JPs_1ST_TrkISOBDT', 'Lb_JPs_2ND_TrkISOBDT', 'Lb_JPs_3RD_TrkISOBDT', 'Lb_JPs_cc_IT_0.5ConeISO', 'Lb_JPs_cc_VPT_0.5ConeISO', 'Lb_JPs_cc_asy_PT_0.5ConeISO', 'Lb_JPs_cc_asy_P_0.5ConeISO', 'Lb_JPs_cc_deltaEta_0.5ConeISO', 'Lb_JPs_cc_deltaPhi_0.5ConeISO', 'Lb_JPs_cc_maxPt_PE_0.5ConeISO', 'Lb_JPs_cc_maxPt_PT_0.5ConeISO', 'Lb_JPs_cc_maxPt_PZ_0.5ConeISO', 'Lb_JPs_cc_maxPt_Q_0.5ConeISO', 'Lb_JPs_cc_mult_0.5ConeISO', 'Lb_JPs_cc_sPT_0.5ConeISO', 'Lb_JPs_cmult_0.5TrkISO', 'Lb_JPs_cp_0.5TrkISO', 'Lb_JPs_cpt_0.5TrkISO', 'Lb_JPs_deltaEta_0.5TrkISO', 'Lb_JPs_deltaPhi_0.5TrkISO', 'Lb_JPs_nc_IT_0.5ConeISO', 'Lb_JPs_nc_VPT_0.5ConeISO', 'Lb_JPs_nc_asy_PT_0.5ConeISO', 'Lb_JPs_nc_asy_P_0.5ConeISO', 'Lb_JPs_nc_deltaEta_0.5ConeISO', 'Lb_JPs_nc_deltaPhi_0.5ConeISO', 'Lb_JPs_nc_maxPt_PT_0.5ConeISO', 'Lb_JPs_nc_maxPt_PZ_0.5ConeISO', 'Lb_JPs_nc_mult_0.5ConeISO', 'Lb_JPs_nc_sPT_0.5ConeISO', 'Lb_JPs_pasy_0.5TrkISO', 'Lb_JPs_ptasy_0.5TrkISO', 'Lb_K_1ST_TrkISOBDT', 'Lb_K_2ND_TrkISOBDT', 'Lb_K_3RD_TrkISOBDT', 'Lb_K_cc_IT_0.5ConeISO', 'Lb_K_cc_VPT_0.5ConeISO', 'Lb_K_cc_asy_PT_0.5ConeISO', 'Lb_K_cc_asy_P_0.5ConeISO', 'Lb_K_cc_deltaEta_0.5ConeISO', 'Lb_K_cc_deltaPhi_0.5ConeISO', 'Lb_K_cc_maxPt_PE_0.5ConeISO', 'Lb_K_cc_maxPt_PT_0.5ConeISO', 'Lb_K_cc_maxPt_PZ_0.5ConeISO', 'Lb_K_cc_maxPt_Q_0.5ConeISO', 'Lb_K_cc_mult_0.5ConeISO', 'Lb_K_cc_sPT_0.5ConeISO', 'Lb_K_cmult_0.5TrkISO', 'Lb_K_cp_0.5TrkISO', 'Lb_K_cpt_0.5TrkISO', 'Lb_K_deltaEta_0.5TrkISO', 'Lb_K_deltaPhi_0.5TrkISO', 'Lb_K_nc_IT_0.5ConeISO', 'Lb_K_nc_VPT_0.5ConeISO', 'Lb_K_nc_asy_PT_0.5ConeISO', 'Lb_K_nc_asy_P_0.5ConeISO', 'Lb_K_nc_deltaEta_0.5ConeISO', 'Lb_K_nc_deltaPhi_0.5ConeISO', 'Lb_K_nc_maxPt_PT_0.5ConeISO', 'Lb_K_nc_maxPt_PZ_0.5ConeISO', 'Lb_K_nc_mult_0.5ConeISO', 'Lb_K_nc_sPT_0.5ConeISO', 'Lb_K_pasy_0.5TrkISO', 'Lb_K_ptasy_0.5TrkISO', 'Lb_L1_1ST_TrkISOBDT', 'Lb_L1_2ND_TrkISOBDT', 'Lb_L1_3RD_TrkISOBDT', 'Lb_L1_cc_IT_0.5ConeISO', 'Lb_L1_cc_VPT_0.5ConeISO', 'Lb_L1_cc_asy_PT_0.5ConeISO', 'Lb_L1_cc_asy_P_0.5ConeISO', 'Lb_L1_cc_deltaEta_0.5ConeISO', 'Lb_L1_cc_deltaPhi_0.5ConeISO', 'Lb_L1_cc_maxPt_PE_0.5ConeISO', 'Lb_L1_cc_maxPt_PT_0.5ConeISO', 'Lb_L1_cc_maxPt_PZ_0.5ConeISO', 'Lb_L1_cc_maxPt_Q_0.5ConeISO', 'Lb_L1_cc_mult_0.5ConeISO', 'Lb_L1_cc_sPT_0.5ConeISO', 'Lb_L1_cmult_0.5TrkISO', 'Lb_L1_cp_0.5TrkISO', 'Lb_L1_cpt_0.5TrkISO', 'Lb_L1_deltaEta_0.5TrkISO', 'Lb_L1_deltaPhi_0.5TrkISO', 'Lb_L1_nc_IT_0.5ConeISO', 'Lb_L1_nc_VPT_0.5ConeISO', 'Lb_L1_nc_asy_PT_0.5ConeISO', 'Lb_L1_nc_asy_P_0.5ConeISO', 'Lb_L1_nc_deltaEta_0.5ConeISO', 'Lb_L1_nc_deltaPhi_0.5ConeISO', 'Lb_L1_nc_maxPt_PT_0.5ConeISO', 'Lb_L1_nc_maxPt_PZ_0.5ConeISO', 'Lb_L1_nc_mult_0.5ConeISO', 'Lb_L1_nc_sPT_0.5ConeISO', 'Lb_L1_pasy_0.5TrkISO', 'Lb_L1_ptasy_0.5TrkISO', 'Lb_L2_1ST_TrkISOBDT', 'Lb_L2_2ND_TrkISOBDT', 'Lb_L2_3RD_TrkISOBDT', 'Lb_L2_cc_IT_0.5ConeISO', 'Lb_L2_cc_VPT_0.5ConeISO', 'Lb_L2_cc_asy_PT_0.5ConeISO', 'Lb_L2_cc_asy_P_0.5ConeISO', 'Lb_L2_cc_deltaEta_0.5ConeISO', 'Lb_L2_cc_deltaPhi_0.5ConeISO', 'Lb_L2_cc_maxPt_PE_0.5ConeISO', 'Lb_L2_cc_maxPt_PT_0.5ConeISO', 'Lb_L2_cc_maxPt_PZ_0.5ConeISO',  ...

# %%
with up.open(FNAME + SUFFIX) as f:
    df = f.arrays(['totCandidates','nCandidate'], library="pd")
    df['tot'] = df['totCandidates'] > df['nCandidate']
df.head()
# Out:
#    totCandidates  nCandidate   tot
# 0              2           1  True
# 1              2           1  True
# 2              2           0  True
# 3              2           0  True
# 4              2           1  True

# %%
df['tot'].unique()
# Out:
# array([ True])

# %%
features = ['nCandidate', 'totCandidate']
particles = ['L2', 'L1', 'K', 'p']

df = get_particles_data(particles, features, FNAME, SUFFIX)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in free_symbols(self, expression, keys, aliases, file_path, object_path)
#     381             try:
# --> 382                 return list(
#     383                     _walk_ast_yield_symbols(
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      91             x = getattr(node, field_name)
# ---> 92             for y in _walk_ast_yield_symbols(x, keys, aliases, functions, getter):
#      93                 yield y
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      96         for x in node:
# ---> 97             for y in _walk_ast_yield_symbols(x, keys, aliases, functions, getter):
#      98                 yield y
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      91             x = getattr(node, field_name)
# ---> 92             for y in _walk_ast_yield_symbols(x, keys, aliases, functions, getter):
#      93                 yield y
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      73         else:
# ---> 74             raise KeyError(node.id)
#      75
#
# KeyError: 'L2_nCandidate'
#
# During handling of the above exception, another exception occurred:
#
# KeyInFileError                            Traceback (most recent call last)
# /tmp/ipykernel_1377325/1999771459.py in <module>
#       2 particles = ['L2', 'L1', 'K', 'p']
#       3
# ----> 4 df = get_particles_data(particles, features, FNAME, SUFFIX)
#
# /tmp/ipykernel_1377325/2404522823.py in get_particles_data(particles, features, fName, suffix)
#      17         fts = [particle + "_" + feature for feature in features]
#      18         with up.open(fName + suffix) as f:
# ---> 19             df = f.arrays(fts, library="pd")
#      20             df.drop_duplicates(keep='first', inplace=True)
#      21             df.columns = features
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/behaviors/TBranch.py in arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, how)
#    1093
#    1094         aliases = _regularize_aliases(self, aliases)
# -> 1095         arrays, expression_context, branchid_interpretation = _regularize_expressions(
#    1096             self,
#    1097             expressions,
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/behaviors/TBranch.py in _regularize_expressions(hasbranches, expressions, cut, filter_name, filter_typename, filter_branch, keys, aliases, language, get_from_cache)
#    3298         for expression, interp in items:
#    3299             if interp is None:
# -> 3300                 _regularize_expression(
#    3301                     hasbranches,
#    3302                     expression,
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/behaviors/TBranch.py in _regularize_expression(hasbranches, expression, keys, aliases, language, get_from_cache, arrays, expression_context, branchid_interpretation, symbol_path, is_cut, rename)
#    3164         is_jagged = False
#    3165         expression_branches = []
# -> 3166         for symbol in language.free_symbols(
#    3167             to_compute,
#    3168             keys,
#
# /cvmfs/lhcbdev.cern.ch/conda/envs/default/2021-09-07_04-06/linux-64/lib/python3.9/site-packages/uproot/language/python.py in free_symbols(self, expression, keys, aliases, file_path, object_path)
#     386                 )
#     387             except KeyError as err:
# --> 388                 raise uproot.KeyInFileError(
#     389                     err.args[0], file_path=file_path, object_path=object_path
#     390                 )
#
# KeyInFileError: not found: 'L2_nCandidate'
# in file /disk/moose/lhcb/djdt/Lb2L1520mueTuples/realData/2016MD/halfSampleOct2021/blindedTriggeredL1520Selec-collision-firstHalf2016MD-pKmue_Full.root
# in object /DTT1520me/DecayTree;1

# %%
kaons = df['K']

# %%
sns.histplot(kaons['ProbNNp'])
# Out:
# <AxesSubplot:xlabel='ProbNNp', ylabel='Count'>
