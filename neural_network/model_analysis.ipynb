# %% [markdown]
# # Model Analysis
# Here we test different datasets made and see if they have features with stronger discriminating power. That is, the neural network can distinguish better between them. This can be a little unstable due to the nature of neural networks.

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import callbacks, layers, Sequential
import matplotlib.pyplot as plt
import mplhep as hep
import pandas as pd

# %%
def plot_history_curves(history, epochs, model_version='No version', savefig='', off=False, isBinary=True, hasAUC=True):
    if type(history) != dict:
        history = history.history
    
    loss = history['loss']
    val_loss = history['val_loss']
    if isBinary:
        accuracy = history['binary_accuracy']
        val_accuracy = history['val_binary_accuracy']
    else:
        accuracy = history['accuracy']
        val_accuracy = history['val_accuracy']
    if hasAUC:
        auc = history['auc']
        val_auc = history['val_auc']
    epoch_range = range(1, epochs+1, 1)    

    ncols = 2
    if hasAUC:
        ncols = 3
    fig, ax = plt.subplots(1, ncols, figsize=(18, 6))
    
    ax[0].plot(epoch_range, loss, 'r.', label='Training Loss')
    ax[0].plot(epoch_range, val_loss, 'b.', label='Validation Loss')
    ax[1].plot(epoch_range, accuracy, 'r.', label='Training Accuracy')
    ax[1].plot(epoch_range, val_accuracy, 'b.', label='Validation Accuracy')
    if hasAUC:
        ax[2].plot(epoch_range, auc, 'r.', label='Training AUC')
        ax[2].plot(epoch_range, val_auc, 'b.', label='Validation AUC')
        ax[2].set_xlabel('Epoch')
        ax[2].set_ylabel('AUC')
        ax[2].legend()
    
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')
    
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Accuracy')
    
    ax[0].legend()
    ax[1].legend()
    
    plt.title(model_version)
    plt.tight_layout()
    if savefig != '':
        plt.savefig(savefig)
    if not off:
        plt.show()

def plot_history(model_version, savefig='', off=False, isBinary=True, hasAUC=True):
    history = pickle.load(open(f'train_history/v{model_version}', "rb"))
    nepochs = len(history['loss'])
    plot_history_curves(history, nepochs, model_version, savefig, off, isBinary, hasAUC)

# %%
plt.style.use([hep.style.ROOT, hep.style.firamath])
version = '9.0.5'
train = pd.read_csv(f'../data_files/{version}/train.csv', index_col=[0])
X_train = train.drop(['category', 'Lb_M', 'IsSimulated'], axis=1)
y_train = train.category

val = pd.read_csv(f'../data_files/{version}/val.csv', index_col=[0])
X_val = val.drop(['category', 'Lb_M', 'IsSimulated'], axis=1)
y_val = val.category

test = pd.read_csv(f'../data_files/{version}/test.csv', index_col=[0])
X_test = test.drop(['category', 'Lb_M', 'IsSimulated'], axis=1)
y_test = test.category

# %% [markdown]
# ## Define the Model and get Data

# %%
custom_callbacks = [
    callbacks.EarlyStopping(patience=20, min_delta=0.0005, restore_best_weights=True), 
    callbacks.ReduceLROnPlateau(patience=5, factor=0.2, min_lr=0.001)
    ]

def compile_model(input_shape):
    model = Sequential([
        layers.Dense(16, activation='relu', input_shape=input_shape, kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['binary_accuracy', 'AUC', 'TruePositives', 'TrueNegatives', 'FalsePositives', 'FalseNegatives'])
    
    return model

# %%
def fit_model(model, train_data, val_data, model_version, callbacks=None, epochs=150, batch_size=512):
    model_history = model.fit(train_data[0], train_data[1], epochs=epochs, batch_size=batch_size, validation_data=val_data, callbacks=callbacks, verbose=1)
    with open(f'train_history/v{model_version}', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)
    model.save(f'models/v{model_version}')

# %%
def run_all(data, version):
    # Give it a list of data objects
    X_train, X_val, X_test = data[0], data[1], data[2]
    y_train, y_val, y_test = data[3], data[4], data[5]
    model = compile_model((X_train.shape[1],))
    fit_model(model, (X_train, y_train), (X_val, y_val), f'{version}', callbacks=custom_callbacks)
    plot_history(f'{version}', f'../images/NeuralNetwork/train_history/{version}.png', off=True)
    #history = pickle.load(open(f'train_history/v{version}', "rb"))
    # Dont plot the first 5 epochs they are dumb

# %%
run_all([X_train, X_val, X_test, y_train, y_val, y_test], version)
# Out:
# Epoch 1/150
# 43/43 [==============================] - 3s 32ms/step - loss: 0.9578 - binary_accuracy: 0.7672 - auc: 0.8528 - true_positives: 8234.0000 - true_negatives: 8515.0000 - false_positives: 2390.0000 - false_negatives: 2693.0000 - val_loss: 0.9038 - val_binary_accuracy: 0.8800 - val_auc: 0.9506 - val_true_positives: 3372.0000 - val_true_negatives: 3033.0000 - val_false_positives: 593.0000 - val_false_negatives: 280.0000
# Epoch 2/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.7420 - binary_accuracy: 0.8745 - auc: 0.9413 - true_positives: 9642.0000 - true_negatives: 9449.0000 - false_positives: 1456.0000 - false_negatives: 1285.0000 - val_loss: 0.7257 - val_binary_accuracy: 0.9148 - val_auc: 0.9710 - val_true_positives: 3408.0000 - val_true_negatives: 3250.0000 - val_false_positives: 376.0000 - val_false_negatives: 244.0000
# Epoch 3/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.6444 - binary_accuracy: 0.8964 - auc: 0.9584 - true_positives: 9848.0000 - true_negatives: 9723.0000 - false_positives: 1182.0000 - false_negatives: 1079.0000 - val_loss: 0.6143 - val_binary_accuracy: 0.9246 - val_auc: 0.9779 - val_true_positives: 3420.0000 - val_true_negatives: 3309.0000 - val_false_positives: 317.0000 - val_false_negatives: 232.0000
# Epoch 4/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.5695 - binary_accuracy: 0.9083 - auc: 0.9669 - true_positives: 9977.0000 - true_negatives: 9852.0000 - false_positives: 1053.0000 - false_negatives: 950.0000 - val_loss: 0.5393 - val_binary_accuracy: 0.9270 - val_auc: 0.9810 - val_true_positives: 3419.0000 - val_true_negatives: 3328.0000 - val_false_positives: 298.0000 - val_false_negatives: 233.0000
# Epoch 5/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.5093 - binary_accuracy: 0.9154 - auc: 0.9717 - true_positives: 10043.0000 - true_negatives: 9943.0000 - false_positives: 962.0000 - false_negatives: 884.0000 - val_loss: 0.4792 - val_binary_accuracy: 0.9312 - val_auc: 0.9829 - val_true_positives: 3408.0000 - val_true_negatives: 3369.0000 - val_false_positives: 257.0000 - val_false_negatives: 244.0000
# Epoch 6/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.4604 - binary_accuracy: 0.9223 - auc: 0.9742 - true_positives: 10094.0000 - true_negatives: 10042.0000 - false_positives: 863.0000 - false_negatives: 833.0000 - val_loss: 0.4389 - val_binary_accuracy: 0.9323 - val_auc: 0.9838 - val_true_positives: 3403.0000 - val_true_negatives: 3382.0000 - val_false_positives: 244.0000 - val_false_negatives: 249.0000
# Epoch 7/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.4221 - binary_accuracy: 0.9235 - auc: 0.9756 - true_positives: 10095.0000 - true_negatives: 10067.0000 - false_positives: 838.0000 - false_negatives: 832.0000 - val_loss: 0.4024 - val_binary_accuracy: 0.9327 - val_auc: 0.9846 - val_true_positives: 3420.0000 - val_true_negatives: 3368.0000 - val_false_positives: 258.0000 - val_false_negatives: 232.0000
# Epoch 8/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.3845 - binary_accuracy: 0.9281 - auc: 0.9779 - true_positives: 10147.0000 - true_negatives: 10115.0000 - false_positives: 790.0000 - false_negatives: 780.0000 - val_loss: 0.3782 - val_binary_accuracy: 0.9342 - val_auc: 0.9850 - val_true_positives: 3449.0000 - val_true_negatives: 3350.0000 - val_false_positives: 276.0000 - val_false_negatives: 203.0000
# Epoch 9/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.3554 - binary_accuracy: 0.9291 - auc: 0.9790 - true_positives: 10153.0000 - true_negatives: 10131.0000 - false_positives: 774.0000 - false_negatives: 774.0000 - val_loss: 0.3495 - val_binary_accuracy: 0.9368 - val_auc: 0.9855 - val_true_positives: 3405.0000 - val_true_negatives: 3413.0000 - val_false_positives: 213.0000 - val_false_negatives: 247.0000
# Epoch 10/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.3334 - binary_accuracy: 0.9330 - auc: 0.9793 - true_positives: 10161.0000 - true_negatives: 10208.0000 - false_positives: 697.0000 - false_negatives: 766.0000 - val_loss: 0.3423 - val_binary_accuracy: 0.9350 - val_auc: 0.9857 - val_true_positives: 3487.0000 - val_true_negatives: 3318.0000 - val_false_positives: 308.0000 - val_false_negatives: 165.0000
# Epoch 11/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.3106 - binary_accuracy: 0.9338 - auc: 0.9806 - true_positives: 10206.0000 - true_negatives: 10181.0000 - false_positives: 724.0000 - false_negatives: 721.0000 - val_loss: 0.3294 - val_binary_accuracy: 0.9383 - val_auc: 0.9864 - val_true_positives: 3481.0000 - val_true_negatives: 3348.0000 - val_false_positives: 278.0000 - val_false_negatives: 171.0000
# Epoch 12/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2985 - binary_accuracy: 0.9332 - auc: 0.9803 - true_positives: 10184.0000 - true_negatives: 10189.0000 - false_positives: 716.0000 - false_negatives: 743.0000 - val_loss: 0.2951 - val_binary_accuracy: 0.9373 - val_auc: 0.9863 - val_true_positives: 3397.0000 - val_true_negatives: 3425.0000 - val_false_positives: 201.0000 - val_false_negatives: 255.0000
# Epoch 13/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2822 - binary_accuracy: 0.9344 - auc: 0.9811 - true_positives: 10200.0000 - true_negatives: 10200.0000 - false_positives: 705.0000 - false_negatives: 727.0000 - val_loss: 0.2931 - val_binary_accuracy: 0.9412 - val_auc: 0.9870 - val_true_positives: 3457.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 195.0000
# Epoch 14/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2695 - binary_accuracy: 0.9350 - auc: 0.9817 - true_positives: 10209.0000 - true_negatives: 10204.0000 - false_positives: 701.0000 - false_negatives: 718.0000 - val_loss: 0.2781 - val_binary_accuracy: 0.9433 - val_auc: 0.9873 - val_true_positives: 3464.0000 - val_true_negatives: 3401.0000 - val_false_positives: 225.0000 - val_false_negatives: 188.0000
# Epoch 15/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2601 - binary_accuracy: 0.9365 - auc: 0.9818 - true_positives: 10224.0000 - true_negatives: 10221.0000 - false_positives: 684.0000 - false_negatives: 703.0000 - val_loss: 0.2660 - val_binary_accuracy: 0.9417 - val_auc: 0.9872 - val_true_positives: 3421.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 231.0000
# Epoch 16/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2480 - binary_accuracy: 0.9381 - auc: 0.9828 - true_positives: 10238.0000 - true_negatives: 10242.0000 - false_positives: 663.0000 - false_negatives: 689.0000 - val_loss: 0.2501 - val_binary_accuracy: 0.9430 - val_auc: 0.9875 - val_true_positives: 3443.0000 - val_true_negatives: 3420.0000 - val_false_positives: 206.0000 - val_false_negatives: 209.0000
# Epoch 17/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2427 - binary_accuracy: 0.9356 - auc: 0.9825 - true_positives: 10199.0000 - true_negatives: 10226.0000 - false_positives: 679.0000 - false_negatives: 728.0000 - val_loss: 0.2427 - val_binary_accuracy: 0.9393 - val_auc: 0.9878 - val_true_positives: 3503.0000 - val_true_negatives: 3333.0000 - val_false_positives: 293.0000 - val_false_negatives: 149.0000
# Epoch 18/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2352 - binary_accuracy: 0.9370 - auc: 0.9830 - true_positives: 10230.0000 - true_negatives: 10227.0000 - false_positives: 678.0000 - false_negatives: 697.0000 - val_loss: 0.2407 - val_binary_accuracy: 0.9409 - val_auc: 0.9876 - val_true_positives: 3469.0000 - val_true_negatives: 3379.0000 - val_false_positives: 247.0000 - val_false_negatives: 183.0000
# Epoch 19/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2281 - binary_accuracy: 0.9384 - auc: 0.9834 - true_positives: 10253.0000 - true_negatives: 10235.0000 - false_positives: 670.0000 - false_negatives: 674.0000 - val_loss: 0.2264 - val_binary_accuracy: 0.9423 - val_auc: 0.9876 - val_true_positives: 3436.0000 - val_true_negatives: 3422.0000 - val_false_positives: 204.0000 - val_false_negatives: 216.0000
# Epoch 20/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2212 - binary_accuracy: 0.9399 - auc: 0.9840 - true_positives: 10262.0000 - true_negatives: 10257.0000 - false_positives: 648.0000 - false_negatives: 665.0000 - val_loss: 0.2216 - val_binary_accuracy: 0.9395 - val_auc: 0.9881 - val_true_positives: 3524.0000 - val_true_negatives: 3314.0000 - val_false_positives: 312.0000 - val_false_negatives: 128.0000
# Epoch 21/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2211 - binary_accuracy: 0.9366 - auc: 0.9833 - true_positives: 10232.0000 - true_negatives: 10215.0000 - false_positives: 690.0000 - false_negatives: 695.0000 - val_loss: 0.2163 - val_binary_accuracy: 0.9419 - val_auc: 0.9877 - val_true_positives: 3432.0000 - val_true_negatives: 3423.0000 - val_false_positives: 203.0000 - val_false_negatives: 220.0000
# Epoch 22/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2161 - binary_accuracy: 0.9383 - auc: 0.9835 - true_positives: 10225.0000 - true_negatives: 10260.0000 - false_positives: 645.0000 - false_negatives: 702.0000 - val_loss: 0.2107 - val_binary_accuracy: 0.9445 - val_auc: 0.9883 - val_true_positives: 3470.0000 - val_true_negatives: 3404.0000 - val_false_positives: 222.0000 - val_false_negatives: 182.0000
# Epoch 23/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2131 - binary_accuracy: 0.9386 - auc: 0.9836 - true_positives: 10222.0000 - true_negatives: 10270.0000 - false_positives: 635.0000 - false_negatives: 705.0000 - val_loss: 0.2045 - val_binary_accuracy: 0.9428 - val_auc: 0.9879 - val_true_positives: 3466.0000 - val_true_negatives: 3396.0000 - val_false_positives: 230.0000 - val_false_negatives: 186.0000
# Epoch 24/150
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2124 - binary_accuracy: 0.9370 - auc: 0.9834 - true_positives: 10225.0000 - true_negatives: 10231.0000 - false_positives: 674.0000 - false_negatives: 702.0000 - val_loss: 0.2017 - val_binary_accuracy: 0.9438 - val_auc: 0.9882 - val_true_positives: 3487.0000 - val_true_negatives: 3382.0000 - val_false_positives: 244.0000 - val_false_negatives: 165.0000
# Epoch 25/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2075 - binary_accuracy: 0.9402 - auc: 0.9837 - true_positives: 10258.0000 - true_negatives: 10269.0000 - false_positives: 636.0000 - false_negatives: 669.0000 - val_loss: 0.2111 - val_binary_accuracy: 0.9405 - val_auc: 0.9885 - val_true_positives: 3522.0000 - val_true_negatives: 3323.0000 - val_false_positives: 303.0000 - val_false_negatives: 130.0000
# Epoch 26/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2028 - binary_accuracy: 0.9404 - auc: 0.9843 - true_positives: 10272.0000 - true_negatives: 10259.0000 - false_positives: 646.0000 - false_negatives: 655.0000 - val_loss: 0.1946 - val_binary_accuracy: 0.9423 - val_auc: 0.9880 - val_true_positives: 3382.0000 - val_true_negatives: 3476.0000 - val_false_positives: 150.0000 - val_false_negatives: 270.0000
# Epoch 27/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2042 - binary_accuracy: 0.9400 - auc: 0.9836 - true_positives: 10256.0000 - true_negatives: 10267.0000 - false_positives: 638.0000 - false_negatives: 671.0000 - val_loss: 0.1988 - val_binary_accuracy: 0.9460 - val_auc: 0.9887 - val_true_positives: 3461.0000 - val_true_negatives: 3424.0000 - val_false_positives: 202.0000 - val_false_negatives: 191.0000
# Epoch 28/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2009 - binary_accuracy: 0.9400 - auc: 0.9837 - true_positives: 10275.0000 - true_negatives: 10248.0000 - false_positives: 657.0000 - false_negatives: 652.0000 - val_loss: 0.1911 - val_binary_accuracy: 0.9442 - val_auc: 0.9883 - val_true_positives: 3485.0000 - val_true_negatives: 3387.0000 - val_false_positives: 239.0000 - val_false_negatives: 167.0000
# Epoch 29/150
# 43/43 [==============================] - 1s 12ms/step - loss: 0.1989 - binary_accuracy: 0.9391 - auc: 0.9841 - true_positives: 10256.0000 - true_negatives: 10246.0000 - false_positives: 659.0000 - false_negatives: 671.0000 - val_loss: 0.1809 - val_binary_accuracy: 0.9446 - val_auc: 0.9887 - val_true_positives: 3444.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 208.0000
# Epoch 30/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1968 - binary_accuracy: 0.9403 - auc: 0.9843 - true_positives: 10256.0000 - true_negatives: 10273.0000 - false_positives: 632.0000 - false_negatives: 671.0000 - val_loss: 0.1845 - val_binary_accuracy: 0.9448 - val_auc: 0.9889 - val_true_positives: 3473.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 179.0000
# Epoch 31/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1928 - binary_accuracy: 0.9412 - auc: 0.9847 - true_positives: 10265.0000 - true_negatives: 10284.0000 - false_positives: 621.0000 - false_negatives: 662.0000 - val_loss: 0.1847 - val_binary_accuracy: 0.9455 - val_auc: 0.9887 - val_true_positives: 3474.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 178.0000
# Epoch 32/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1916 - binary_accuracy: 0.9418 - auc: 0.9847 - true_positives: 10278.0000 - true_negatives: 10284.0000 - false_positives: 621.0000 - false_negatives: 649.0000 - val_loss: 0.1829 - val_binary_accuracy: 0.9449 - val_auc: 0.9888 - val_true_positives: 3468.0000 - val_true_negatives: 3409.0000 - val_false_positives: 217.0000 - val_false_negatives: 184.0000
# Epoch 33/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1926 - binary_accuracy: 0.9396 - auc: 0.9843 - true_positives: 10259.0000 - true_negatives: 10254.0000 - false_positives: 651.0000 - false_negatives: 668.0000 - val_loss: 0.1776 - val_binary_accuracy: 0.9456 - val_auc: 0.9888 - val_true_positives: 3487.0000 - val_true_negatives: 3395.0000 - val_false_positives: 231.0000 - val_false_negatives: 165.0000
# Epoch 34/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1916 - binary_accuracy: 0.9395 - auc: 0.9844 - true_positives: 10253.0000 - true_negatives: 10258.0000 - false_positives: 647.0000 - false_negatives: 674.0000 - val_loss: 0.1766 - val_binary_accuracy: 0.9439 - val_auc: 0.9885 - val_true_positives: 3439.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 213.0000
# Epoch 35/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1886 - binary_accuracy: 0.9415 - auc: 0.9847 - true_positives: 10266.0000 - true_negatives: 10289.0000 - false_positives: 616.0000 - false_negatives: 661.0000 - val_loss: 0.1778 - val_binary_accuracy: 0.9444 - val_auc: 0.9887 - val_true_positives: 3480.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 172.0000
# Epoch 36/150
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1902 - binary_accuracy: 0.9389 - auc: 0.9844 - true_positives: 10249.0000 - true_negatives: 10249.0000 - false_positives: 656.0000 - false_negatives: 678.0000 - val_loss: 0.1762 - val_binary_accuracy: 0.9450 - val_auc: 0.9888 - val_true_positives: 3439.0000 - val_true_negatives: 3439.0000 - val_false_positives: 187.0000 - val_false_negatives: 213.0000
# Epoch 37/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1855 - binary_accuracy: 0.9420 - auc: 0.9850 - true_positives: 10266.0000 - true_negatives: 10300.0000 - false_positives: 605.0000 - false_negatives: 661.0000 - val_loss: 0.1788 - val_binary_accuracy: 0.9438 - val_auc: 0.9889 - val_true_positives: 3385.0000 - val_true_negatives: 3484.0000 - val_false_positives: 142.0000 - val_false_negatives: 267.0000
# Epoch 38/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1837 - binary_accuracy: 0.9413 - auc: 0.9853 - true_positives: 10255.0000 - true_negatives: 10295.0000 - false_positives: 610.0000 - false_negatives: 672.0000 - val_loss: 0.1716 - val_binary_accuracy: 0.9424 - val_auc: 0.9883 - val_true_positives: 3404.0000 - val_true_negatives: 3455.0000 - val_false_positives: 171.0000 - val_false_negatives: 248.0000
# Epoch 39/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1828 - binary_accuracy: 0.9443 - auc: 0.9850 - true_positives: 10300.0000 - true_negatives: 10315.0000 - false_positives: 590.0000 - false_negatives: 627.0000 - val_loss: 0.1678 - val_binary_accuracy: 0.9445 - val_auc: 0.9889 - val_true_positives: 3454.0000 - val_true_negatives: 3420.0000 - val_false_positives: 206.0000 - val_false_negatives: 198.0000
# Epoch 40/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1816 - binary_accuracy: 0.9436 - auc: 0.9852 - true_positives: 10292.0000 - true_negatives: 10309.0000 - false_positives: 596.0000 - false_negatives: 635.0000 - val_loss: 0.1658 - val_binary_accuracy: 0.9490 - val_auc: 0.9894 - val_true_positives: 3475.0000 - val_true_negatives: 3432.0000 - val_false_positives: 194.0000 - val_false_negatives: 177.0000
# Epoch 41/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1812 - binary_accuracy: 0.9427 - auc: 0.9854 - true_positives: 10293.0000 - true_negatives: 10287.0000 - false_positives: 618.0000 - false_negatives: 634.0000 - val_loss: 0.1703 - val_binary_accuracy: 0.9460 - val_auc: 0.9889 - val_true_positives: 3430.0000 - val_true_negatives: 3455.0000 - val_false_positives: 171.0000 - val_false_negatives: 222.0000
# Epoch 42/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1820 - binary_accuracy: 0.9402 - auc: 0.9852 - true_positives: 10250.0000 - true_negatives: 10276.0000 - false_positives: 629.0000 - false_negatives: 677.0000 - val_loss: 0.1666 - val_binary_accuracy: 0.9445 - val_auc: 0.9885 - val_true_positives: 3416.0000 - val_true_negatives: 3458.0000 - val_false_positives: 168.0000 - val_false_negatives: 236.0000
# Epoch 43/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1804 - binary_accuracy: 0.9425 - auc: 0.9853 - true_positives: 10283.0000 - true_negatives: 10293.0000 - false_positives: 612.0000 - false_negatives: 644.0000 - val_loss: 0.1637 - val_binary_accuracy: 0.9468 - val_auc: 0.9890 - val_true_positives: 3448.0000 - val_true_negatives: 3443.0000 - val_false_positives: 183.0000 - val_false_negatives: 204.0000
# Epoch 44/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1799 - binary_accuracy: 0.9423 - auc: 0.9853 - true_positives: 10291.0000 - true_negatives: 10281.0000 - false_positives: 624.0000 - false_negatives: 636.0000 - val_loss: 0.1723 - val_binary_accuracy: 0.9452 - val_auc: 0.9891 - val_true_positives: 3385.0000 - val_true_negatives: 3494.0000 - val_false_positives: 132.0000 - val_false_negatives: 267.0000
# Epoch 45/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1787 - binary_accuracy: 0.9417 - auc: 0.9854 - true_positives: 10260.0000 - true_negatives: 10299.0000 - false_positives: 606.0000 - false_negatives: 667.0000 - val_loss: 0.1652 - val_binary_accuracy: 0.9505 - val_auc: 0.9902 - val_true_positives: 3463.0000 - val_true_negatives: 3455.0000 - val_false_positives: 171.0000 - val_false_negatives: 189.0000
# Epoch 46/150
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1833 - binary_accuracy: 0.9421 - auc: 0.9844 - true_positives: 10288.0000 - true_negatives: 10279.0000 - false_positives: 626.0000 - false_negatives: 639.0000 - val_loss: 0.1682 - val_binary_accuracy: 0.9455 - val_auc: 0.9885 - val_true_positives: 3415.0000 - val_true_negatives: 3466.0000 - val_false_positives: 160.0000 - val_false_negatives: 237.0000
# Epoch 47/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1798 - binary_accuracy: 0.9410 - auc: 0.9852 - true_positives: 10250.0000 - true_negatives: 10294.0000 - false_positives: 611.0000 - false_negatives: 677.0000 - val_loss: 0.1626 - val_binary_accuracy: 0.9470 - val_auc: 0.9892 - val_true_positives: 3459.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 193.0000
# Epoch 48/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1790 - binary_accuracy: 0.9426 - auc: 0.9850 - true_positives: 10275.0000 - true_negatives: 10303.0000 - false_positives: 602.0000 - false_negatives: 652.0000 - val_loss: 0.1605 - val_binary_accuracy: 0.9471 - val_auc: 0.9895 - val_true_positives: 3414.0000 - val_true_negatives: 3479.0000 - val_false_positives: 147.0000 - val_false_negatives: 238.0000
# Epoch 49/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1763 - binary_accuracy: 0.9439 - auc: 0.9853 - true_positives: 10301.0000 - true_negatives: 10307.0000 - false_positives: 598.0000 - false_negatives: 626.0000 - val_loss: 0.1594 - val_binary_accuracy: 0.9470 - val_auc: 0.9895 - val_true_positives: 3424.0000 - val_true_negatives: 3468.0000 - val_false_positives: 158.0000 - val_false_negatives: 228.0000
# Epoch 50/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1781 - binary_accuracy: 0.9416 - auc: 0.9852 - true_positives: 10255.0000 - true_negatives: 10301.0000 - false_positives: 604.0000 - false_negatives: 672.0000 - val_loss: 0.1636 - val_binary_accuracy: 0.9504 - val_auc: 0.9895 - val_true_positives: 3452.0000 - val_true_negatives: 3465.0000 - val_false_positives: 161.0000 - val_false_negatives: 200.0000
# Epoch 51/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1775 - binary_accuracy: 0.9405 - auc: 0.9851 - true_positives: 10243.0000 - true_negatives: 10290.0000 - false_positives: 615.0000 - false_negatives: 684.0000 - val_loss: 0.1631 - val_binary_accuracy: 0.9471 - val_auc: 0.9886 - val_true_positives: 3426.0000 - val_true_negatives: 3467.0000 - val_false_positives: 159.0000 - val_false_negatives: 226.0000
# Epoch 52/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1756 - binary_accuracy: 0.9420 - auc: 0.9855 - true_positives: 10278.0000 - true_negatives: 10287.0000 - false_positives: 618.0000 - false_negatives: 649.0000 - val_loss: 0.1592 - val_binary_accuracy: 0.9492 - val_auc: 0.9899 - val_true_positives: 3451.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 201.0000
# Epoch 53/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1773 - binary_accuracy: 0.9425 - auc: 0.9849 - true_positives: 10267.0000 - true_negatives: 10310.0000 - false_positives: 595.0000 - false_negatives: 660.0000 - val_loss: 0.1642 - val_binary_accuracy: 0.9459 - val_auc: 0.9888 - val_true_positives: 3483.0000 - val_true_negatives: 3401.0000 - val_false_positives: 225.0000 - val_false_negatives: 169.0000
# Epoch 54/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1769 - binary_accuracy: 0.9420 - auc: 0.9852 - true_positives: 10264.0000 - true_negatives: 10301.0000 - false_positives: 604.0000 - false_negatives: 663.0000 - val_loss: 0.1575 - val_binary_accuracy: 0.9490 - val_auc: 0.9895 - val_true_positives: 3444.0000 - val_true_negatives: 3463.0000 - val_false_positives: 163.0000 - val_false_negatives: 208.0000
# Epoch 55/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1755 - binary_accuracy: 0.9421 - auc: 0.9854 - true_positives: 10253.0000 - true_negatives: 10314.0000 - false_positives: 591.0000 - false_negatives: 674.0000 - val_loss: 0.1557 - val_binary_accuracy: 0.9494 - val_auc: 0.9898 - val_true_positives: 3462.0000 - val_true_negatives: 3448.0000 - val_false_positives: 178.0000 - val_false_negatives: 190.0000
# Epoch 56/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1746 - binary_accuracy: 0.9429 - auc: 0.9855 - true_positives: 10278.0000 - true_negatives: 10307.0000 - false_positives: 598.0000 - false_negatives: 649.0000 - val_loss: 0.1596 - val_binary_accuracy: 0.9457 - val_auc: 0.9896 - val_true_positives: 3379.0000 - val_true_negatives: 3504.0000 - val_false_positives: 122.0000 - val_false_negatives: 273.0000
# Epoch 57/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1734 - binary_accuracy: 0.9426 - auc: 0.9857 - true_positives: 10250.0000 - true_negatives: 10329.0000 - false_positives: 576.0000 - false_negatives: 677.0000 - val_loss: 0.1609 - val_binary_accuracy: 0.9450 - val_auc: 0.9896 - val_true_positives: 3377.0000 - val_true_negatives: 3501.0000 - val_false_positives: 125.0000 - val_false_negatives: 275.0000
# Epoch 58/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1765 - binary_accuracy: 0.9419 - auc: 0.9850 - true_positives: 10257.0000 - true_negatives: 10306.0000 - false_positives: 599.0000 - false_negatives: 670.0000 - val_loss: 0.1595 - val_binary_accuracy: 0.9441 - val_auc: 0.9893 - val_true_positives: 3369.0000 - val_true_negatives: 3502.0000 - val_false_positives: 124.0000 - val_false_negatives: 283.0000
# Epoch 59/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1730 - binary_accuracy: 0.9425 - auc: 0.9857 - true_positives: 10271.0000 - true_negatives: 10305.0000 - false_positives: 600.0000 - false_negatives: 656.0000 - val_loss: 0.1583 - val_binary_accuracy: 0.9478 - val_auc: 0.9893 - val_true_positives: 3438.0000 - val_true_negatives: 3460.0000 - val_false_positives: 166.0000 - val_false_negatives: 214.0000
# Epoch 60/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1734 - binary_accuracy: 0.9437 - auc: 0.9854 - true_positives: 10306.0000 - true_negatives: 10297.0000 - false_positives: 608.0000 - false_negatives: 621.0000 - val_loss: 0.1567 - val_binary_accuracy: 0.9474 - val_auc: 0.9891 - val_true_positives: 3424.0000 - val_true_negatives: 3471.0000 - val_false_positives: 155.0000 - val_false_negatives: 228.0000
# Epoch 61/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1753 - binary_accuracy: 0.9411 - auc: 0.9851 - true_positives: 10261.0000 - true_negatives: 10286.0000 - false_positives: 619.0000 - false_negatives: 666.0000 - val_loss: 0.1640 - val_binary_accuracy: 0.9448 - val_auc: 0.9890 - val_true_positives: 3378.0000 - val_true_negatives: 3498.0000 - val_false_positives: 128.0000 - val_false_negatives: 274.0000
# Epoch 62/150
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1725 - binary_accuracy: 0.9421 - auc: 0.9856 - true_positives: 10266.0000 - true_negatives: 10301.0000 - false_positives: 604.0000 - false_negatives: 661.0000 - val_loss: 0.1575 - val_binary_accuracy: 0.9455 - val_auc: 0.9890 - val_true_positives: 3403.0000 - val_true_negatives: 3478.0000 - val_false_positives: 148.0000 - val_false_negatives: 249.0000
# Epoch 63/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1728 - binary_accuracy: 0.9414 - auc: 0.9854 - true_positives: 10270.0000 - true_negatives: 10282.0000 - false_positives: 623.0000 - false_negatives: 657.0000 - val_loss: 0.1602 - val_binary_accuracy: 0.9468 - val_auc: 0.9895 - val_true_positives: 3393.0000 - val_true_negatives: 3498.0000 - val_false_positives: 128.0000 - val_false_negatives: 259.0000
# Epoch 64/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1735 - binary_accuracy: 0.9427 - auc: 0.9851 - true_positives: 10273.0000 - true_negatives: 10308.0000 - false_positives: 597.0000 - false_negatives: 654.0000 - val_loss: 0.1600 - val_binary_accuracy: 0.9457 - val_auc: 0.9891 - val_true_positives: 3501.0000 - val_true_negatives: 3382.0000 - val_false_positives: 244.0000 - val_false_negatives: 151.0000
# Epoch 65/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1738 - binary_accuracy: 0.9420 - auc: 0.9852 - true_positives: 10278.0000 - true_negatives: 10287.0000 - false_positives: 618.0000 - false_negatives: 649.0000 - val_loss: 0.1532 - val_binary_accuracy: 0.9483 - val_auc: 0.9895 - val_true_positives: 3465.0000 - val_true_negatives: 3437.0000 - val_false_positives: 189.0000 - val_false_negatives: 187.0000
# Epoch 66/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1709 - binary_accuracy: 0.9427 - auc: 0.9856 - true_positives: 10285.0000 - true_negatives: 10296.0000 - false_positives: 609.0000 - false_negatives: 642.0000 - val_loss: 0.1609 - val_binary_accuracy: 0.9435 - val_auc: 0.9897 - val_true_positives: 3343.0000 - val_true_negatives: 3524.0000 - val_false_positives: 102.0000 - val_false_negatives: 309.0000
# Epoch 67/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1718 - binary_accuracy: 0.9421 - auc: 0.9855 - true_positives: 10279.0000 - true_negatives: 10288.0000 - false_positives: 617.0000 - false_negatives: 648.0000 - val_loss: 0.1587 - val_binary_accuracy: 0.9489 - val_auc: 0.9887 - val_true_positives: 3473.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 179.0000
# Epoch 68/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1716 - binary_accuracy: 0.9416 - auc: 0.9855 - true_positives: 10272.0000 - true_negatives: 10286.0000 - false_positives: 619.0000 - false_negatives: 655.0000 - val_loss: 0.1573 - val_binary_accuracy: 0.9455 - val_auc: 0.9892 - val_true_positives: 3383.0000 - val_true_negatives: 3498.0000 - val_false_positives: 128.0000 - val_false_negatives: 269.0000
# Epoch 69/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1706 - binary_accuracy: 0.9429 - auc: 0.9856 - true_positives: 10263.0000 - true_negatives: 10323.0000 - false_positives: 582.0000 - false_negatives: 664.0000 - val_loss: 0.1514 - val_binary_accuracy: 0.9498 - val_auc: 0.9895 - val_true_positives: 3441.0000 - val_true_negatives: 3472.0000 - val_false_positives: 154.0000 - val_false_negatives: 211.0000
# Epoch 70/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1723 - binary_accuracy: 0.9424 - auc: 0.9851 - true_positives: 10272.0000 - true_negatives: 10302.0000 - false_positives: 603.0000 - false_negatives: 655.0000 - val_loss: 0.1551 - val_binary_accuracy: 0.9477 - val_auc: 0.9890 - val_true_positives: 3433.0000 - val_true_negatives: 3464.0000 - val_false_positives: 162.0000 - val_false_negatives: 219.0000
# Epoch 71/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1737 - binary_accuracy: 0.9410 - auc: 0.9850 - true_positives: 10255.0000 - true_negatives: 10290.0000 - false_positives: 615.0000 - false_negatives: 672.0000 - val_loss: 0.1523 - val_binary_accuracy: 0.9486 - val_auc: 0.9895 - val_true_positives: 3419.0000 - val_true_negatives: 3485.0000 - val_false_positives: 141.0000 - val_false_negatives: 233.0000
# Epoch 72/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1728 - binary_accuracy: 0.9410 - auc: 0.9852 - true_positives: 10268.0000 - true_negatives: 10275.0000 - false_positives: 630.0000 - false_negatives: 659.0000 - val_loss: 0.1539 - val_binary_accuracy: 0.9478 - val_auc: 0.9889 - val_true_positives: 3424.0000 - val_true_negatives: 3474.0000 - val_false_positives: 152.0000 - val_false_negatives: 228.0000
# Epoch 73/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1714 - binary_accuracy: 0.9423 - auc: 0.9852 - true_positives: 10271.0000 - true_negatives: 10302.0000 - false_positives: 603.0000 - false_negatives: 656.0000 - val_loss: 0.1532 - val_binary_accuracy: 0.9479 - val_auc: 0.9895 - val_true_positives: 3405.0000 - val_true_negatives: 3494.0000 - val_false_positives: 132.0000 - val_false_negatives: 247.0000
# Epoch 74/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1687 - binary_accuracy: 0.9433 - auc: 0.9857 - true_positives: 10273.0000 - true_negatives: 10322.0000 - false_positives: 583.0000 - false_negatives: 654.0000 - val_loss: 0.1538 - val_binary_accuracy: 0.9492 - val_auc: 0.9895 - val_true_positives: 3443.0000 - val_true_negatives: 3465.0000 - val_false_positives: 161.0000 - val_false_negatives: 209.0000
# Epoch 75/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1676 - binary_accuracy: 0.9449 - auc: 0.9859 - true_positives: 10287.0000 - true_negatives: 10341.0000 - false_positives: 564.0000 - false_negatives: 640.0000 - val_loss: 0.1498 - val_binary_accuracy: 0.9493 - val_auc: 0.9898 - val_true_positives: 3443.0000 - val_true_negatives: 3466.0000 - val_false_positives: 160.0000 - val_false_negatives: 209.0000
# Epoch 76/150
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1716 - binary_accuracy: 0.9432 - auc: 0.9851 - true_positives: 10256.0000 - true_negatives: 10335.0000 - false_positives: 570.0000 - false_negatives: 671.0000 - val_loss: 0.1546 - val_binary_accuracy: 0.9463 - val_auc: 0.9896 - val_true_positives: 3510.0000 - val_true_negatives: 3377.0000 - val_false_positives: 249.0000 - val_false_negatives: 142.0000
# Epoch 77/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1685 - binary_accuracy: 0.9443 - auc: 0.9857 - true_positives: 10285.0000 - true_negatives: 10330.0000 - false_positives: 575.0000 - false_negatives: 642.0000 - val_loss: 0.1531 - val_binary_accuracy: 0.9494 - val_auc: 0.9894 - val_true_positives: 3463.0000 - val_true_negatives: 3447.0000 - val_false_positives: 179.0000 - val_false_negatives: 189.0000
# Epoch 78/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1676 - binary_accuracy: 0.9438 - auc: 0.9861 - true_positives: 10287.0000 - true_negatives: 10319.0000 - false_positives: 586.0000 - false_negatives: 640.0000 - val_loss: 0.1545 - val_binary_accuracy: 0.9475 - val_auc: 0.9894 - val_true_positives: 3396.0000 - val_true_negatives: 3500.0000 - val_false_positives: 126.0000 - val_false_negatives: 256.0000
# Epoch 79/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1715 - binary_accuracy: 0.9419 - auc: 0.9853 - true_positives: 10259.0000 - true_negatives: 10304.0000 - false_positives: 601.0000 - false_negatives: 668.0000 - val_loss: 0.1518 - val_binary_accuracy: 0.9489 - val_auc: 0.9894 - val_true_positives: 3444.0000 - val_true_negatives: 3462.0000 - val_false_positives: 164.0000 - val_false_negatives: 208.0000
# Epoch 80/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1685 - binary_accuracy: 0.9427 - auc: 0.9858 - true_positives: 10268.0000 - true_negatives: 10314.0000 - false_positives: 591.0000 - false_negatives: 659.0000 - val_loss: 0.1507 - val_binary_accuracy: 0.9500 - val_auc: 0.9894 - val_true_positives: 3457.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 195.0000
# Epoch 81/150
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1682 - binary_accuracy: 0.9438 - auc: 0.9857 - true_positives: 10278.0000 - true_negatives: 10326.0000 - false_positives: 579.0000 - false_negatives: 649.0000 - val_loss: 0.1488 - val_binary_accuracy: 0.9494 - val_auc: 0.9902 - val_true_positives: 3420.0000 - val_true_negatives: 3490.0000 - val_false_positives: 136.0000 - val_false_negatives: 232.0000
# Epoch 82/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1706 - binary_accuracy: 0.9440 - auc: 0.9852 - true_positives: 10289.0000 - true_negatives: 10321.0000 - false_positives: 584.0000 - false_negatives: 638.0000 - val_loss: 0.1538 - val_binary_accuracy: 0.9475 - val_auc: 0.9894 - val_true_positives: 3417.0000 - val_true_negatives: 3479.0000 - val_false_positives: 147.0000 - val_false_negatives: 235.0000
# Epoch 83/150
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1682 - binary_accuracy: 0.9425 - auc: 0.9858 - true_positives: 10271.0000 - true_negatives: 10305.0000 - false_positives: 600.0000 - false_negatives: 656.0000 - val_loss: 0.1537 - val_binary_accuracy: 0.9487 - val_auc: 0.9895 - val_true_positives: 3514.0000 - val_true_negatives: 3391.0000 - val_false_positives: 235.0000 - val_false_negatives: 138.0000
# Epoch 84/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1664 - binary_accuracy: 0.9422 - auc: 0.9859 - true_positives: 10282.0000 - true_negatives: 10288.0000 - false_positives: 617.0000 - false_negatives: 645.0000 - val_loss: 0.1520 - val_binary_accuracy: 0.9501 - val_auc: 0.9892 - val_true_positives: 3475.0000 - val_true_negatives: 3440.0000 - val_false_positives: 186.0000 - val_false_negatives: 177.0000
# Epoch 85/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1715 - binary_accuracy: 0.9428 - auc: 0.9850 - true_positives: 10264.0000 - true_negatives: 10320.0000 - false_positives: 585.0000 - false_negatives: 663.0000 - val_loss: 0.1506 - val_binary_accuracy: 0.9477 - val_auc: 0.9896 - val_true_positives: 3425.0000 - val_true_negatives: 3472.0000 - val_false_positives: 154.0000 - val_false_negatives: 227.0000
# Epoch 86/150
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1698 - binary_accuracy: 0.9422 - auc: 0.9855 - true_positives: 10269.0000 - true_negatives: 10301.0000 - false_positives: 604.0000 - false_negatives: 658.0000 - val_loss: 0.1532 - val_binary_accuracy: 0.9471 - val_auc: 0.9890 - val_true_positives: 3432.0000 - val_true_negatives: 3461.0000 - val_false_positives: 165.0000 - val_false_negatives: 220.0000
# Epoch 87/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1644 - binary_accuracy: 0.9452 - auc: 0.9863 - true_positives: 10304.0000 - true_negatives: 10332.0000 - false_positives: 573.0000 - false_negatives: 623.0000 - val_loss: 0.1516 - val_binary_accuracy: 0.9471 - val_auc: 0.9893 - val_true_positives: 3459.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 193.0000
# Epoch 88/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1662 - binary_accuracy: 0.9442 - auc: 0.9861 - true_positives: 10300.0000 - true_negatives: 10314.0000 - false_positives: 591.0000 - false_negatives: 627.0000 - val_loss: 0.1578 - val_binary_accuracy: 0.9444 - val_auc: 0.9882 - val_true_positives: 3439.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 213.0000
# Epoch 89/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1680 - binary_accuracy: 0.9434 - auc: 0.9858 - true_positives: 10264.0000 - true_negatives: 10332.0000 - false_positives: 573.0000 - false_negatives: 663.0000 - val_loss: 0.1593 - val_binary_accuracy: 0.9466 - val_auc: 0.9890 - val_true_positives: 3508.0000 - val_true_negatives: 3381.0000 - val_false_positives: 245.0000 - val_false_negatives: 144.0000
# Epoch 90/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1672 - binary_accuracy: 0.9425 - auc: 0.9859 - true_positives: 10256.0000 - true_negatives: 10321.0000 - false_positives: 584.0000 - false_negatives: 671.0000 - val_loss: 0.1551 - val_binary_accuracy: 0.9481 - val_auc: 0.9894 - val_true_positives: 3503.0000 - val_true_negatives: 3397.0000 - val_false_positives: 229.0000 - val_false_negatives: 149.0000
# Epoch 91/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1680 - binary_accuracy: 0.9427 - auc: 0.9857 - true_positives: 10270.0000 - true_negatives: 10310.0000 - false_positives: 595.0000 - false_negatives: 657.0000 - val_loss: 0.1495 - val_binary_accuracy: 0.9483 - val_auc: 0.9894 - val_true_positives: 3439.0000 - val_true_negatives: 3463.0000 - val_false_positives: 163.0000 - val_false_negatives: 213.0000
# Epoch 92/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1687 - binary_accuracy: 0.9426 - auc: 0.9856 - true_positives: 10274.0000 - true_negatives: 10305.0000 - false_positives: 600.0000 - false_negatives: 653.0000 - val_loss: 0.1488 - val_binary_accuracy: 0.9475 - val_auc: 0.9897 - val_true_positives: 3411.0000 - val_true_negatives: 3485.0000 - val_false_positives: 141.0000 - val_false_negatives: 241.0000
# Epoch 93/150
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1680 - binary_accuracy: 0.9430 - auc: 0.9857 - true_positives: 10262.0000 - true_negatives: 10325.0000 - false_positives: 580.0000 - false_negatives: 665.0000 - val_loss: 0.1487 - val_binary_accuracy: 0.9503 - val_auc: 0.9896 - val_true_positives: 3451.0000 - val_true_negatives: 3465.0000 - val_false_positives: 161.0000 - val_false_negatives: 201.0000
# Epoch 94/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1680 - binary_accuracy: 0.9439 - auc: 0.9854 - true_positives: 10272.0000 - true_negatives: 10336.0000 - false_positives: 569.0000 - false_negatives: 655.0000 - val_loss: 0.1518 - val_binary_accuracy: 0.9497 - val_auc: 0.9895 - val_true_positives: 3481.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 171.0000
# Epoch 95/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1687 - binary_accuracy: 0.9422 - auc: 0.9855 - true_positives: 10258.0000 - true_negatives: 10313.0000 - false_positives: 592.0000 - false_negatives: 669.0000 - val_loss: 0.1533 - val_binary_accuracy: 0.9487 - val_auc: 0.9896 - val_true_positives: 3495.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 157.0000
# Epoch 96/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1700 - binary_accuracy: 0.9424 - auc: 0.9853 - true_positives: 10287.0000 - true_negatives: 10288.0000 - false_positives: 617.0000 - false_negatives: 640.0000 - val_loss: 0.1536 - val_binary_accuracy: 0.9482 - val_auc: 0.9893 - val_true_positives: 3399.0000 - val_true_negatives: 3502.0000 - val_false_positives: 124.0000 - val_false_negatives: 253.0000
# Epoch 97/150
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1705 - binary_accuracy: 0.9415 - auc: 0.9849 - true_positives: 10247.0000 - true_negatives: 10308.0000 - false_positives: 597.0000 - false_negatives: 680.0000 - val_loss: 0.1495 - val_binary_accuracy: 0.9497 - val_auc: 0.9895 - val_true_positives: 3475.0000 - val_true_negatives: 3437.0000 - val_false_positives: 189.0000 - val_false_negatives: 177.0000
# Epoch 98/150
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1696 - binary_accuracy: 0.9421 - auc: 0.9853 - true_positives: 10269.0000 - true_negatives: 10298.0000 - false_positives: 607.0000 - false_negatives: 658.0000 - val_loss: 0.1487 - val_binary_accuracy: 0.9494 - val_auc: 0.9898 - val_true_positives: 3444.0000 - val_true_negatives: 3466.0000 - val_false_positives: 160.0000 - val_false_negatives: 208.0000
# Epoch 99/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1689 - binary_accuracy: 0.9416 - auc: 0.9853 - true_positives: 10270.0000 - true_negatives: 10288.0000 - false_positives: 617.0000 - false_negatives: 657.0000 - val_loss: 0.1565 - val_binary_accuracy: 0.9446 - val_auc: 0.9892 - val_true_positives: 3373.0000 - val_true_negatives: 3502.0000 - val_false_positives: 124.0000 - val_false_negatives: 279.0000
# Epoch 100/150
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1684 - binary_accuracy: 0.9415 - auc: 0.9855 - true_positives: 10251.0000 - true_negatives: 10304.0000 - false_positives: 601.0000 - false_negatives: 676.0000 - val_loss: 0.1511 - val_binary_accuracy: 0.9477 - val_auc: 0.9893 - val_true_positives: 3422.0000 - val_true_negatives: 3475.0000 - val_false_positives: 151.0000 - val_false_negatives: 230.0000
# Epoch 101/150
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1675 - binary_accuracy: 0.9437 - auc: 0.9855 - true_positives: 10259.0000 - true_negatives: 10344.0000 - false_positives: 561.0000 - false_negatives: 668.0000 - val_loss: 0.1528 - val_binary_accuracy: 0.9468 - val_auc: 0.9893 - val_true_positives: 3496.0000 - val_true_negatives: 3395.0000 - val_false_positives: 231.0000 - val_false_negatives: 156.0000
# INFO:tensorflow:Assets written to: models/v9.0.5/assets

# %% [markdown]
# ## Plot Prediction Distribution
# Now we plot the distribution of the assigned probabilities across the train, validation and test data. Split colours via the dataset and solid or dashed being either signal or bakground.

# %%
model = tf.keras.models.load_model(f'models/v{version}')

X_test_sig = X_test[y_test == 1]
X_test_bg = X_test[y_test == 0]

X_val_sig = X_val[y_val == 1]
X_val_bg = X_val[y_val == 0]

X_train_sig = X_train[y_train == 1]
X_train_bg = X_train[y_train == 0]

tests = model.predict(X_test_sig).flatten()
vals = model.predict(X_val_sig).flatten()
trains = model.predict(X_train_sig).flatten()
testb = model.predict(X_test_bg).flatten()
valb = model.predict(X_val_bg).flatten()
trainb = model.predict(X_train_bg).flatten()

# %%
sets = [trainb, trains, valb, vals, testb, tests]

bins = np.linspace(0, 1, 41)
bin_centres = 0.5*(bins[1:] + bins[:-1])
labs = ['Train', 'Val', 'Test']

dath = [np.histogram(sett, bins=bins, density=True)[0] for sett in sets]

fig, ax = plt.subplots(1, 1)
hep.histplot(dath, bins=bins, ax=ax, label=['Train Bg', 'Train Sig', 'Val Bg', 'Val Sig', 'Test Bg', 'Test Sig'])
ax.set_ylim(bottom=0)
plt.ylabel('Normalised Frequency')
plt.xlabel('Probability')
plt.title(f'Prob. Dist. for Model {version}')
plt.legend(loc='upper center')
plt.savefig(f'../images/NeuralNetwork/prob_dists/{version}_prob_dist.png')
plt.show()

# %% [markdown]
# # Punzi FOM Scan This calculation method can introduce BIAS
# Now we have a model which is producing a reasonable set of predictions that are fairly stable (hence the U-shaped graph) and are common for the training, validation and test features. As such we can now evaluate the Punzi FOM across the probability space to define where our cut point should be to maximise signal selection and background rejection efficiency.

# %%
def calculate_punzi(model, labelled_data, prob_range=[0.3, 0.9], dpoints=150, significance=5, mass_range=[5200, 5800]):
    import numpy as np
    import pandas as pd
    
    probability_space = np.linspace(prob_range[0], prob_range[1], dpoints)
    # A region over which the Punzi FOM will be calculated
    
    labels = labelled_data['category'].to_numpy()
    nsignal_before = labelled_data['category'].value_counts()[1]
    # How many signal events are in the original data sample
    
    feature_cols = labelled_data.columns.to_list()
    feature_cols.remove('category')
    # Get all the columns with features and not the category
    predictions = model.predict(labelled_data[feature_cols])
    # Make predictions on the labelled data using the trained MVA model
    
    punzis = []
    for p in probability_space:
        # Iterate through each point in probability space
        
        # Each event is predicted a probability P. If P < p we say that,
        # it is background, else it is signal. I.e. p -> 1 in limit of high
        # background rejection, high purity sample 
        
        preds = np.squeeze(np.where(predictions < p, 0, 1))
        all = np.array([preds, labels]).T
        
        efficiency = len(np.squeeze(np.where((all == [1, 1]).all(axis=1)))) / nsignal_before
        # Truth matched signal i.e. model said it was signal and it actually was 
        
        background = len(np.squeeze(np.where((all == [1, 0]).all(axis=1))))
        # background you thought was signal, so did not reject i.e. it got through 
        
        #print(f'{p:.4f} {efficiency:.5f} {background}')
        # Background is how much background is left after the cut i.e. how much REAL background is left (incorrectly identified as signal)
        
        punzi = efficiency / (significance/2 + np.sqrt(background))
        # Calculate the Punzi as defined by LHCb 
        
        punzis.append(punzi)
        # Add this point to the array of Punzis
    return np.array(punzis), probability_space

# %%
test_df = X_test
test_df['category'] = y_test

val_df = X_val
val_df['category'] = y_val

train_df = X_train
train_df['category'] = y_train

# %%
p1, probs1 = calculate_punzi(model, train_df, prob_range=[0.4, 0.98], dpoints=1000)
p2, probs2 = calculate_punzi(model, val_df, prob_range=[0.4, 0.98], dpoints=1000)
p3, probs3 = calculate_punzi(model, test_df, prob_range=[0.4, 0.98], dpoints=1000)

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

fonts = {'fontname':'Arial'}

ax.scatter(probs1, p1, s=2, label='Train Punzi')
ax.scatter(probs2, p2, s=2, label='Validation Punzi')
ax.scatter(probs3, p3, s=2, label='Test Punzi')

plt.ylabel('Punzi FOM Value', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability Cut Value', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.legend(loc='upper left', ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/train_history/{version}_punzi_scan.png')
plt.show()

# %% [markdown]
# The probability cut value, $P$ says that for $P_{pred}\lt P$ it is classed as background and if it is above then it is classed as signal. This means that for very high values of $P$ we have a very high purity sample but end up throwing away most events. Conversely a low value means we keep most data at the sacrifice of more background events leaking through.
