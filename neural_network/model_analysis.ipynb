# %% [markdown]
# # Model Analysis
# Here we test different datasets made and see if they have features with stronger discriminating power. That is, the neural network can distinguish better between them. This can be a little unstable due to the nature of neural networks.

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import callbacks, layers, Sequential
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import sys
sys.path.append('../')
from dataflow import Flow

# %%
version = "6.0.4"
fname = f'../data_files/{version}'

# %% [markdown]
# ## Define the Model and get Data

# %%
data = Flow(None, None, None, csv_path=f'{fname}.csv')
df = data.get_combined_data()

# %%
custom_callbacks = [
    callbacks.EarlyStopping(patience=20, min_delta=0.0005, restore_best_weights=True), 
    callbacks.ReduceLROnPlateau(patience=5, factor=0.2, min_lr=0.001)
    ]

def compile_model(input_shape):
    model = Sequential([
        layers.Dense(16, activation='relu', input_shape=input_shape, kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['binary_accuracy', 'AUC', 'TruePositives', 'TrueNegatives', 'FalsePositives', 'FalseNegatives'])
    
    return model

# %%
def plot_history_curves(history, epochs, model_version='No version', savefig='', off=False):
    if type(history) != dict:
        history = history.history
    
    loss = history['loss']
    val_loss = history['val_loss']
    accuracy = history['binary_accuracy']
    val_accuracy = history['val_binary_accuracy']
    auc = history['auc']
    val_auc = history['val_auc']
    epoch_range = range(1, epochs+1, 1)    

    fig, ax = plt.subplots(1, 3, figsize=(22, 6))
    
    ax[0].xaxis.set_minor_locator(AutoMinorLocator())
    ax[0].yaxis.set_minor_locator(AutoMinorLocator())
    ax[1].xaxis.set_minor_locator(AutoMinorLocator())
    ax[1].yaxis.set_minor_locator(AutoMinorLocator())
    ax[2].xaxis.set_minor_locator(AutoMinorLocator())
    ax[2].yaxis.set_minor_locator(AutoMinorLocator())
    fonts = {'fontname':'Arial'}
    
    ax[0].plot(epoch_range, loss, 'r.', label='Training Loss')
    ax[0].plot(epoch_range, val_loss, 'b.', label='Validation Loss')
    ax[1].plot(epoch_range, accuracy, 'r.', label='Training Accuracy')
    ax[1].plot(epoch_range, val_accuracy, 'b.', label='Validation Accuracy')
    ax[2].plot(epoch_range, auc, 'r.', label='Training AUC')
    ax[2].plot(epoch_range, val_auc, 'b.', label='Validation AUC')
    
    
    ax[0].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[0].set_ylabel('Loss', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[1].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[1].set_ylabel('Accuracy', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[2].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[2].set_ylabel('AUC', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[0].legend(loc='upper right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[1].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[2].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    
    plt.title(model_version)
    if savefig != '':
        plt.savefig(savefig)
    if not off:
        plt.show()

def plot_history(model_version, savefig='', off=False):
    history = pickle.load(open(f'train_history/v{model_version}', "rb"))
    nepochs = len(history['loss'])
    plot_history_curves(history, nepochs, model_version, savefig, off)

# %%
def fit_model(model, train_data, val_data, model_version, callbacks=None, epochs=100, batch_size=512):
    model_history = model.fit(train_data[0], train_data[1], epochs=epochs, batch_size=batch_size, validation_data=val_data, callbacks=callbacks, verbose=1)
    with open(f'train_history/v{model_version}', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)
    model.save(f'models/v{model_version}')

# %%
def roc_curve(history, y_train, y_val, mversion='No Version', savefig=False, off=False, excl_epochs=0):
    train_signal_eff = history['true_positives']/y_train.value_counts()[1]
    val_signal_eff = history['val_true_positives']/y_val.value_counts()[1]
    # What percentage of total signal events were identified as signal events

    train_background_rej = 1 - (history['false_positives'] / y_train.value_counts()[0])
    val_background_rej = 1 - (history['val_false_positives'] / y_val.value_counts()[0])
    # The number of true positives to total positives
    
    train_background_rej, val_background_rej = train_background_rej[excl_epochs:], val_background_rej[excl_epochs:]
    train_signal_eff, val_signal_eff = train_signal_eff[excl_epochs:], val_signal_eff[excl_epochs:]
    
    fig, ax = plt.subplots(1, 1, figsize=(7, 5))
    ax.scatter(train_signal_eff, train_background_rej,  label='Training', s=2)
    ax.scatter(val_signal_eff, val_background_rej, label='Validation', s=2)
    ax.set_ylabel('Background Rejection (1 - False Positive Rate)')
    ax.set_xlabel('Signal Efficiency (True Positive Rate)')
    plt.title(f'Model {mversion}')
    plt.legend()
    if savefig != False:
        plt.savefig(savefig)
    if not off:
        plt.show()

# %%
def run_all(data, version):
    # Give it a list of data objects
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()
    model = compile_model((X_train.shape[1],))
    fit_model(model, (X_train, y_train), (X_val, y_val), f'{version}', callbacks=custom_callbacks)
    plot_history(f'{version}', f'../images/NeuralNetwork/train_history/{version}.png', off=True)
    history = pickle.load(open(f'train_history/v{version}', "rb"))
    roc_curve(history, y_train, y_val, mversion=f'{version}', savefig=f'../images/NeuralNetwork/train_history/{version}_roc.png', off=True, excl_epochs=5)
    # Dont plot the first 5 epochs they are dumb

# %%
run_all(data, version)
# Out:
# 2022-03-04 16:10:34.991618: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-04 16:10:35.000450: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-03-04 16:10:35.958167: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-04 16:10:35.994734: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2400145000 Hz
# Epoch 1/100
# 43/43 [==============================] - 5s 33ms/step - loss: 1.0526 - binary_accuracy: 0.7287 - auc: 0.8039 - true_positives: 8290.0000 - true_negatives: 7619.0000 - false_positives: 3292.0000 - false_negatives: 2631.0000 - val_loss: 0.9733 - val_binary_accuracy: 0.8354 - val_auc: 0.9461 - val_true_positives: 2638.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 1014.0000
# Epoch 2/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.8054 - binary_accuracy: 0.8533 - auc: 0.9252 - true_positives: 9631.0000 - true_negatives: 8999.0000 - false_positives: 1912.0000 - false_negatives: 1290.0000 - val_loss: 0.7983 - val_binary_accuracy: 0.8974 - val_auc: 0.9678 - val_true_positives: 3128.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 524.0000
# Epoch 3/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.6996 - binary_accuracy: 0.8836 - auc: 0.9474 - true_positives: 9793.0000 - true_negatives: 9497.0000 - false_positives: 1414.0000 - false_negatives: 1128.0000 - val_loss: 0.6679 - val_binary_accuracy: 0.9147 - val_auc: 0.9730 - val_true_positives: 3296.0000 - val_true_negatives: 3361.0000 - val_false_positives: 265.0000 - val_false_negatives: 356.0000
# Epoch 4/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.6181 - binary_accuracy: 0.8977 - auc: 0.9576 - true_positives: 9903.0000 - true_negatives: 9696.0000 - false_positives: 1215.0000 - false_negatives: 1018.0000 - val_loss: 0.5827 - val_binary_accuracy: 0.9189 - val_auc: 0.9757 - val_true_positives: 3313.0000 - val_true_negatives: 3375.0000 - val_false_positives: 251.0000 - val_false_negatives: 339.0000
# Epoch 5/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.5564 - binary_accuracy: 0.9032 - auc: 0.9624 - true_positives: 9936.0000 - true_negatives: 9783.0000 - false_positives: 1128.0000 - false_negatives: 985.0000 - val_loss: 0.5138 - val_binary_accuracy: 0.9237 - val_auc: 0.9775 - val_true_positives: 3360.0000 - val_true_negatives: 3363.0000 - val_false_positives: 263.0000 - val_false_negatives: 292.0000
# Epoch 6/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.5040 - binary_accuracy: 0.9091 - auc: 0.9658 - true_positives: 9962.0000 - true_negatives: 9886.0000 - false_positives: 1025.0000 - false_negatives: 959.0000 - val_loss: 0.4689 - val_binary_accuracy: 0.9243 - val_auc: 0.9785 - val_true_positives: 3330.0000 - val_true_negatives: 3397.0000 - val_false_positives: 229.0000 - val_false_negatives: 322.0000
# Epoch 7/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.4588 - binary_accuracy: 0.9143 - auc: 0.9686 - true_positives: 10025.0000 - true_negatives: 9937.0000 - false_positives: 974.0000 - false_negatives: 896.0000 - val_loss: 0.4307 - val_binary_accuracy: 0.9243 - val_auc: 0.9794 - val_true_positives: 3320.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 332.0000
# Epoch 8/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.4208 - binary_accuracy: 0.9160 - auc: 0.9705 - true_positives: 10020.0000 - true_negatives: 9979.0000 - false_positives: 932.0000 - false_negatives: 901.0000 - val_loss: 0.4105 - val_binary_accuracy: 0.9254 - val_auc: 0.9801 - val_true_positives: 3295.0000 - val_true_negatives: 3440.0000 - val_false_positives: 186.0000 - val_false_negatives: 357.0000
# Epoch 9/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.3921 - binary_accuracy: 0.9161 - auc: 0.9713 - true_positives: 10030.0000 - true_negatives: 9970.0000 - false_positives: 941.0000 - false_negatives: 891.0000 - val_loss: 0.3741 - val_binary_accuracy: 0.9268 - val_auc: 0.9805 - val_true_positives: 3320.0000 - val_true_negatives: 3425.0000 - val_false_positives: 201.0000 - val_false_negatives: 332.0000
# Epoch 10/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.3661 - binary_accuracy: 0.9171 - auc: 0.9721 - true_positives: 10039.0000 - true_negatives: 9984.0000 - false_positives: 927.0000 - false_negatives: 882.0000 - val_loss: 0.3614 - val_binary_accuracy: 0.9273 - val_auc: 0.9806 - val_true_positives: 3316.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 336.0000
# Epoch 11/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.3460 - binary_accuracy: 0.9199 - auc: 0.9725 - true_positives: 10060.0000 - true_negatives: 10023.0000 - false_positives: 888.0000 - false_negatives: 861.0000 - val_loss: 0.3396 - val_binary_accuracy: 0.9303 - val_auc: 0.9812 - val_true_positives: 3368.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 284.0000
# Epoch 12/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.3226 - binary_accuracy: 0.9234 - auc: 0.9744 - true_positives: 10105.0000 - true_negatives: 10054.0000 - false_positives: 857.0000 - false_negatives: 816.0000 - val_loss: 0.3342 - val_binary_accuracy: 0.9314 - val_auc: 0.9815 - val_true_positives: 3363.0000 - val_true_negatives: 3416.0000 - val_false_positives: 210.0000 - val_false_negatives: 289.0000
# Epoch 13/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.3082 - binary_accuracy: 0.9235 - auc: 0.9749 - true_positives: 10104.0000 - true_negatives: 10057.0000 - false_positives: 854.0000 - false_negatives: 817.0000 - val_loss: 0.3172 - val_binary_accuracy: 0.9318 - val_auc: 0.9819 - val_true_positives: 3398.0000 - val_true_negatives: 3384.0000 - val_false_positives: 242.0000 - val_false_negatives: 254.0000
# Epoch 14/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.3002 - binary_accuracy: 0.9214 - auc: 0.9741 - true_positives: 10088.0000 - true_negatives: 10029.0000 - false_positives: 882.0000 - false_negatives: 833.0000 - val_loss: 0.2954 - val_binary_accuracy: 0.9327 - val_auc: 0.9824 - val_true_positives: 3358.0000 - val_true_negatives: 3430.0000 - val_false_positives: 196.0000 - val_false_negatives: 294.0000
# Epoch 15/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2835 - binary_accuracy: 0.9251 - auc: 0.9760 - true_positives: 10111.0000 - true_negatives: 10085.0000 - false_positives: 826.0000 - false_negatives: 810.0000 - val_loss: 0.3071 - val_binary_accuracy: 0.9332 - val_auc: 0.9826 - val_true_positives: 3334.0000 - val_true_negatives: 3458.0000 - val_false_positives: 168.0000 - val_false_negatives: 318.0000
# Epoch 16/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2771 - binary_accuracy: 0.9230 - auc: 0.9756 - true_positives: 10080.0000 - true_negatives: 10071.0000 - false_positives: 840.0000 - false_negatives: 841.0000 - val_loss: 0.2760 - val_binary_accuracy: 0.9321 - val_auc: 0.9831 - val_true_positives: 3415.0000 - val_true_negatives: 3369.0000 - val_false_positives: 257.0000 - val_false_negatives: 237.0000
# Epoch 17/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2665 - binary_accuracy: 0.9258 - auc: 0.9766 - true_positives: 10130.0000 - true_negatives: 10083.0000 - false_positives: 828.0000 - false_negatives: 791.0000 - val_loss: 0.2601 - val_binary_accuracy: 0.9309 - val_auc: 0.9834 - val_true_positives: 3448.0000 - val_true_negatives: 3327.0000 - val_false_positives: 299.0000 - val_false_negatives: 204.0000
# Epoch 18/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2611 - binary_accuracy: 0.9255 - auc: 0.9765 - true_positives: 10121.0000 - true_negatives: 10085.0000 - false_positives: 826.0000 - false_negatives: 800.0000 - val_loss: 0.2788 - val_binary_accuracy: 0.9350 - val_auc: 0.9834 - val_true_positives: 3393.0000 - val_true_negatives: 3412.0000 - val_false_positives: 214.0000 - val_false_negatives: 259.0000
# Epoch 19/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2541 - binary_accuracy: 0.9261 - auc: 0.9770 - true_positives: 10127.0000 - true_negatives: 10091.0000 - false_positives: 820.0000 - false_negatives: 794.0000 - val_loss: 0.2464 - val_binary_accuracy: 0.9350 - val_auc: 0.9838 - val_true_positives: 3408.0000 - val_true_negatives: 3397.0000 - val_false_positives: 229.0000 - val_false_negatives: 244.0000
# Epoch 20/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2477 - binary_accuracy: 0.9257 - auc: 0.9775 - true_positives: 10136.0000 - true_negatives: 10073.0000 - false_positives: 838.0000 - false_negatives: 785.0000 - val_loss: 0.2438 - val_binary_accuracy: 0.9338 - val_auc: 0.9837 - val_true_positives: 3446.0000 - val_true_negatives: 3350.0000 - val_false_positives: 276.0000 - val_false_negatives: 206.0000
# Epoch 21/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2435 - binary_accuracy: 0.9274 - auc: 0.9775 - true_positives: 10153.0000 - true_negatives: 10095.0000 - false_positives: 816.0000 - false_negatives: 768.0000 - val_loss: 0.2281 - val_binary_accuracy: 0.9346 - val_auc: 0.9839 - val_true_positives: 3409.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 243.0000
# Epoch 22/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2397 - binary_accuracy: 0.9284 - auc: 0.9774 - true_positives: 10164.0000 - true_negatives: 10104.0000 - false_positives: 807.0000 - false_negatives: 757.0000 - val_loss: 0.2262 - val_binary_accuracy: 0.9358 - val_auc: 0.9840 - val_true_positives: 3412.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 240.0000
# Epoch 23/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2347 - binary_accuracy: 0.9269 - auc: 0.9781 - true_positives: 10160.0000 - true_negatives: 10077.0000 - false_positives: 834.0000 - false_negatives: 761.0000 - val_loss: 0.2220 - val_binary_accuracy: 0.9364 - val_auc: 0.9841 - val_true_positives: 3448.0000 - val_true_negatives: 3367.0000 - val_false_positives: 259.0000 - val_false_negatives: 204.0000
# Epoch 24/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2350 - binary_accuracy: 0.9261 - auc: 0.9776 - true_positives: 10116.0000 - true_negatives: 10103.0000 - false_positives: 808.0000 - false_negatives: 805.0000 - val_loss: 0.2161 - val_binary_accuracy: 0.9361 - val_auc: 0.9842 - val_true_positives: 3439.0000 - val_true_negatives: 3374.0000 - val_false_positives: 252.0000 - val_false_negatives: 213.0000
# Epoch 25/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.2301 - binary_accuracy: 0.9277 - auc: 0.9780 - true_positives: 10158.0000 - true_negatives: 10096.0000 - false_positives: 815.0000 - false_negatives: 763.0000 - val_loss: 0.2217 - val_binary_accuracy: 0.9342 - val_auc: 0.9844 - val_true_positives: 3483.0000 - val_true_negatives: 3316.0000 - val_false_positives: 310.0000 - val_false_negatives: 169.0000
# Epoch 26/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2257 - binary_accuracy: 0.9294 - auc: 0.9785 - true_positives: 10176.0000 - true_negatives: 10115.0000 - false_positives: 796.0000 - false_negatives: 745.0000 - val_loss: 0.2107 - val_binary_accuracy: 0.9354 - val_auc: 0.9843 - val_true_positives: 3422.0000 - val_true_negatives: 3386.0000 - val_false_positives: 240.0000 - val_false_negatives: 230.0000
# Epoch 27/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2245 - binary_accuracy: 0.9270 - auc: 0.9786 - true_positives: 10127.0000 - true_negatives: 10111.0000 - false_positives: 800.0000 - false_negatives: 794.0000 - val_loss: 0.2133 - val_binary_accuracy: 0.9360 - val_auc: 0.9841 - val_true_positives: 3501.0000 - val_true_negatives: 3311.0000 - val_false_positives: 315.0000 - val_false_negatives: 151.0000
# Epoch 28/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2222 - binary_accuracy: 0.9277 - auc: 0.9785 - true_positives: 10176.0000 - true_negatives: 10077.0000 - false_positives: 834.0000 - false_negatives: 745.0000 - val_loss: 0.2093 - val_binary_accuracy: 0.9358 - val_auc: 0.9842 - val_true_positives: 3389.0000 - val_true_negatives: 3422.0000 - val_false_positives: 204.0000 - val_false_negatives: 263.0000
# Epoch 29/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2210 - binary_accuracy: 0.9274 - auc: 0.9787 - true_positives: 10160.0000 - true_negatives: 10087.0000 - false_positives: 824.0000 - false_negatives: 761.0000 - val_loss: 0.2163 - val_binary_accuracy: 0.9361 - val_auc: 0.9846 - val_true_positives: 3452.0000 - val_true_negatives: 3361.0000 - val_false_positives: 265.0000 - val_false_negatives: 200.0000
# Epoch 30/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2170 - binary_accuracy: 0.9303 - auc: 0.9790 - true_positives: 10205.0000 - true_negatives: 10106.0000 - false_positives: 805.0000 - false_negatives: 716.0000 - val_loss: 0.2048 - val_binary_accuracy: 0.9367 - val_auc: 0.9847 - val_true_positives: 3397.0000 - val_true_negatives: 3420.0000 - val_false_positives: 206.0000 - val_false_negatives: 255.0000
# Epoch 31/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2145 - binary_accuracy: 0.9299 - auc: 0.9793 - true_positives: 10179.0000 - true_negatives: 10122.0000 - false_positives: 789.0000 - false_negatives: 742.0000 - val_loss: 0.1982 - val_binary_accuracy: 0.9365 - val_auc: 0.9848 - val_true_positives: 3410.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 242.0000
# Epoch 32/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2153 - binary_accuracy: 0.9285 - auc: 0.9789 - true_positives: 10166.0000 - true_negatives: 10105.0000 - false_positives: 806.0000 - false_negatives: 755.0000 - val_loss: 0.2009 - val_binary_accuracy: 0.9349 - val_auc: 0.9851 - val_true_positives: 3487.0000 - val_true_negatives: 3317.0000 - val_false_positives: 309.0000 - val_false_negatives: 165.0000
# Epoch 33/100
# 43/43 [==============================] - 1s 12ms/step - loss: 0.2112 - binary_accuracy: 0.9296 - auc: 0.9797 - true_positives: 10189.0000 - true_negatives: 10107.0000 - false_positives: 804.0000 - false_negatives: 732.0000 - val_loss: 0.1915 - val_binary_accuracy: 0.9376 - val_auc: 0.9850 - val_true_positives: 3430.0000 - val_true_negatives: 3394.0000 - val_false_positives: 232.0000 - val_false_negatives: 222.0000
# Epoch 34/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.2110 - binary_accuracy: 0.9301 - auc: 0.9795 - true_positives: 10171.0000 - true_negatives: 10135.0000 - false_positives: 776.0000 - false_negatives: 750.0000 - val_loss: 0.1881 - val_binary_accuracy: 0.9373 - val_auc: 0.9850 - val_true_positives: 3408.0000 - val_true_negatives: 3414.0000 - val_false_positives: 212.0000 - val_false_negatives: 244.0000
# Epoch 35/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.2122 - binary_accuracy: 0.9280 - auc: 0.9790 - true_positives: 10166.0000 - true_negatives: 10094.0000 - false_positives: 817.0000 - false_negatives: 755.0000 - val_loss: 0.1955 - val_binary_accuracy: 0.9373 - val_auc: 0.9845 - val_true_positives: 3373.0000 - val_true_negatives: 3449.0000 - val_false_positives: 177.0000 - val_false_negatives: 279.0000
# Epoch 36/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2082 - binary_accuracy: 0.9289 - auc: 0.9797 - true_positives: 10185.0000 - true_negatives: 10095.0000 - false_positives: 816.0000 - false_negatives: 736.0000 - val_loss: 0.2084 - val_binary_accuracy: 0.9383 - val_auc: 0.9848 - val_true_positives: 3458.0000 - val_true_negatives: 3371.0000 - val_false_positives: 255.0000 - val_false_negatives: 194.0000
# Epoch 37/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2078 - binary_accuracy: 0.9299 - auc: 0.9797 - true_positives: 10179.0000 - true_negatives: 10123.0000 - false_positives: 788.0000 - false_negatives: 742.0000 - val_loss: 0.1868 - val_binary_accuracy: 0.9379 - val_auc: 0.9852 - val_true_positives: 3363.0000 - val_true_negatives: 3463.0000 - val_false_positives: 163.0000 - val_false_negatives: 289.0000
# Epoch 38/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2088 - binary_accuracy: 0.9293 - auc: 0.9793 - true_positives: 10174.0000 - true_negatives: 10114.0000 - false_positives: 797.0000 - false_negatives: 747.0000 - val_loss: 0.1951 - val_binary_accuracy: 0.9351 - val_auc: 0.9842 - val_true_positives: 3407.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 245.0000
# Epoch 39/100
# 43/43 [==============================] - 1s 23ms/step - loss: 0.2063 - binary_accuracy: 0.9299 - auc: 0.9798 - true_positives: 10178.0000 - true_negatives: 10123.0000 - false_positives: 788.0000 - false_negatives: 743.0000 - val_loss: 0.1877 - val_binary_accuracy: 0.9390 - val_auc: 0.9850 - val_true_positives: 3400.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 252.0000
# Epoch 40/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2082 - binary_accuracy: 0.9301 - auc: 0.9792 - true_positives: 10195.0000 - true_negatives: 10111.0000 - false_positives: 800.0000 - false_negatives: 726.0000 - val_loss: 0.1839 - val_binary_accuracy: 0.9393 - val_auc: 0.9852 - val_true_positives: 3437.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 215.0000
# Epoch 41/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2030 - binary_accuracy: 0.9321 - auc: 0.9803 - true_positives: 10200.0000 - true_negatives: 10149.0000 - false_positives: 762.0000 - false_negatives: 721.0000 - val_loss: 0.1825 - val_binary_accuracy: 0.9386 - val_auc: 0.9851 - val_true_positives: 3430.0000 - val_true_negatives: 3401.0000 - val_false_positives: 225.0000 - val_false_negatives: 222.0000
# Epoch 42/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2024 - binary_accuracy: 0.9311 - auc: 0.9802 - true_positives: 10183.0000 - true_negatives: 10144.0000 - false_positives: 767.0000 - false_negatives: 738.0000 - val_loss: 0.1799 - val_binary_accuracy: 0.9376 - val_auc: 0.9858 - val_true_positives: 3435.0000 - val_true_negatives: 3389.0000 - val_false_positives: 237.0000 - val_false_negatives: 217.0000
# Epoch 43/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2003 - binary_accuracy: 0.9317 - auc: 0.9806 - true_positives: 10208.0000 - true_negatives: 10132.0000 - false_positives: 779.0000 - false_negatives: 713.0000 - val_loss: 0.1823 - val_binary_accuracy: 0.9380 - val_auc: 0.9850 - val_true_positives: 3450.0000 - val_true_negatives: 3377.0000 - val_false_positives: 249.0000 - val_false_negatives: 202.0000
# Epoch 44/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1996 - binary_accuracy: 0.9318 - auc: 0.9805 - true_positives: 10214.0000 - true_negatives: 10128.0000 - false_positives: 783.0000 - false_negatives: 707.0000 - val_loss: 0.1821 - val_binary_accuracy: 0.9387 - val_auc: 0.9850 - val_true_positives: 3447.0000 - val_true_negatives: 3385.0000 - val_false_positives: 241.0000 - val_false_negatives: 205.0000
# Epoch 45/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2009 - binary_accuracy: 0.9302 - auc: 0.9803 - true_positives: 10185.0000 - true_negatives: 10123.0000 - false_positives: 788.0000 - false_negatives: 736.0000 - val_loss: 0.1777 - val_binary_accuracy: 0.9395 - val_auc: 0.9855 - val_true_positives: 3397.0000 - val_true_negatives: 3441.0000 - val_false_positives: 185.0000 - val_false_negatives: 255.0000
# Epoch 46/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1962 - binary_accuracy: 0.9324 - auc: 0.9812 - true_positives: 10203.0000 - true_negatives: 10154.0000 - false_positives: 757.0000 - false_negatives: 718.0000 - val_loss: 0.1754 - val_binary_accuracy: 0.9398 - val_auc: 0.9856 - val_true_positives: 3437.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 215.0000
# Epoch 47/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2003 - binary_accuracy: 0.9321 - auc: 0.9802 - true_positives: 10200.0000 - true_negatives: 10149.0000 - false_positives: 762.0000 - false_negatives: 721.0000 - val_loss: 0.1763 - val_binary_accuracy: 0.9405 - val_auc: 0.9856 - val_true_positives: 3396.0000 - val_true_negatives: 3449.0000 - val_false_positives: 177.0000 - val_false_negatives: 256.0000
# Epoch 48/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1997 - binary_accuracy: 0.9307 - auc: 0.9804 - true_positives: 10180.0000 - true_negatives: 10140.0000 - false_positives: 771.0000 - false_negatives: 741.0000 - val_loss: 0.1781 - val_binary_accuracy: 0.9411 - val_auc: 0.9862 - val_true_positives: 3411.0000 - val_true_negatives: 3438.0000 - val_false_positives: 188.0000 - val_false_negatives: 241.0000
# Epoch 49/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1989 - binary_accuracy: 0.9308 - auc: 0.9804 - true_positives: 10182.0000 - true_negatives: 10140.0000 - false_positives: 771.0000 - false_negatives: 739.0000 - val_loss: 0.1762 - val_binary_accuracy: 0.9391 - val_auc: 0.9856 - val_true_positives: 3400.0000 - val_true_negatives: 3435.0000 - val_false_positives: 191.0000 - val_false_negatives: 252.0000
# Epoch 50/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1968 - binary_accuracy: 0.9324 - auc: 0.9807 - true_positives: 10200.0000 - true_negatives: 10156.0000 - false_positives: 755.0000 - false_negatives: 721.0000 - val_loss: 0.1738 - val_binary_accuracy: 0.9391 - val_auc: 0.9860 - val_true_positives: 3458.0000 - val_true_negatives: 3377.0000 - val_false_positives: 249.0000 - val_false_negatives: 194.0000
# Epoch 51/100
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1973 - binary_accuracy: 0.9328 - auc: 0.9807 - true_positives: 10242.0000 - true_negatives: 10123.0000 - false_positives: 788.0000 - false_negatives: 679.0000 - val_loss: 0.1728 - val_binary_accuracy: 0.9401 - val_auc: 0.9859 - val_true_positives: 3445.0000 - val_true_negatives: 3397.0000 - val_false_positives: 229.0000 - val_false_negatives: 207.0000
# Epoch 52/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1976 - binary_accuracy: 0.9304 - auc: 0.9805 - true_positives: 10194.0000 - true_negatives: 10118.0000 - false_positives: 793.0000 - false_negatives: 727.0000 - val_loss: 0.1719 - val_binary_accuracy: 0.9406 - val_auc: 0.9858 - val_true_positives: 3433.0000 - val_true_negatives: 3413.0000 - val_false_positives: 213.0000 - val_false_negatives: 219.0000
# Epoch 53/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1969 - binary_accuracy: 0.9331 - auc: 0.9806 - true_positives: 10200.0000 - true_negatives: 10171.0000 - false_positives: 740.0000 - false_negatives: 721.0000 - val_loss: 0.1748 - val_binary_accuracy: 0.9380 - val_auc: 0.9858 - val_true_positives: 3478.0000 - val_true_negatives: 3349.0000 - val_false_positives: 277.0000 - val_false_negatives: 174.0000
# Epoch 54/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1966 - binary_accuracy: 0.9324 - auc: 0.9806 - true_positives: 10210.0000 - true_negatives: 10146.0000 - false_positives: 765.0000 - false_negatives: 711.0000 - val_loss: 0.1783 - val_binary_accuracy: 0.9401 - val_auc: 0.9858 - val_true_positives: 3456.0000 - val_true_negatives: 3386.0000 - val_false_positives: 240.0000 - val_false_negatives: 196.0000
# Epoch 55/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1943 - binary_accuracy: 0.9326 - auc: 0.9811 - true_positives: 10217.0000 - true_negatives: 10143.0000 - false_positives: 768.0000 - false_negatives: 704.0000 - val_loss: 0.1752 - val_binary_accuracy: 0.9391 - val_auc: 0.9855 - val_true_positives: 3398.0000 - val_true_negatives: 3437.0000 - val_false_positives: 189.0000 - val_false_negatives: 254.0000
# Epoch 56/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1970 - binary_accuracy: 0.9309 - auc: 0.9805 - true_positives: 10216.0000 - true_negatives: 10108.0000 - false_positives: 803.0000 - false_negatives: 705.0000 - val_loss: 0.1723 - val_binary_accuracy: 0.9424 - val_auc: 0.9862 - val_true_positives: 3420.0000 - val_true_negatives: 3439.0000 - val_false_positives: 187.0000 - val_false_negatives: 232.0000
# Epoch 57/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1952 - binary_accuracy: 0.9324 - auc: 0.9808 - true_positives: 10198.0000 - true_negatives: 10158.0000 - false_positives: 753.0000 - false_negatives: 723.0000 - val_loss: 0.1711 - val_binary_accuracy: 0.9404 - val_auc: 0.9862 - val_true_positives: 3390.0000 - val_true_negatives: 3454.0000 - val_false_positives: 172.0000 - val_false_negatives: 262.0000
# Epoch 58/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.1939 - binary_accuracy: 0.9328 - auc: 0.9811 - true_positives: 10215.0000 - true_negatives: 10149.0000 - false_positives: 762.0000 - false_negatives: 706.0000 - val_loss: 0.1772 - val_binary_accuracy: 0.9405 - val_auc: 0.9859 - val_true_positives: 3425.0000 - val_true_negatives: 3420.0000 - val_false_positives: 206.0000 - val_false_negatives: 227.0000
# Epoch 59/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1930 - binary_accuracy: 0.9340 - auc: 0.9813 - true_positives: 10212.0000 - true_negatives: 10179.0000 - false_positives: 732.0000 - false_negatives: 709.0000 - val_loss: 0.1743 - val_binary_accuracy: 0.9405 - val_auc: 0.9857 - val_true_positives: 3385.0000 - val_true_negatives: 3460.0000 - val_false_positives: 166.0000 - val_false_negatives: 267.0000
# Epoch 60/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1935 - binary_accuracy: 0.9323 - auc: 0.9813 - true_positives: 10174.0000 - true_negatives: 10179.0000 - false_positives: 732.0000 - false_negatives: 747.0000 - val_loss: 0.1740 - val_binary_accuracy: 0.9405 - val_auc: 0.9861 - val_true_positives: 3491.0000 - val_true_negatives: 3354.0000 - val_false_positives: 272.0000 - val_false_negatives: 161.0000
# Epoch 61/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1938 - binary_accuracy: 0.9329 - auc: 0.9810 - true_positives: 10202.0000 - true_negatives: 10165.0000 - false_positives: 746.0000 - false_negatives: 719.0000 - val_loss: 0.1780 - val_binary_accuracy: 0.9411 - val_auc: 0.9855 - val_true_positives: 3445.0000 - val_true_negatives: 3404.0000 - val_false_positives: 222.0000 - val_false_negatives: 207.0000
# Epoch 62/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1921 - binary_accuracy: 0.9343 - auc: 0.9814 - true_positives: 10218.0000 - true_negatives: 10180.0000 - false_positives: 731.0000 - false_negatives: 703.0000 - val_loss: 0.1681 - val_binary_accuracy: 0.9416 - val_auc: 0.9864 - val_true_positives: 3405.0000 - val_true_negatives: 3448.0000 - val_false_positives: 178.0000 - val_false_negatives: 247.0000
# Epoch 63/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1917 - binary_accuracy: 0.9335 - auc: 0.9815 - true_positives: 10201.0000 - true_negatives: 10180.0000 - false_positives: 731.0000 - false_negatives: 720.0000 - val_loss: 0.1767 - val_binary_accuracy: 0.9397 - val_auc: 0.9864 - val_true_positives: 3374.0000 - val_true_negatives: 3465.0000 - val_false_positives: 161.0000 - val_false_negatives: 278.0000
# Epoch 64/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1928 - binary_accuracy: 0.9330 - auc: 0.9812 - true_positives: 10215.0000 - true_negatives: 10154.0000 - false_positives: 757.0000 - false_negatives: 706.0000 - val_loss: 0.1683 - val_binary_accuracy: 0.9404 - val_auc: 0.9861 - val_true_positives: 3416.0000 - val_true_negatives: 3428.0000 - val_false_positives: 198.0000 - val_false_negatives: 236.0000
# Epoch 65/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1911 - binary_accuracy: 0.9333 - auc: 0.9816 - true_positives: 10203.0000 - true_negatives: 10173.0000 - false_positives: 738.0000 - false_negatives: 718.0000 - val_loss: 0.1668 - val_binary_accuracy: 0.9416 - val_auc: 0.9865 - val_true_positives: 3428.0000 - val_true_negatives: 3425.0000 - val_false_positives: 201.0000 - val_false_negatives: 224.0000
# Epoch 66/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1927 - binary_accuracy: 0.9345 - auc: 0.9811 - true_positives: 10214.0000 - true_negatives: 10187.0000 - false_positives: 724.0000 - false_negatives: 707.0000 - val_loss: 0.1707 - val_binary_accuracy: 0.9393 - val_auc: 0.9858 - val_true_positives: 3454.0000 - val_true_negatives: 3382.0000 - val_false_positives: 244.0000 - val_false_negatives: 198.0000
# Epoch 67/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1910 - binary_accuracy: 0.9329 - auc: 0.9814 - true_positives: 10198.0000 - true_negatives: 10169.0000 - false_positives: 742.0000 - false_negatives: 723.0000 - val_loss: 0.1679 - val_binary_accuracy: 0.9406 - val_auc: 0.9861 - val_true_positives: 3446.0000 - val_true_negatives: 3400.0000 - val_false_positives: 226.0000 - val_false_negatives: 206.0000
# Epoch 68/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1909 - binary_accuracy: 0.9338 - auc: 0.9815 - true_positives: 10210.0000 - true_negatives: 10176.0000 - false_positives: 735.0000 - false_negatives: 711.0000 - val_loss: 0.1710 - val_binary_accuracy: 0.9427 - val_auc: 0.9860 - val_true_positives: 3403.0000 - val_true_negatives: 3458.0000 - val_false_positives: 168.0000 - val_false_negatives: 249.0000
# Epoch 69/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1919 - binary_accuracy: 0.9324 - auc: 0.9813 - true_positives: 10154.0000 - true_negatives: 10203.0000 - false_positives: 708.0000 - false_negatives: 767.0000 - val_loss: 0.1680 - val_binary_accuracy: 0.9405 - val_auc: 0.9864 - val_true_positives: 3469.0000 - val_true_negatives: 3376.0000 - val_false_positives: 250.0000 - val_false_negatives: 183.0000
# Epoch 70/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1914 - binary_accuracy: 0.9326 - auc: 0.9815 - true_positives: 10198.0000 - true_negatives: 10162.0000 - false_positives: 749.0000 - false_negatives: 723.0000 - val_loss: 0.1730 - val_binary_accuracy: 0.9428 - val_auc: 0.9860 - val_true_positives: 3505.0000 - val_true_negatives: 3357.0000 - val_false_positives: 269.0000 - val_false_negatives: 147.0000
# Epoch 71/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1905 - binary_accuracy: 0.9340 - auc: 0.9816 - true_positives: 10206.0000 - true_negatives: 10186.0000 - false_positives: 725.0000 - false_negatives: 715.0000 - val_loss: 0.1671 - val_binary_accuracy: 0.9413 - val_auc: 0.9863 - val_true_positives: 3437.0000 - val_true_negatives: 3414.0000 - val_false_positives: 212.0000 - val_false_negatives: 215.0000
# Epoch 72/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1918 - binary_accuracy: 0.9334 - auc: 0.9813 - true_positives: 10214.0000 - true_negatives: 10164.0000 - false_positives: 747.0000 - false_negatives: 707.0000 - val_loss: 0.1710 - val_binary_accuracy: 0.9412 - val_auc: 0.9859 - val_true_positives: 3473.0000 - val_true_negatives: 3377.0000 - val_false_positives: 249.0000 - val_false_negatives: 179.0000
# Epoch 73/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1941 - binary_accuracy: 0.9321 - auc: 0.9805 - true_positives: 10177.0000 - true_negatives: 10173.0000 - false_positives: 738.0000 - false_negatives: 744.0000 - val_loss: 0.1688 - val_binary_accuracy: 0.9408 - val_auc: 0.9859 - val_true_positives: 3436.0000 - val_true_negatives: 3411.0000 - val_false_positives: 215.0000 - val_false_negatives: 216.0000
# Epoch 74/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1915 - binary_accuracy: 0.9322 - auc: 0.9813 - true_positives: 10188.0000 - true_negatives: 10163.0000 - false_positives: 748.0000 - false_negatives: 733.0000 - val_loss: 0.1663 - val_binary_accuracy: 0.9424 - val_auc: 0.9863 - val_true_positives: 3439.0000 - val_true_negatives: 3420.0000 - val_false_positives: 206.0000 - val_false_negatives: 213.0000
# Epoch 75/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1925 - binary_accuracy: 0.9329 - auc: 0.9810 - true_positives: 10173.0000 - true_negatives: 10193.0000 - false_positives: 718.0000 - false_negatives: 748.0000 - val_loss: 0.1726 - val_binary_accuracy: 0.9395 - val_auc: 0.9859 - val_true_positives: 3512.0000 - val_true_negatives: 3326.0000 - val_false_positives: 300.0000 - val_false_negatives: 140.0000
# Epoch 76/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1915 - binary_accuracy: 0.9336 - auc: 0.9811 - true_positives: 10199.0000 - true_negatives: 10184.0000 - false_positives: 727.0000 - false_negatives: 722.0000 - val_loss: 0.1687 - val_binary_accuracy: 0.9404 - val_auc: 0.9859 - val_true_positives: 3431.0000 - val_true_negatives: 3413.0000 - val_false_positives: 213.0000 - val_false_negatives: 221.0000
# Epoch 77/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1926 - binary_accuracy: 0.9335 - auc: 0.9809 - true_positives: 10206.0000 - true_negatives: 10174.0000 - false_positives: 737.0000 - false_negatives: 715.0000 - val_loss: 0.1740 - val_binary_accuracy: 0.9413 - val_auc: 0.9859 - val_true_positives: 3383.0000 - val_true_negatives: 3468.0000 - val_false_positives: 158.0000 - val_false_negatives: 269.0000
# Epoch 78/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1910 - binary_accuracy: 0.9337 - auc: 0.9811 - true_positives: 10222.0000 - true_negatives: 10163.0000 - false_positives: 748.0000 - false_negatives: 699.0000 - val_loss: 0.1669 - val_binary_accuracy: 0.9412 - val_auc: 0.9862 - val_true_positives: 3451.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 201.0000
# Epoch 79/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1890 - binary_accuracy: 0.9330 - auc: 0.9816 - true_positives: 10217.0000 - true_negatives: 10153.0000 - false_positives: 758.0000 - false_negatives: 704.0000 - val_loss: 0.1681 - val_binary_accuracy: 0.9422 - val_auc: 0.9859 - val_true_positives: 3464.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 188.0000
# Epoch 80/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1900 - binary_accuracy: 0.9346 - auc: 0.9815 - true_positives: 10227.0000 - true_negatives: 10178.0000 - false_positives: 733.0000 - false_negatives: 694.0000 - val_loss: 0.1718 - val_binary_accuracy: 0.9400 - val_auc: 0.9854 - val_true_positives: 3429.0000 - val_true_negatives: 3412.0000 - val_false_positives: 214.0000 - val_false_negatives: 223.0000
# Epoch 81/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1950 - binary_accuracy: 0.9304 - auc: 0.9805 - true_positives: 10168.0000 - true_negatives: 10144.0000 - false_positives: 767.0000 - false_negatives: 753.0000 - val_loss: 0.1718 - val_binary_accuracy: 0.9394 - val_auc: 0.9859 - val_true_positives: 3503.0000 - val_true_negatives: 3334.0000 - val_false_positives: 292.0000 - val_false_negatives: 149.0000
# Epoch 82/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1882 - binary_accuracy: 0.9345 - auc: 0.9818 - true_positives: 10217.0000 - true_negatives: 10185.0000 - false_positives: 726.0000 - false_negatives: 704.0000 - val_loss: 0.1664 - val_binary_accuracy: 0.9417 - val_auc: 0.9864 - val_true_positives: 3452.0000 - val_true_negatives: 3402.0000 - val_false_positives: 224.0000 - val_false_negatives: 200.0000
# Epoch 83/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1923 - binary_accuracy: 0.9316 - auc: 0.9810 - true_positives: 10191.0000 - true_negatives: 10147.0000 - false_positives: 764.0000 - false_negatives: 730.0000 - val_loss: 0.1676 - val_binary_accuracy: 0.9408 - val_auc: 0.9861 - val_true_positives: 3442.0000 - val_true_negatives: 3405.0000 - val_false_positives: 221.0000 - val_false_negatives: 210.0000
# Epoch 84/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1903 - binary_accuracy: 0.9335 - auc: 0.9814 - true_positives: 10215.0000 - true_negatives: 10165.0000 - false_positives: 746.0000 - false_negatives: 706.0000 - val_loss: 0.1694 - val_binary_accuracy: 0.9424 - val_auc: 0.9864 - val_true_positives: 3428.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 224.0000
# Epoch 85/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1888 - binary_accuracy: 0.9342 - auc: 0.9817 - true_positives: 10202.0000 - true_negatives: 10193.0000 - false_positives: 718.0000 - false_negatives: 719.0000 - val_loss: 0.1692 - val_binary_accuracy: 0.9428 - val_auc: 0.9860 - val_true_positives: 3489.0000 - val_true_negatives: 3373.0000 - val_false_positives: 253.0000 - val_false_negatives: 163.0000
# Epoch 86/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1918 - binary_accuracy: 0.9331 - auc: 0.9809 - true_positives: 10220.0000 - true_negatives: 10152.0000 - false_positives: 759.0000 - false_negatives: 701.0000 - val_loss: 0.1694 - val_binary_accuracy: 0.9420 - val_auc: 0.9864 - val_true_positives: 3414.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 238.0000
# Epoch 87/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1921 - binary_accuracy: 0.9337 - auc: 0.9808 - true_positives: 10212.0000 - true_negatives: 10172.0000 - false_positives: 739.0000 - false_negatives: 709.0000 - val_loss: 0.1728 - val_binary_accuracy: 0.9391 - val_auc: 0.9852 - val_true_positives: 3431.0000 - val_true_negatives: 3404.0000 - val_false_positives: 222.0000 - val_false_negatives: 221.0000
# Epoch 88/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1911 - binary_accuracy: 0.9334 - auc: 0.9812 - true_positives: 10196.0000 - true_negatives: 10182.0000 - false_positives: 729.0000 - false_negatives: 725.0000 - val_loss: 0.1642 - val_binary_accuracy: 0.9428 - val_auc: 0.9866 - val_true_positives: 3414.0000 - val_true_negatives: 3448.0000 - val_false_positives: 178.0000 - val_false_negatives: 238.0000
# Epoch 89/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1897 - binary_accuracy: 0.9331 - auc: 0.9814 - true_positives: 10186.0000 - true_negatives: 10186.0000 - false_positives: 725.0000 - false_negatives: 735.0000 - val_loss: 0.1676 - val_binary_accuracy: 0.9424 - val_auc: 0.9860 - val_true_positives: 3443.0000 - val_true_negatives: 3416.0000 - val_false_positives: 210.0000 - val_false_negatives: 209.0000
# Epoch 90/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1894 - binary_accuracy: 0.9342 - auc: 0.9816 - true_positives: 10219.0000 - true_negatives: 10176.0000 - false_positives: 735.0000 - false_negatives: 702.0000 - val_loss: 0.1778 - val_binary_accuracy: 0.9398 - val_auc: 0.9859 - val_true_positives: 3349.0000 - val_true_negatives: 3491.0000 - val_false_positives: 135.0000 - val_false_negatives: 303.0000
# Epoch 91/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1896 - binary_accuracy: 0.9335 - auc: 0.9814 - true_positives: 10194.0000 - true_negatives: 10187.0000 - false_positives: 724.0000 - false_negatives: 727.0000 - val_loss: 0.1669 - val_binary_accuracy: 0.9431 - val_auc: 0.9863 - val_true_positives: 3453.0000 - val_true_negatives: 3411.0000 - val_false_positives: 215.0000 - val_false_negatives: 199.0000
# Epoch 92/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1895 - binary_accuracy: 0.9332 - auc: 0.9814 - true_positives: 10206.0000 - true_negatives: 10167.0000 - false_positives: 744.0000 - false_negatives: 715.0000 - val_loss: 0.1669 - val_binary_accuracy: 0.9412 - val_auc: 0.9862 - val_true_positives: 3427.0000 - val_true_negatives: 3423.0000 - val_false_positives: 203.0000 - val_false_negatives: 225.0000
# Epoch 93/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1886 - binary_accuracy: 0.9338 - auc: 0.9816 - true_positives: 10186.0000 - true_negatives: 10201.0000 - false_positives: 710.0000 - false_negatives: 735.0000 - val_loss: 0.1865 - val_binary_accuracy: 0.9371 - val_auc: 0.9855 - val_true_positives: 3372.0000 - val_true_negatives: 3448.0000 - val_false_positives: 178.0000 - val_false_negatives: 280.0000
# Epoch 94/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1882 - binary_accuracy: 0.9340 - auc: 0.9816 - true_positives: 10209.0000 - true_negatives: 10183.0000 - false_positives: 728.0000 - false_negatives: 712.0000 - val_loss: 0.1672 - val_binary_accuracy: 0.9415 - val_auc: 0.9862 - val_true_positives: 3446.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 206.0000
# Epoch 95/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1888 - binary_accuracy: 0.9331 - auc: 0.9815 - true_positives: 10214.0000 - true_negatives: 10157.0000 - false_positives: 754.0000 - false_negatives: 707.0000 - val_loss: 0.1686 - val_binary_accuracy: 0.9404 - val_auc: 0.9859 - val_true_positives: 3431.0000 - val_true_negatives: 3413.0000 - val_false_positives: 213.0000 - val_false_negatives: 221.0000
# Epoch 96/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1909 - binary_accuracy: 0.9340 - auc: 0.9813 - true_positives: 10223.0000 - true_negatives: 10168.0000 - false_positives: 743.0000 - false_negatives: 698.0000 - val_loss: 0.1664 - val_binary_accuracy: 0.9412 - val_auc: 0.9861 - val_true_positives: 3443.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 209.0000
# Epoch 97/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1908 - binary_accuracy: 0.9347 - auc: 0.9810 - true_positives: 10220.0000 - true_negatives: 10186.0000 - false_positives: 725.0000 - false_negatives: 701.0000 - val_loss: 0.1741 - val_binary_accuracy: 0.9378 - val_auc: 0.9859 - val_true_positives: 3329.0000 - val_true_negatives: 3496.0000 - val_false_positives: 130.0000 - val_false_negatives: 323.0000
# Epoch 98/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1890 - binary_accuracy: 0.9347 - auc: 0.9815 - true_positives: 10191.0000 - true_negatives: 10216.0000 - false_positives: 695.0000 - false_negatives: 730.0000 - val_loss: 0.1699 - val_binary_accuracy: 0.9420 - val_auc: 0.9864 - val_true_positives: 3428.0000 - val_true_negatives: 3428.0000 - val_false_positives: 198.0000 - val_false_negatives: 224.0000
# Epoch 99/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1881 - binary_accuracy: 0.9344 - auc: 0.9816 - true_positives: 10204.0000 - true_negatives: 10195.0000 - false_positives: 716.0000 - false_negatives: 717.0000 - val_loss: 0.1705 - val_binary_accuracy: 0.9416 - val_auc: 0.9865 - val_true_positives: 3422.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 230.0000
# Epoch 100/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1893 - binary_accuracy: 0.9327 - auc: 0.9814 - true_positives: 10171.0000 - true_negatives: 10191.0000 - false_positives: 720.0000 - false_negatives: 750.0000 - val_loss: 0.1673 - val_binary_accuracy: 0.9415 - val_auc: 0.9862 - val_true_positives: 3442.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 210.0000
# 2022-03-04 16:12:01.738642: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/v6.0.4/assets

# %% [markdown]
# ## Plot Prediction Distribution
# Now we plot the distribution of the assigned probabilities across the train, validation and test data. Split colours via the dataset and solid or dashed being either signal or bakground.

# %%
model = tf.keras.models.load_model(f'models/v{version}')
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()

X_test_sig = X_test[y_test == 1]
X_test_bg = X_test[y_test == 0]

X_val_sig = X_val[y_val == 1]
X_val_bg = X_val[y_val == 0]

X_train_sig = X_train[y_train == 1]
X_train_bg = X_train[y_train == 0]

tests = model.predict(X_test_sig)
vals = model.predict(X_val_sig)
trains = model.predict(X_train_sig)
testb = model.predict(X_test_bg)
valb = model.predict(X_val_bg)
trainb = model.predict(X_train_bg)

# %%
sets = [(trainb, trains), (valb, vals), (testb, tests)]
bins = np.linspace(0, 1, 41)
bin_centres = 0.5*(bins[1:] + bins[:-1])
fonts = {'fontname':'Arial'}
labs = ['Train', 'Val', 'Test']
colors = ['b', '#f40000', '#008000']

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
fig.patch.set_facecolor('#FFFFFF')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
for i, set in enumerate(sets):

    ftb = ax.hist(set[0], bins=bins, histtype='step', label=f'{labs[i]} Bg.', density=True, color=colors[i], linewidth=2)[0]
    fts = ax.hist(set[1], bins=bins, histtype='step', label=f'{labs[i]} Sg.', density=True, linestyle='dashed', color=colors[i], linewidth=2)[0]

    ax.fill_between(bins[:-1], ftb-np.sqrt(ftb), ftb+np.sqrt(ftb), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')
    ax.fill_between(bins[:-1], fts-np.sqrt(fts), fts+np.sqrt(fts), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')

ax.set_ylim(bottom=0)
plt.ylabel('Normalised Frequency', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.title(f'Prob. Dist. (NN) for Model {version}')
plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.95), ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/prob_dists/{version}_prob_dist.png')
plt.show()

# %% [markdown]
# # Punzi FOM Scan
# Now we have a model which is producing a reasonable set of predictions that are fairly stable (hence the U-shaped graph) and are common for the training, validation and test features. As such we can now evaluate the Punzi FOM across the probability space to define where our cut point should be to maximise signal selection and background rejection efficiency.

# %%
def calculate_punzi(model, labelled_data, prob_range=[0.3, 0.9], dpoints=150, significance=5, mass_range=[5200, 5800]):
    import numpy as np
    import pandas as pd
    
    probability_space = np.linspace(prob_range[0], prob_range[1], dpoints)
    # A region over which the Punzi FOM will be calculated
    
    labels = labelled_data['category'].to_numpy()
    nsignal_before = labelled_data['category'].value_counts()[1]
    # How many signal events are in the original data sample
    
    feature_cols = labelled_data.columns.to_list()
    feature_cols.remove('category')
    # Get all the columns with features and not the category
    predictions = model.predict(labelled_data[feature_cols])
    # Make predictions on the labelled data using the trained MVA model
    
    punzis = []
    for p in probability_space:
        # Iterate through each point in probability space
        
        # Each event is predicted a probability P. If P < p we say that,
        # it is background, else it is signal. I.e. p -> 1 in limit of high
        # background rejection, high purity sample 
        
        preds = np.squeeze(np.where(predictions < p, 0, 1))
        all = np.array([preds, labels]).T
        
        efficiency = len(np.squeeze(np.where((all == [1, 1]).all(axis=1)))) / nsignal_before
        # Truth matched signal i.e. model said it was signal and it actually was 
        
        background = len(np.squeeze(np.where((all == [1, 0]).all(axis=1))))
        # background you thought was signal, so did not reject i.e. it got through 
        
        #print(f'{p:.4f} {efficiency:.5f} {background}')
        # Background is how much background is left after the cut i.e. how much REAL background is left (incorrectly identified as signal)
        
        punzi = efficiency / (significance/2 + np.sqrt(background))
        # Calculate the Punzi as defined by LHCb 
        
        punzis.append(punzi)
        # Add this point to the array of Punzis
    return np.array(punzis), probability_space

# %%
test_df = X_test
test_df['category'] = y_test

val_df = X_val
val_df['category'] = y_val

train_df = X_train
train_df['category'] = y_train

# %%
p1, probs1 = calculate_punzi(model, train_df, prob_range=[0.4, 0.98], dpoints=1000)
p2, probs2 = calculate_punzi(model, val_df, prob_range=[0.4, 0.98], dpoints=1000)
p3, probs3 = calculate_punzi(model, test_df, prob_range=[0.4, 0.98], dpoints=1000)

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

fonts = {'fontname':'Arial'}

ax.scatter(probs1, p1, s=2, label='Train Punzi')
ax.scatter(probs2, p2, s=2, label='Validation Punzi')
ax.scatter(probs3, p3, s=2, label='Test Punzi')

plt.ylabel('Punzi FOM Value', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability Cut Value', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.legend(loc='upper left', ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/train_history/{version}_punzi_scan.png')
plt.show()

# %% [markdown]
# The probability cut value, $P$ says that for $P_{pred}\lt P$ it is classed as background and if it is above then it is classed as signal. This means that for very high values of $P$ we have a very high purity sample but end up throwing away most events. Conversely a low value means we keep most data at the sacrifice of more background events leaking through.
