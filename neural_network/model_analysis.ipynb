# %% [markdown]
# # Model Analysis
# Here we test different datasets made and see if they have features with stronger discriminating power. That is, the neural network can distinguish better between them. This can be a little unstable due to the nature of neural networks.

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import callbacks, layers, Sequential
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import sys
sys.path.append('../')
from dataflow import Flow

# %%
version = "6.0.6"
fname = f'../data_files/{version}'

# %% [markdown]
# ## Define the Model and get Data

# %%
data = Flow(None, None, None, csv_path=f'{fname}.csv')
df = data.get_combined_data()

# %%
custom_callbacks = [
    callbacks.EarlyStopping(patience=20, min_delta=0.0005, restore_best_weights=True), 
    callbacks.ReduceLROnPlateau(patience=5, factor=0.2, min_lr=0.001)
    ]

def compile_model(input_shape):
    model = Sequential([
        layers.Dense(16, activation='relu', input_shape=input_shape, kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['binary_accuracy', 'AUC', 'TruePositives', 'TrueNegatives', 'FalsePositives', 'FalseNegatives'])
    
    return model

# %%
def plot_history_curves(history, epochs, model_version='No version', savefig='', off=False):
    if type(history) != dict:
        history = history.history
    
    loss = history['loss']
    val_loss = history['val_loss']
    accuracy = history['binary_accuracy']
    val_accuracy = history['val_binary_accuracy']
    auc = history['auc']
    val_auc = history['val_auc']
    epoch_range = range(1, epochs+1, 1)    

    fig, ax = plt.subplots(1, 3, figsize=(22, 6))
    
    ax[0].xaxis.set_minor_locator(AutoMinorLocator())
    ax[0].yaxis.set_minor_locator(AutoMinorLocator())
    ax[1].xaxis.set_minor_locator(AutoMinorLocator())
    ax[1].yaxis.set_minor_locator(AutoMinorLocator())
    ax[2].xaxis.set_minor_locator(AutoMinorLocator())
    ax[2].yaxis.set_minor_locator(AutoMinorLocator())
    fonts = {'fontname':'Arial'}
    
    ax[0].plot(epoch_range, loss, 'r.', label='Training Loss')
    ax[0].plot(epoch_range, val_loss, 'b.', label='Validation Loss')
    ax[1].plot(epoch_range, accuracy, 'r.', label='Training Accuracy')
    ax[1].plot(epoch_range, val_accuracy, 'b.', label='Validation Accuracy')
    ax[2].plot(epoch_range, auc, 'r.', label='Training AUC')
    ax[2].plot(epoch_range, val_auc, 'b.', label='Validation AUC')
    
    
    ax[0].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[0].set_ylabel('Loss', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[1].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[1].set_ylabel('Accuracy', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[2].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[2].set_ylabel('AUC', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[0].legend(loc='upper right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[1].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[2].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    
    plt.title(model_version)
    if savefig != '':
        plt.savefig(savefig)
    if not off:
        plt.show()

def plot_history(model_version, savefig='', off=False):
    history = pickle.load(open(f'train_history/v{model_version}', "rb"))
    nepochs = len(history['loss'])
    plot_history_curves(history, nepochs, model_version, savefig, off)

# %%
def fit_model(model, train_data, val_data, model_version, callbacks=None, epochs=100, batch_size=512):
    model_history = model.fit(train_data[0], train_data[1], epochs=epochs, batch_size=batch_size, validation_data=val_data, callbacks=callbacks, verbose=1)
    with open(f'train_history/v{model_version}', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)
    model.save(f'models/v{model_version}')

# %%
def run_all(data, version):
    # Give it a list of data objects
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()
    model = compile_model((X_train.shape[1],))
    fit_model(model, (X_train, y_train), (X_val, y_val), f'{version}', callbacks=custom_callbacks)
    plot_history(f'{version}', f'../images/NeuralNetwork/train_history/{version}.png', off=True)
    history = pickle.load(open(f'train_history/v{version}', "rb"))
    # Dont plot the first 5 epochs they are dumb

# %%
run_all(data, version)
# Out:
# 2022-03-10 13:58:10.169038: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-10 13:58:10.172460: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-03-10 13:58:10.953033: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-10 13:58:10.991744: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2400145000 Hz
# Epoch 1/100
# 43/43 [==============================] - 5s 33ms/step - loss: 0.9134 - binary_accuracy: 0.8148 - auc: 0.8956 - true_positives: 9068.0000 - true_negatives: 8721.0000 - false_positives: 2190.0000 - false_negatives: 1853.0000 - val_loss: 0.8299 - val_binary_accuracy: 0.9174 - val_auc: 0.9724 - val_true_positives: 3301.0000 - val_true_negatives: 3376.0000 - val_false_positives: 250.0000 - val_false_negatives: 351.0000
# Epoch 2/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7316 - binary_accuracy: 0.8903 - auc: 0.9541 - true_positives: 9771.0000 - true_negatives: 9667.0000 - false_positives: 1244.0000 - false_negatives: 1150.0000 - val_loss: 0.6947 - val_binary_accuracy: 0.9261 - val_auc: 0.9785 - val_true_positives: 3389.0000 - val_true_negatives: 3351.0000 - val_false_positives: 275.0000 - val_false_negatives: 263.0000
# Epoch 3/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.6412 - binary_accuracy: 0.9068 - auc: 0.9659 - true_positives: 9913.0000 - true_negatives: 9884.0000 - false_positives: 1027.0000 - false_negatives: 1008.0000 - val_loss: 0.6008 - val_binary_accuracy: 0.9276 - val_auc: 0.9809 - val_true_positives: 3421.0000 - val_true_negatives: 3330.0000 - val_false_positives: 296.0000 - val_false_negatives: 231.0000
# Epoch 4/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.5745 - binary_accuracy: 0.9146 - auc: 0.9697 - true_positives: 10011.0000 - true_negatives: 9957.0000 - false_positives: 954.0000 - false_negatives: 910.0000 - val_loss: 0.5368 - val_binary_accuracy: 0.9318 - val_auc: 0.9822 - val_true_positives: 3396.0000 - val_true_negatives: 3386.0000 - val_false_positives: 240.0000 - val_false_negatives: 256.0000
# Epoch 5/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.5204 - binary_accuracy: 0.9179 - auc: 0.9720 - true_positives: 10019.0000 - true_negatives: 10020.0000 - false_positives: 891.0000 - false_negatives: 902.0000 - val_loss: 0.4900 - val_binary_accuracy: 0.9340 - val_auc: 0.9830 - val_true_positives: 3399.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 253.0000
# Epoch 6/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.4741 - binary_accuracy: 0.9224 - auc: 0.9736 - true_positives: 10070.0000 - true_negatives: 10068.0000 - false_positives: 843.0000 - false_negatives: 851.0000 - val_loss: 0.4535 - val_binary_accuracy: 0.9343 - val_auc: 0.9836 - val_true_positives: 3414.0000 - val_true_negatives: 3386.0000 - val_false_positives: 240.0000 - val_false_negatives: 238.0000
# Epoch 7/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.4327 - binary_accuracy: 0.9245 - auc: 0.9754 - true_positives: 10110.0000 - true_negatives: 10074.0000 - false_positives: 837.0000 - false_negatives: 811.0000 - val_loss: 0.4160 - val_binary_accuracy: 0.9365 - val_auc: 0.9841 - val_true_positives: 3414.0000 - val_true_negatives: 3402.0000 - val_false_positives: 224.0000 - val_false_negatives: 238.0000
# Epoch 8/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.3978 - binary_accuracy: 0.9257 - auc: 0.9764 - true_positives: 10119.0000 - true_negatives: 10090.0000 - false_positives: 821.0000 - false_negatives: 802.0000 - val_loss: 0.3934 - val_binary_accuracy: 0.9367 - val_auc: 0.9845 - val_true_positives: 3390.0000 - val_true_negatives: 3427.0000 - val_false_positives: 199.0000 - val_false_negatives: 262.0000
# Epoch 9/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.3696 - binary_accuracy: 0.9276 - auc: 0.9772 - true_positives: 10152.0000 - true_negatives: 10100.0000 - false_positives: 811.0000 - false_negatives: 769.0000 - val_loss: 0.3659 - val_binary_accuracy: 0.9357 - val_auc: 0.9847 - val_true_positives: 3344.0000 - val_true_negatives: 3466.0000 - val_false_positives: 160.0000 - val_false_negatives: 308.0000
# Epoch 10/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.3497 - binary_accuracy: 0.9279 - auc: 0.9768 - true_positives: 10122.0000 - true_negatives: 10137.0000 - false_positives: 774.0000 - false_negatives: 799.0000 - val_loss: 0.3449 - val_binary_accuracy: 0.9371 - val_auc: 0.9849 - val_true_positives: 3430.0000 - val_true_negatives: 3390.0000 - val_false_positives: 236.0000 - val_false_negatives: 222.0000
# Epoch 11/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.3278 - binary_accuracy: 0.9292 - auc: 0.9778 - true_positives: 10151.0000 - true_negatives: 10136.0000 - false_positives: 775.0000 - false_negatives: 770.0000 - val_loss: 0.3360 - val_binary_accuracy: 0.9356 - val_auc: 0.9852 - val_true_positives: 3503.0000 - val_true_negatives: 3306.0000 - val_false_positives: 320.0000 - val_false_negatives: 149.0000
# Epoch 12/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.3100 - binary_accuracy: 0.9303 - auc: 0.9783 - true_positives: 10170.0000 - true_negatives: 10141.0000 - false_positives: 770.0000 - false_negatives: 751.0000 - val_loss: 0.3249 - val_binary_accuracy: 0.9386 - val_auc: 0.9853 - val_true_positives: 3433.0000 - val_true_negatives: 3398.0000 - val_false_positives: 228.0000 - val_false_negatives: 219.0000
# Epoch 13/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2949 - binary_accuracy: 0.9304 - auc: 0.9786 - true_positives: 10158.0000 - true_negatives: 10154.0000 - false_positives: 757.0000 - false_negatives: 763.0000 - val_loss: 0.3075 - val_binary_accuracy: 0.9380 - val_auc: 0.9855 - val_true_positives: 3468.0000 - val_true_negatives: 3359.0000 - val_false_positives: 267.0000 - val_false_negatives: 184.0000
# Epoch 14/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2829 - binary_accuracy: 0.9311 - auc: 0.9787 - true_positives: 10188.0000 - true_negatives: 10139.0000 - false_positives: 772.0000 - false_negatives: 733.0000 - val_loss: 0.2809 - val_binary_accuracy: 0.9400 - val_auc: 0.9857 - val_true_positives: 3438.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 214.0000
# Epoch 15/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2710 - binary_accuracy: 0.9309 - auc: 0.9794 - true_positives: 10166.0000 - true_negatives: 10157.0000 - false_positives: 754.0000 - false_negatives: 755.0000 - val_loss: 0.2711 - val_binary_accuracy: 0.9405 - val_auc: 0.9858 - val_true_positives: 3443.0000 - val_true_negatives: 3402.0000 - val_false_positives: 224.0000 - val_false_negatives: 209.0000
# Epoch 16/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2614 - binary_accuracy: 0.9315 - auc: 0.9798 - true_positives: 10167.0000 - true_negatives: 10169.0000 - false_positives: 742.0000 - false_negatives: 754.0000 - val_loss: 0.2764 - val_binary_accuracy: 0.9391 - val_auc: 0.9862 - val_true_positives: 3484.0000 - val_true_negatives: 3351.0000 - val_false_positives: 275.0000 - val_false_negatives: 168.0000
# Epoch 17/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2536 - binary_accuracy: 0.9323 - auc: 0.9797 - true_positives: 10189.0000 - true_negatives: 10164.0000 - false_positives: 747.0000 - false_negatives: 732.0000 - val_loss: 0.2752 - val_binary_accuracy: 0.9411 - val_auc: 0.9858 - val_true_positives: 3443.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 209.0000
# Epoch 18/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2467 - binary_accuracy: 0.9324 - auc: 0.9799 - true_positives: 10209.0000 - true_negatives: 10148.0000 - false_positives: 763.0000 - false_negatives: 712.0000 - val_loss: 0.2577 - val_binary_accuracy: 0.9409 - val_auc: 0.9866 - val_true_positives: 3480.0000 - val_true_negatives: 3368.0000 - val_false_positives: 258.0000 - val_false_negatives: 172.0000
# Epoch 19/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2407 - binary_accuracy: 0.9329 - auc: 0.9803 - true_positives: 10206.0000 - true_negatives: 10162.0000 - false_positives: 749.0000 - false_negatives: 715.0000 - val_loss: 0.2501 - val_binary_accuracy: 0.9390 - val_auc: 0.9862 - val_true_positives: 3507.0000 - val_true_negatives: 3327.0000 - val_false_positives: 299.0000 - val_false_negatives: 145.0000
# Epoch 20/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2356 - binary_accuracy: 0.9328 - auc: 0.9803 - true_positives: 10205.0000 - true_negatives: 10159.0000 - false_positives: 752.0000 - false_negatives: 716.0000 - val_loss: 0.2289 - val_binary_accuracy: 0.9401 - val_auc: 0.9863 - val_true_positives: 3443.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 209.0000
# Epoch 21/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2284 - binary_accuracy: 0.9334 - auc: 0.9811 - true_positives: 10211.0000 - true_negatives: 10167.0000 - false_positives: 744.0000 - false_negatives: 710.0000 - val_loss: 0.2236 - val_binary_accuracy: 0.9420 - val_auc: 0.9863 - val_true_positives: 3466.0000 - val_true_negatives: 3390.0000 - val_false_positives: 236.0000 - val_false_negatives: 186.0000
# Epoch 22/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2302 - binary_accuracy: 0.9315 - auc: 0.9800 - true_positives: 10185.0000 - true_negatives: 10152.0000 - false_positives: 759.0000 - false_negatives: 736.0000 - val_loss: 0.2169 - val_binary_accuracy: 0.9426 - val_auc: 0.9864 - val_true_positives: 3502.0000 - val_true_negatives: 3358.0000 - val_false_positives: 268.0000 - val_false_negatives: 150.0000
# Epoch 23/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2198 - binary_accuracy: 0.9361 - auc: 0.9814 - true_positives: 10228.0000 - true_negatives: 10208.0000 - false_positives: 703.0000 - false_negatives: 693.0000 - val_loss: 0.2133 - val_binary_accuracy: 0.9405 - val_auc: 0.9861 - val_true_positives: 3500.0000 - val_true_negatives: 3345.0000 - val_false_positives: 281.0000 - val_false_negatives: 152.0000
# Epoch 24/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.2214 - binary_accuracy: 0.9331 - auc: 0.9806 - true_positives: 10233.0000 - true_negatives: 10138.0000 - false_positives: 773.0000 - false_negatives: 688.0000 - val_loss: 0.2061 - val_binary_accuracy: 0.9422 - val_auc: 0.9865 - val_true_positives: 3447.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 205.0000
# Epoch 25/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.2173 - binary_accuracy: 0.9348 - auc: 0.9809 - true_positives: 10228.0000 - true_negatives: 10181.0000 - false_positives: 730.0000 - false_negatives: 693.0000 - val_loss: 0.2054 - val_binary_accuracy: 0.9424 - val_auc: 0.9864 - val_true_positives: 3453.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 199.0000
# Epoch 26/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2142 - binary_accuracy: 0.9355 - auc: 0.9809 - true_positives: 10235.0000 - true_negatives: 10188.0000 - false_positives: 723.0000 - false_negatives: 686.0000 - val_loss: 0.1976 - val_binary_accuracy: 0.9405 - val_auc: 0.9864 - val_true_positives: 3461.0000 - val_true_negatives: 3384.0000 - val_false_positives: 242.0000 - val_false_negatives: 191.0000
# Epoch 27/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2120 - binary_accuracy: 0.9345 - auc: 0.9813 - true_positives: 10208.0000 - true_negatives: 10193.0000 - false_positives: 718.0000 - false_negatives: 713.0000 - val_loss: 0.1904 - val_binary_accuracy: 0.9401 - val_auc: 0.9870 - val_true_positives: 3406.0000 - val_true_negatives: 3436.0000 - val_false_positives: 190.0000 - val_false_negatives: 246.0000
# Epoch 28/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2104 - binary_accuracy: 0.9346 - auc: 0.9811 - true_positives: 10207.0000 - true_negatives: 10197.0000 - false_positives: 714.0000 - false_negatives: 714.0000 - val_loss: 0.1997 - val_binary_accuracy: 0.9390 - val_auc: 0.9868 - val_true_positives: 3400.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 252.0000
# Epoch 29/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2092 - binary_accuracy: 0.9350 - auc: 0.9809 - true_positives: 10234.0000 - true_negatives: 10178.0000 - false_positives: 733.0000 - false_negatives: 687.0000 - val_loss: 0.1954 - val_binary_accuracy: 0.9446 - val_auc: 0.9872 - val_true_positives: 3466.0000 - val_true_negatives: 3409.0000 - val_false_positives: 217.0000 - val_false_negatives: 186.0000
# Epoch 30/100
# 43/43 [==============================] - 1s 12ms/step - loss: 0.2043 - binary_accuracy: 0.9352 - auc: 0.9819 - true_positives: 10238.0000 - true_negatives: 10180.0000 - false_positives: 731.0000 - false_negatives: 683.0000 - val_loss: 0.1944 - val_binary_accuracy: 0.9434 - val_auc: 0.9869 - val_true_positives: 3482.0000 - val_true_negatives: 3384.0000 - val_false_positives: 242.0000 - val_false_negatives: 170.0000
# Epoch 31/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2025 - binary_accuracy: 0.9347 - auc: 0.9820 - true_positives: 10219.0000 - true_negatives: 10187.0000 - false_positives: 724.0000 - false_negatives: 702.0000 - val_loss: 0.1825 - val_binary_accuracy: 0.9445 - val_auc: 0.9871 - val_true_positives: 3469.0000 - val_true_negatives: 3405.0000 - val_false_positives: 221.0000 - val_false_negatives: 183.0000
# Epoch 32/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2027 - binary_accuracy: 0.9346 - auc: 0.9818 - true_positives: 10208.0000 - true_negatives: 10197.0000 - false_positives: 714.0000 - false_negatives: 713.0000 - val_loss: 0.1943 - val_binary_accuracy: 0.9409 - val_auc: 0.9869 - val_true_positives: 3520.0000 - val_true_negatives: 3328.0000 - val_false_positives: 298.0000 - val_false_negatives: 132.0000
# Epoch 33/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1990 - binary_accuracy: 0.9354 - auc: 0.9822 - true_positives: 10251.0000 - true_negatives: 10171.0000 - false_positives: 740.0000 - false_negatives: 670.0000 - val_loss: 0.1955 - val_binary_accuracy: 0.9400 - val_auc: 0.9872 - val_true_positives: 3358.0000 - val_true_negatives: 3483.0000 - val_false_positives: 143.0000 - val_false_negatives: 294.0000
# Epoch 34/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2000 - binary_accuracy: 0.9359 - auc: 0.9817 - true_positives: 10228.0000 - true_negatives: 10204.0000 - false_positives: 707.0000 - false_negatives: 693.0000 - val_loss: 0.1757 - val_binary_accuracy: 0.9446 - val_auc: 0.9871 - val_true_positives: 3451.0000 - val_true_negatives: 3424.0000 - val_false_positives: 202.0000 - val_false_negatives: 201.0000
# Epoch 35/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2008 - binary_accuracy: 0.9343 - auc: 0.9815 - true_positives: 10219.0000 - true_negatives: 10178.0000 - false_positives: 733.0000 - false_negatives: 702.0000 - val_loss: 0.2048 - val_binary_accuracy: 0.9416 - val_auc: 0.9873 - val_true_positives: 3374.0000 - val_true_negatives: 3479.0000 - val_false_positives: 147.0000 - val_false_negatives: 278.0000
# Epoch 36/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1961 - binary_accuracy: 0.9371 - auc: 0.9821 - true_positives: 10228.0000 - true_negatives: 10231.0000 - false_positives: 680.0000 - false_negatives: 693.0000 - val_loss: 0.1793 - val_binary_accuracy: 0.9431 - val_auc: 0.9866 - val_true_positives: 3470.0000 - val_true_negatives: 3394.0000 - val_false_positives: 232.0000 - val_false_negatives: 182.0000
# Epoch 37/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1930 - binary_accuracy: 0.9358 - auc: 0.9829 - true_positives: 10227.0000 - true_negatives: 10203.0000 - false_positives: 708.0000 - false_negatives: 694.0000 - val_loss: 0.1814 - val_binary_accuracy: 0.9397 - val_auc: 0.9873 - val_true_positives: 3362.0000 - val_true_negatives: 3477.0000 - val_false_positives: 149.0000 - val_false_negatives: 290.0000
# Epoch 38/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1954 - binary_accuracy: 0.9355 - auc: 0.9821 - true_positives: 10225.0000 - true_negatives: 10198.0000 - false_positives: 713.0000 - false_negatives: 696.0000 - val_loss: 0.1751 - val_binary_accuracy: 0.9433 - val_auc: 0.9872 - val_true_positives: 3427.0000 - val_true_negatives: 3438.0000 - val_false_positives: 188.0000 - val_false_negatives: 225.0000
# Epoch 39/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1945 - binary_accuracy: 0.9358 - auc: 0.9822 - true_positives: 10231.0000 - true_negatives: 10199.0000 - false_positives: 712.0000 - false_negatives: 690.0000 - val_loss: 0.1741 - val_binary_accuracy: 0.9437 - val_auc: 0.9874 - val_true_positives: 3447.0000 - val_true_negatives: 3421.0000 - val_false_positives: 205.0000 - val_false_negatives: 205.0000
# Epoch 40/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1896 - binary_accuracy: 0.9375 - auc: 0.9829 - true_positives: 10242.0000 - true_negatives: 10226.0000 - false_positives: 685.0000 - false_negatives: 679.0000 - val_loss: 0.1734 - val_binary_accuracy: 0.9433 - val_auc: 0.9872 - val_true_positives: 3487.0000 - val_true_negatives: 3378.0000 - val_false_positives: 248.0000 - val_false_negatives: 165.0000
# Epoch 41/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1955 - binary_accuracy: 0.9334 - auc: 0.9817 - true_positives: 10219.0000 - true_negatives: 10158.0000 - false_positives: 753.0000 - false_negatives: 702.0000 - val_loss: 0.1739 - val_binary_accuracy: 0.9460 - val_auc: 0.9877 - val_true_positives: 3453.0000 - val_true_negatives: 3432.0000 - val_false_positives: 194.0000 - val_false_negatives: 199.0000
# Epoch 42/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1931 - binary_accuracy: 0.9372 - auc: 0.9820 - true_positives: 10269.0000 - true_negatives: 10191.0000 - false_positives: 720.0000 - false_negatives: 652.0000 - val_loss: 0.1727 - val_binary_accuracy: 0.9431 - val_auc: 0.9872 - val_true_positives: 3399.0000 - val_true_negatives: 3465.0000 - val_false_positives: 161.0000 - val_false_negatives: 253.0000
# Epoch 43/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1921 - binary_accuracy: 0.9355 - auc: 0.9822 - true_positives: 10200.0000 - true_negatives: 10224.0000 - false_positives: 687.0000 - false_negatives: 721.0000 - val_loss: 0.1762 - val_binary_accuracy: 0.9477 - val_auc: 0.9878 - val_true_positives: 3476.0000 - val_true_negatives: 3421.0000 - val_false_positives: 205.0000 - val_false_negatives: 176.0000
# Epoch 44/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1913 - binary_accuracy: 0.9370 - auc: 0.9824 - true_positives: 10242.0000 - true_negatives: 10215.0000 - false_positives: 696.0000 - false_negatives: 679.0000 - val_loss: 0.1702 - val_binary_accuracy: 0.9452 - val_auc: 0.9876 - val_true_positives: 3476.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 176.0000
# Epoch 45/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1872 - binary_accuracy: 0.9377 - auc: 0.9832 - true_positives: 10243.0000 - true_negatives: 10229.0000 - false_positives: 682.0000 - false_negatives: 678.0000 - val_loss: 0.1687 - val_binary_accuracy: 0.9428 - val_auc: 0.9874 - val_true_positives: 3405.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 247.0000
# Epoch 46/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1881 - binary_accuracy: 0.9368 - auc: 0.9827 - true_positives: 10236.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 685.0000 - val_loss: 0.1680 - val_binary_accuracy: 0.9460 - val_auc: 0.9874 - val_true_positives: 3493.0000 - val_true_negatives: 3392.0000 - val_false_positives: 234.0000 - val_false_negatives: 159.0000
# Epoch 47/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1884 - binary_accuracy: 0.9381 - auc: 0.9828 - true_positives: 10267.0000 - true_negatives: 10214.0000 - false_positives: 697.0000 - false_negatives: 654.0000 - val_loss: 0.1677 - val_binary_accuracy: 0.9453 - val_auc: 0.9876 - val_true_positives: 3457.0000 - val_true_negatives: 3423.0000 - val_false_positives: 203.0000 - val_false_negatives: 195.0000
# Epoch 48/100
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1877 - binary_accuracy: 0.9368 - auc: 0.9829 - true_positives: 10247.0000 - true_negatives: 10205.0000 - false_positives: 706.0000 - false_negatives: 674.0000 - val_loss: 0.1654 - val_binary_accuracy: 0.9459 - val_auc: 0.9876 - val_true_positives: 3454.0000 - val_true_negatives: 3430.0000 - val_false_positives: 196.0000 - val_false_negatives: 198.0000
# Epoch 49/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1875 - binary_accuracy: 0.9387 - auc: 0.9825 - true_positives: 10269.0000 - true_negatives: 10225.0000 - false_positives: 686.0000 - false_negatives: 652.0000 - val_loss: 0.1683 - val_binary_accuracy: 0.9453 - val_auc: 0.9872 - val_true_positives: 3447.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 205.0000
# Epoch 50/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1856 - binary_accuracy: 0.9373 - auc: 0.9829 - true_positives: 10237.0000 - true_negatives: 10227.0000 - false_positives: 684.0000 - false_negatives: 684.0000 - val_loss: 0.1677 - val_binary_accuracy: 0.9442 - val_auc: 0.9877 - val_true_positives: 3495.0000 - val_true_negatives: 3377.0000 - val_false_positives: 249.0000 - val_false_negatives: 157.0000
# Epoch 51/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1842 - binary_accuracy: 0.9375 - auc: 0.9834 - true_positives: 10265.0000 - true_negatives: 10202.0000 - false_positives: 709.0000 - false_negatives: 656.0000 - val_loss: 0.1638 - val_binary_accuracy: 0.9430 - val_auc: 0.9877 - val_true_positives: 3425.0000 - val_true_negatives: 3438.0000 - val_false_positives: 188.0000 - val_false_negatives: 227.0000
# Epoch 52/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1882 - binary_accuracy: 0.9362 - auc: 0.9825 - true_positives: 10236.0000 - true_negatives: 10203.0000 - false_positives: 708.0000 - false_negatives: 685.0000 - val_loss: 0.1638 - val_binary_accuracy: 0.9435 - val_auc: 0.9876 - val_true_positives: 3406.0000 - val_true_negatives: 3461.0000 - val_false_positives: 165.0000 - val_false_negatives: 246.0000
# Epoch 53/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1833 - binary_accuracy: 0.9376 - auc: 0.9834 - true_positives: 10227.0000 - true_negatives: 10243.0000 - false_positives: 668.0000 - false_negatives: 694.0000 - val_loss: 0.1665 - val_binary_accuracy: 0.9456 - val_auc: 0.9874 - val_true_positives: 3479.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 173.0000
# Epoch 54/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1842 - binary_accuracy: 0.9378 - auc: 0.9830 - true_positives: 10257.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 664.0000 - val_loss: 0.1631 - val_binary_accuracy: 0.9457 - val_auc: 0.9876 - val_true_positives: 3452.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 200.0000
# Epoch 55/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1835 - binary_accuracy: 0.9375 - auc: 0.9832 - true_positives: 10242.0000 - true_negatives: 10226.0000 - false_positives: 685.0000 - false_negatives: 679.0000 - val_loss: 0.1672 - val_binary_accuracy: 0.9424 - val_auc: 0.9876 - val_true_positives: 3390.0000 - val_true_negatives: 3469.0000 - val_false_positives: 157.0000 - val_false_negatives: 262.0000
# Epoch 56/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1851 - binary_accuracy: 0.9378 - auc: 0.9827 - true_positives: 10255.0000 - true_negatives: 10218.0000 - false_positives: 693.0000 - false_negatives: 666.0000 - val_loss: 0.1618 - val_binary_accuracy: 0.9430 - val_auc: 0.9878 - val_true_positives: 3408.0000 - val_true_negatives: 3455.0000 - val_false_positives: 171.0000 - val_false_negatives: 244.0000
# Epoch 57/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1821 - binary_accuracy: 0.9366 - auc: 0.9836 - true_positives: 10252.0000 - true_negatives: 10196.0000 - false_positives: 715.0000 - false_negatives: 669.0000 - val_loss: 0.1620 - val_binary_accuracy: 0.9459 - val_auc: 0.9876 - val_true_positives: 3466.0000 - val_true_negatives: 3418.0000 - val_false_positives: 208.0000 - val_false_negatives: 186.0000
# Epoch 58/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1825 - binary_accuracy: 0.9381 - auc: 0.9832 - true_positives: 10250.0000 - true_negatives: 10231.0000 - false_positives: 680.0000 - false_negatives: 671.0000 - val_loss: 0.1616 - val_binary_accuracy: 0.9467 - val_auc: 0.9878 - val_true_positives: 3433.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 219.0000
# Epoch 59/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1831 - binary_accuracy: 0.9368 - auc: 0.9832 - true_positives: 10241.0000 - true_negatives: 10211.0000 - false_positives: 700.0000 - false_negatives: 680.0000 - val_loss: 0.1615 - val_binary_accuracy: 0.9446 - val_auc: 0.9879 - val_true_positives: 3424.0000 - val_true_negatives: 3451.0000 - val_false_positives: 175.0000 - val_false_negatives: 228.0000
# Epoch 60/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1809 - binary_accuracy: 0.9383 - auc: 0.9835 - true_positives: 10273.0000 - true_negatives: 10212.0000 - false_positives: 699.0000 - false_negatives: 648.0000 - val_loss: 0.1620 - val_binary_accuracy: 0.9456 - val_auc: 0.9877 - val_true_positives: 3406.0000 - val_true_negatives: 3476.0000 - val_false_positives: 150.0000 - val_false_negatives: 246.0000
# Epoch 61/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1804 - binary_accuracy: 0.9379 - auc: 0.9835 - true_positives: 10252.0000 - true_negatives: 10224.0000 - false_positives: 687.0000 - false_negatives: 669.0000 - val_loss: 0.1622 - val_binary_accuracy: 0.9468 - val_auc: 0.9878 - val_true_positives: 3430.0000 - val_true_negatives: 3461.0000 - val_false_positives: 165.0000 - val_false_negatives: 222.0000
# Epoch 62/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1817 - binary_accuracy: 0.9375 - auc: 0.9831 - true_positives: 10270.0000 - true_negatives: 10197.0000 - false_positives: 714.0000 - false_negatives: 651.0000 - val_loss: 0.1655 - val_binary_accuracy: 0.9412 - val_auc: 0.9876 - val_true_positives: 3361.0000 - val_true_negatives: 3489.0000 - val_false_positives: 137.0000 - val_false_negatives: 291.0000
# Epoch 63/100
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1810 - binary_accuracy: 0.9383 - auc: 0.9833 - true_positives: 10264.0000 - true_negatives: 10220.0000 - false_positives: 691.0000 - false_negatives: 657.0000 - val_loss: 0.1640 - val_binary_accuracy: 0.9463 - val_auc: 0.9875 - val_true_positives: 3443.0000 - val_true_negatives: 3444.0000 - val_false_positives: 182.0000 - val_false_negatives: 209.0000
# Epoch 64/100
# 43/43 [==============================] - 1s 25ms/step - loss: 0.1795 - binary_accuracy: 0.9384 - auc: 0.9836 - true_positives: 10270.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 651.0000 - val_loss: 0.1620 - val_binary_accuracy: 0.9422 - val_auc: 0.9876 - val_true_positives: 3400.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 252.0000
# Epoch 65/100
# 43/43 [==============================] - 1s 30ms/step - loss: 0.1805 - binary_accuracy: 0.9377 - auc: 0.9833 - true_positives: 10251.0000 - true_negatives: 10220.0000 - false_positives: 691.0000 - false_negatives: 670.0000 - val_loss: 0.1626 - val_binary_accuracy: 0.9427 - val_auc: 0.9877 - val_true_positives: 3377.0000 - val_true_negatives: 3484.0000 - val_false_positives: 142.0000 - val_false_negatives: 275.0000
# Epoch 66/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1830 - binary_accuracy: 0.9383 - auc: 0.9827 - true_positives: 10247.0000 - true_negatives: 10239.0000 - false_positives: 672.0000 - false_negatives: 674.0000 - val_loss: 0.1637 - val_binary_accuracy: 0.9470 - val_auc: 0.9875 - val_true_positives: 3459.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 193.0000
# Epoch 67/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1798 - binary_accuracy: 0.9382 - auc: 0.9835 - true_positives: 10270.0000 - true_negatives: 10212.0000 - false_positives: 699.0000 - false_negatives: 651.0000 - val_loss: 0.1621 - val_binary_accuracy: 0.9470 - val_auc: 0.9871 - val_true_positives: 3456.0000 - val_true_negatives: 3436.0000 - val_false_positives: 190.0000 - val_false_negatives: 196.0000
# Epoch 68/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1784 - binary_accuracy: 0.9400 - auc: 0.9836 - true_positives: 10293.0000 - true_negatives: 10229.0000 - false_positives: 682.0000 - false_negatives: 628.0000 - val_loss: 0.1594 - val_binary_accuracy: 0.9449 - val_auc: 0.9876 - val_true_positives: 3461.0000 - val_true_negatives: 3416.0000 - val_false_positives: 210.0000 - val_false_negatives: 191.0000
# Epoch 69/100
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1781 - binary_accuracy: 0.9386 - auc: 0.9839 - true_positives: 10272.0000 - true_negatives: 10220.0000 - false_positives: 691.0000 - false_negatives: 649.0000 - val_loss: 0.1601 - val_binary_accuracy: 0.9434 - val_auc: 0.9875 - val_true_positives: 3429.0000 - val_true_negatives: 3437.0000 - val_false_positives: 189.0000 - val_false_negatives: 223.0000
# Epoch 70/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1796 - binary_accuracy: 0.9393 - auc: 0.9833 - true_positives: 10282.0000 - true_negatives: 10225.0000 - false_positives: 686.0000 - false_negatives: 639.0000 - val_loss: 0.1735 - val_binary_accuracy: 0.9391 - val_auc: 0.9880 - val_true_positives: 3318.0000 - val_true_negatives: 3517.0000 - val_false_positives: 109.0000 - val_false_negatives: 334.0000
# Epoch 71/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1781 - binary_accuracy: 0.9390 - auc: 0.9837 - true_positives: 10231.0000 - true_negatives: 10269.0000 - false_positives: 642.0000 - false_negatives: 690.0000 - val_loss: 0.1617 - val_binary_accuracy: 0.9445 - val_auc: 0.9876 - val_true_positives: 3418.0000 - val_true_negatives: 3456.0000 - val_false_positives: 170.0000 - val_false_negatives: 234.0000
# Epoch 72/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1776 - binary_accuracy: 0.9393 - auc: 0.9838 - true_positives: 10275.0000 - true_negatives: 10232.0000 - false_positives: 679.0000 - false_negatives: 646.0000 - val_loss: 0.1609 - val_binary_accuracy: 0.9430 - val_auc: 0.9879 - val_true_positives: 3370.0000 - val_true_negatives: 3493.0000 - val_false_positives: 133.0000 - val_false_negatives: 282.0000
# Epoch 73/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1782 - binary_accuracy: 0.9398 - auc: 0.9837 - true_positives: 10245.0000 - true_negatives: 10272.0000 - false_positives: 639.0000 - false_negatives: 676.0000 - val_loss: 0.1594 - val_binary_accuracy: 0.9446 - val_auc: 0.9874 - val_true_positives: 3440.0000 - val_true_negatives: 3435.0000 - val_false_positives: 191.0000 - val_false_negatives: 212.0000
# Epoch 74/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1751 - binary_accuracy: 0.9393 - auc: 0.9842 - true_positives: 10243.0000 - true_negatives: 10264.0000 - false_positives: 647.0000 - false_negatives: 678.0000 - val_loss: 0.1632 - val_binary_accuracy: 0.9423 - val_auc: 0.9879 - val_true_positives: 3360.0000 - val_true_negatives: 3498.0000 - val_false_positives: 128.0000 - val_false_negatives: 292.0000
# Epoch 75/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1790 - binary_accuracy: 0.9396 - auc: 0.9833 - true_positives: 10267.0000 - true_negatives: 10247.0000 - false_positives: 664.0000 - false_negatives: 654.0000 - val_loss: 0.1593 - val_binary_accuracy: 0.9478 - val_auc: 0.9875 - val_true_positives: 3479.0000 - val_true_negatives: 3419.0000 - val_false_positives: 207.0000 - val_false_negatives: 173.0000
# Epoch 76/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.1773 - binary_accuracy: 0.9395 - auc: 0.9837 - true_positives: 10261.0000 - true_negatives: 10251.0000 - false_positives: 660.0000 - false_negatives: 660.0000 - val_loss: 0.1664 - val_binary_accuracy: 0.9466 - val_auc: 0.9876 - val_true_positives: 3501.0000 - val_true_negatives: 3388.0000 - val_false_positives: 238.0000 - val_false_negatives: 151.0000
# Epoch 77/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1788 - binary_accuracy: 0.9390 - auc: 0.9834 - true_positives: 10262.0000 - true_negatives: 10238.0000 - false_positives: 673.0000 - false_negatives: 659.0000 - val_loss: 0.1566 - val_binary_accuracy: 0.9455 - val_auc: 0.9877 - val_true_positives: 3455.0000 - val_true_negatives: 3426.0000 - val_false_positives: 200.0000 - val_false_negatives: 197.0000
# Epoch 78/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1756 - binary_accuracy: 0.9396 - auc: 0.9840 - true_positives: 10266.0000 - true_negatives: 10248.0000 - false_positives: 663.0000 - false_negatives: 655.0000 - val_loss: 0.1576 - val_binary_accuracy: 0.9455 - val_auc: 0.9878 - val_true_positives: 3417.0000 - val_true_negatives: 3464.0000 - val_false_positives: 162.0000 - val_false_negatives: 235.0000
# Epoch 79/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1749 - binary_accuracy: 0.9408 - auc: 0.9840 - true_positives: 10275.0000 - true_negatives: 10265.0000 - false_positives: 646.0000 - false_negatives: 646.0000 - val_loss: 0.1612 - val_binary_accuracy: 0.9442 - val_auc: 0.9875 - val_true_positives: 3391.0000 - val_true_negatives: 3481.0000 - val_false_positives: 145.0000 - val_false_negatives: 261.0000
# Epoch 80/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1765 - binary_accuracy: 0.9396 - auc: 0.9840 - true_positives: 10264.0000 - true_negatives: 10250.0000 - false_positives: 661.0000 - false_negatives: 657.0000 - val_loss: 0.1622 - val_binary_accuracy: 0.9450 - val_auc: 0.9869 - val_true_positives: 3474.0000 - val_true_negatives: 3404.0000 - val_false_positives: 222.0000 - val_false_negatives: 178.0000
# Epoch 81/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1786 - binary_accuracy: 0.9394 - auc: 0.9832 - true_positives: 10277.0000 - true_negatives: 10233.0000 - false_positives: 678.0000 - false_negatives: 644.0000 - val_loss: 0.1605 - val_binary_accuracy: 0.9434 - val_auc: 0.9879 - val_true_positives: 3406.0000 - val_true_negatives: 3460.0000 - val_false_positives: 166.0000 - val_false_negatives: 246.0000
# Epoch 82/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1769 - binary_accuracy: 0.9405 - auc: 0.9835 - true_positives: 10263.0000 - true_negatives: 10271.0000 - false_positives: 640.0000 - false_negatives: 658.0000 - val_loss: 0.1601 - val_binary_accuracy: 0.9467 - val_auc: 0.9875 - val_true_positives: 3463.0000 - val_true_negatives: 3427.0000 - val_false_positives: 199.0000 - val_false_negatives: 189.0000
# Epoch 83/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1786 - binary_accuracy: 0.9388 - auc: 0.9834 - true_positives: 10257.0000 - true_negatives: 10239.0000 - false_positives: 672.0000 - false_negatives: 664.0000 - val_loss: 0.1582 - val_binary_accuracy: 0.9471 - val_auc: 0.9878 - val_true_positives: 3487.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 165.0000
# Epoch 84/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1770 - binary_accuracy: 0.9395 - auc: 0.9835 - true_positives: 10266.0000 - true_negatives: 10246.0000 - false_positives: 665.0000 - false_negatives: 655.0000 - val_loss: 0.1604 - val_binary_accuracy: 0.9477 - val_auc: 0.9879 - val_true_positives: 3476.0000 - val_true_negatives: 3421.0000 - val_false_positives: 205.0000 - val_false_negatives: 176.0000
# Epoch 85/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1796 - binary_accuracy: 0.9390 - auc: 0.9831 - true_positives: 10283.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 638.0000 - val_loss: 0.1574 - val_binary_accuracy: 0.9467 - val_auc: 0.9881 - val_true_positives: 3440.0000 - val_true_negatives: 3450.0000 - val_false_positives: 176.0000 - val_false_negatives: 212.0000
# Epoch 86/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1756 - binary_accuracy: 0.9402 - auc: 0.9840 - true_positives: 10304.0000 - true_negatives: 10223.0000 - false_positives: 688.0000 - false_negatives: 617.0000 - val_loss: 0.1603 - val_binary_accuracy: 0.9442 - val_auc: 0.9877 - val_true_positives: 3383.0000 - val_true_negatives: 3489.0000 - val_false_positives: 137.0000 - val_false_negatives: 269.0000
# Epoch 87/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1759 - binary_accuracy: 0.9377 - auc: 0.9839 - true_positives: 10252.0000 - true_negatives: 10219.0000 - false_positives: 692.0000 - false_negatives: 669.0000 - val_loss: 0.1641 - val_binary_accuracy: 0.9450 - val_auc: 0.9873 - val_true_positives: 3394.0000 - val_true_negatives: 3484.0000 - val_false_positives: 142.0000 - val_false_negatives: 258.0000
# Epoch 88/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1785 - binary_accuracy: 0.9387 - auc: 0.9832 - true_positives: 10253.0000 - true_negatives: 10240.0000 - false_positives: 671.0000 - false_negatives: 668.0000 - val_loss: 0.1569 - val_binary_accuracy: 0.9446 - val_auc: 0.9878 - val_true_positives: 3428.0000 - val_true_negatives: 3447.0000 - val_false_positives: 179.0000 - val_false_negatives: 224.0000
# Epoch 89/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1762 - binary_accuracy: 0.9408 - auc: 0.9836 - true_positives: 10284.0000 - true_negatives: 10255.0000 - false_positives: 656.0000 - false_negatives: 637.0000 - val_loss: 0.1564 - val_binary_accuracy: 0.9449 - val_auc: 0.9879 - val_true_positives: 3435.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 217.0000
# Epoch 90/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1762 - binary_accuracy: 0.9399 - auc: 0.9837 - true_positives: 10269.0000 - true_negatives: 10251.0000 - false_positives: 660.0000 - false_negatives: 652.0000 - val_loss: 0.1556 - val_binary_accuracy: 0.9452 - val_auc: 0.9877 - val_true_positives: 3463.0000 - val_true_negatives: 3416.0000 - val_false_positives: 210.0000 - val_false_negatives: 189.0000
# Epoch 91/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1783 - binary_accuracy: 0.9386 - auc: 0.9831 - true_positives: 10273.0000 - true_negatives: 10218.0000 - false_positives: 693.0000 - false_negatives: 648.0000 - val_loss: 0.1597 - val_binary_accuracy: 0.9449 - val_auc: 0.9877 - val_true_positives: 3510.0000 - val_true_negatives: 3367.0000 - val_false_positives: 259.0000 - val_false_negatives: 142.0000
# Epoch 92/100
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1752 - binary_accuracy: 0.9397 - auc: 0.9838 - true_positives: 10262.0000 - true_negatives: 10254.0000 - false_positives: 657.0000 - false_negatives: 659.0000 - val_loss: 0.1583 - val_binary_accuracy: 0.9467 - val_auc: 0.9876 - val_true_positives: 3451.0000 - val_true_negatives: 3439.0000 - val_false_positives: 187.0000 - val_false_negatives: 201.0000
# Epoch 93/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1747 - binary_accuracy: 0.9397 - auc: 0.9841 - true_positives: 10269.0000 - true_negatives: 10246.0000 - false_positives: 665.0000 - false_negatives: 652.0000 - val_loss: 0.1623 - val_binary_accuracy: 0.9422 - val_auc: 0.9878 - val_true_positives: 3358.0000 - val_true_negatives: 3499.0000 - val_false_positives: 127.0000 - val_false_negatives: 294.0000
# Epoch 94/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1761 - binary_accuracy: 0.9401 - auc: 0.9838 - true_positives: 10282.0000 - true_negatives: 10242.0000 - false_positives: 669.0000 - false_negatives: 639.0000 - val_loss: 0.1585 - val_binary_accuracy: 0.9441 - val_auc: 0.9876 - val_true_positives: 3409.0000 - val_true_negatives: 3462.0000 - val_false_positives: 164.0000 - val_false_negatives: 243.0000
# Epoch 95/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1765 - binary_accuracy: 0.9389 - auc: 0.9836 - true_positives: 10250.0000 - true_negatives: 10248.0000 - false_positives: 663.0000 - false_negatives: 671.0000 - val_loss: 0.1573 - val_binary_accuracy: 0.9468 - val_auc: 0.9875 - val_true_positives: 3460.0000 - val_true_negatives: 3431.0000 - val_false_positives: 195.0000 - val_false_negatives: 192.0000
# Epoch 96/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1758 - binary_accuracy: 0.9397 - auc: 0.9839 - true_positives: 10275.0000 - true_negatives: 10241.0000 - false_positives: 670.0000 - false_negatives: 646.0000 - val_loss: 0.1586 - val_binary_accuracy: 0.9460 - val_auc: 0.9874 - val_true_positives: 3433.0000 - val_true_negatives: 3452.0000 - val_false_positives: 174.0000 - val_false_negatives: 219.0000
# Epoch 97/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1764 - binary_accuracy: 0.9384 - auc: 0.9837 - true_positives: 10242.0000 - true_negatives: 10245.0000 - false_positives: 666.0000 - false_negatives: 679.0000 - val_loss: 0.1575 - val_binary_accuracy: 0.9456 - val_auc: 0.9878 - val_true_positives: 3428.0000 - val_true_negatives: 3454.0000 - val_false_positives: 172.0000 - val_false_negatives: 224.0000
# Epoch 98/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1774 - binary_accuracy: 0.9377 - auc: 0.9835 - true_positives: 10255.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 666.0000 - val_loss: 0.1587 - val_binary_accuracy: 0.9449 - val_auc: 0.9878 - val_true_positives: 3425.0000 - val_true_negatives: 3452.0000 - val_false_positives: 174.0000 - val_false_negatives: 227.0000
# Epoch 99/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1775 - binary_accuracy: 0.9386 - auc: 0.9834 - true_positives: 10272.0000 - true_negatives: 10220.0000 - false_positives: 691.0000 - false_negatives: 649.0000 - val_loss: 0.1699 - val_binary_accuracy: 0.9383 - val_auc: 0.9875 - val_true_positives: 3319.0000 - val_true_negatives: 3510.0000 - val_false_positives: 116.0000 - val_false_negatives: 333.0000
# Epoch 100/100
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1765 - binary_accuracy: 0.9391 - auc: 0.9834 - true_positives: 10246.0000 - true_negatives: 10257.0000 - false_positives: 654.0000 - false_negatives: 675.0000 - val_loss: 0.1560 - val_binary_accuracy: 0.9457 - val_auc: 0.9878 - val_true_positives: 3477.0000 - val_true_negatives: 3406.0000 - val_false_positives: 220.0000 - val_false_negatives: 175.0000
# 2022-03-10 13:59:34.023495: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/v6.0.6/assets

# %% [markdown]
# ## Plot Prediction Distribution
# Now we plot the distribution of the assigned probabilities across the train, validation and test data. Split colours via the dataset and solid or dashed being either signal or bakground.

# %%
model = tf.keras.models.load_model(f'models/v{version}')
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()

X_test_sig = X_test[y_test == 1]
X_test_bg = X_test[y_test == 0]

X_val_sig = X_val[y_val == 1]
X_val_bg = X_val[y_val == 0]

X_train_sig = X_train[y_train == 1]
X_train_bg = X_train[y_train == 0]

tests = model.predict(X_test_sig)
vals = model.predict(X_val_sig)
trains = model.predict(X_train_sig)
testb = model.predict(X_test_bg)
valb = model.predict(X_val_bg)
trainb = model.predict(X_train_bg)

# %%
sets = [(trainb, trains), (valb, vals), (testb, tests)]
bins = np.linspace(0, 1, 41)
bin_centres = 0.5*(bins[1:] + bins[:-1])
fonts = {'fontname':'Arial'}
labs = ['Train', 'Val', 'Test']
colors = ['b', '#f40000', '#008000']

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
fig.patch.set_facecolor('#FFFFFF')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
for i, set in enumerate(sets):

    ftb = ax.hist(set[0], bins=bins, histtype='step', label=f'{labs[i]} Bg.', density=True, color=colors[i], linewidth=2)[0]
    fts = ax.hist(set[1], bins=bins, histtype='step', label=f'{labs[i]} Sg.', density=True, linestyle='dashed', color=colors[i], linewidth=2)[0]

    ax.fill_between(bins[:-1], ftb-np.sqrt(ftb), ftb+np.sqrt(ftb), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')
    ax.fill_between(bins[:-1], fts-np.sqrt(fts), fts+np.sqrt(fts), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')

ax.set_ylim(bottom=0)
plt.ylabel('Normalised Frequency', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.title(f'Prob. Dist. (NN) for Model {version}')
plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.95), ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/prob_dists/{version}_prob_dist.png')
plt.show()

# %% [markdown]
# # Punzi FOM Scan
# Now we have a model which is producing a reasonable set of predictions that are fairly stable (hence the U-shaped graph) and are common for the training, validation and test features. As such we can now evaluate the Punzi FOM across the probability space to define where our cut point should be to maximise signal selection and background rejection efficiency.

# %%
def calculate_punzi(model, labelled_data, prob_range=[0.3, 0.9], dpoints=150, significance=5, mass_range=[5200, 5800]):
    import numpy as np
    import pandas as pd
    
    probability_space = np.linspace(prob_range[0], prob_range[1], dpoints)
    # A region over which the Punzi FOM will be calculated
    
    labels = labelled_data['category'].to_numpy()
    nsignal_before = labelled_data['category'].value_counts()[1]
    # How many signal events are in the original data sample
    
    feature_cols = labelled_data.columns.to_list()
    feature_cols.remove('category')
    # Get all the columns with features and not the category
    predictions = model.predict(labelled_data[feature_cols])
    # Make predictions on the labelled data using the trained MVA model
    
    punzis = []
    for p in probability_space:
        # Iterate through each point in probability space
        
        # Each event is predicted a probability P. If P < p we say that,
        # it is background, else it is signal. I.e. p -> 1 in limit of high
        # background rejection, high purity sample 
        
        preds = np.squeeze(np.where(predictions < p, 0, 1))
        all = np.array([preds, labels]).T
        
        efficiency = len(np.squeeze(np.where((all == [1, 1]).all(axis=1)))) / nsignal_before
        # Truth matched signal i.e. model said it was signal and it actually was 
        
        background = len(np.squeeze(np.where((all == [1, 0]).all(axis=1))))
        # background you thought was signal, so did not reject i.e. it got through 
        
        #print(f'{p:.4f} {efficiency:.5f} {background}')
        # Background is how much background is left after the cut i.e. how much REAL background is left (incorrectly identified as signal)
        
        punzi = efficiency / (significance/2 + np.sqrt(background))
        # Calculate the Punzi as defined by LHCb 
        
        punzis.append(punzi)
        # Add this point to the array of Punzis
    return np.array(punzis), probability_space

# %%
test_df = X_test
test_df['category'] = y_test

val_df = X_val
val_df['category'] = y_val

train_df = X_train
train_df['category'] = y_train

# %%
p1, probs1 = calculate_punzi(model, train_df, prob_range=[0.4, 0.98], dpoints=1000)
p2, probs2 = calculate_punzi(model, val_df, prob_range=[0.4, 0.98], dpoints=1000)
p3, probs3 = calculate_punzi(model, test_df, prob_range=[0.4, 0.98], dpoints=1000)

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

fonts = {'fontname':'Arial'}

ax.scatter(probs1, p1, s=2, label='Train Punzi')
ax.scatter(probs2, p2, s=2, label='Validation Punzi')
ax.scatter(probs3, p3, s=2, label='Test Punzi')

plt.ylabel('Punzi FOM Value', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability Cut Value', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.legend(loc='upper left', ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/train_history/{version}_punzi_scan.png')
plt.show()

# %% [markdown]
# The probability cut value, $P$ says that for $P_{pred}\lt P$ it is classed as background and if it is above then it is classed as signal. This means that for very high values of $P$ we have a very high purity sample but end up throwing away most events. Conversely a low value means we keep most data at the sacrifice of more background events leaking through.
