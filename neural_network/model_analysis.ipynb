# %% [markdown]
# # Model Analysis
# Here we test different datasets made and see if they have features with stronger discriminating power. That is, the neural network can distinguish better between them. This can be a little unstable due to the nature of neural networks.

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import callbacks, layers, Sequential
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import sys
sys.path.append('../')
from dataflow import Flow

# %%
version = "6.0.5"
fname = f'../data_files/{version}'

# %% [markdown]
# ## Define the Model and get Data

# %%
data = Flow(None, None, None, csv_path=f'{fname}.csv')
df = data.get_combined_data()

# %%
custom_callbacks = [
    callbacks.EarlyStopping(patience=20, min_delta=0.0005, restore_best_weights=True), 
    callbacks.ReduceLROnPlateau(patience=5, factor=0.2, min_lr=0.001)
    ]

def compile_model(input_shape):
    model = Sequential([
        layers.Dense(16, activation='relu', input_shape=input_shape, kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(32, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['binary_accuracy', 'AUC', 'TruePositives', 'TrueNegatives', 'FalsePositives', 'FalseNegatives'])
    
    return model

# %%
def plot_history_curves(history, epochs, model_version='No version', savefig='', off=False):
    if type(history) != dict:
        history = history.history
    
    loss = history['loss']
    val_loss = history['val_loss']
    accuracy = history['binary_accuracy']
    val_accuracy = history['val_binary_accuracy']
    auc = history['auc']
    val_auc = history['val_auc']
    epoch_range = range(1, epochs+1, 1)    

    fig, ax = plt.subplots(1, 3, figsize=(22, 6))
    
    ax[0].xaxis.set_minor_locator(AutoMinorLocator())
    ax[0].yaxis.set_minor_locator(AutoMinorLocator())
    ax[1].xaxis.set_minor_locator(AutoMinorLocator())
    ax[1].yaxis.set_minor_locator(AutoMinorLocator())
    ax[2].xaxis.set_minor_locator(AutoMinorLocator())
    ax[2].yaxis.set_minor_locator(AutoMinorLocator())
    fonts = {'fontname':'Arial'}
    
    ax[0].plot(epoch_range, loss, 'r.', label='Training Loss')
    ax[0].plot(epoch_range, val_loss, 'b.', label='Validation Loss')
    ax[1].plot(epoch_range, accuracy, 'r.', label='Training Accuracy')
    ax[1].plot(epoch_range, val_accuracy, 'b.', label='Validation Accuracy')
    ax[2].plot(epoch_range, auc, 'r.', label='Training AUC')
    ax[2].plot(epoch_range, val_auc, 'b.', label='Validation AUC')
    
    
    ax[0].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[0].set_ylabel('Loss', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[1].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[1].set_ylabel('Accuracy', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[2].set_xlabel('Epoch', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
    ax[2].set_ylabel('AUC', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
    
    ax[0].legend(loc='upper right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[1].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    ax[2].legend(loc='lower right', ncol=1, fancybox=False, shadow=True, frameon=False)
    
    plt.title(model_version)
    if savefig != '':
        plt.savefig(savefig)
    if not off:
        plt.show()

def plot_history(model_version, savefig='', off=False):
    history = pickle.load(open(f'train_history/v{model_version}', "rb"))
    nepochs = len(history['loss'])
    plot_history_curves(history, nepochs, model_version, savefig, off)

# %%
def fit_model(model, train_data, val_data, model_version, callbacks=None, epochs=100, batch_size=512):
    model_history = model.fit(train_data[0], train_data[1], epochs=epochs, batch_size=batch_size, validation_data=val_data, callbacks=callbacks, verbose=1)
    with open(f'train_history/v{model_version}', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)
    model.save(f'models/v{model_version}')

# %%
def run_all(data, version):
    # Give it a list of data objects
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()
    model = compile_model((X_train.shape[1],))
    fit_model(model, (X_train, y_train), (X_val, y_val), f'{version}', callbacks=custom_callbacks)
    plot_history(f'{version}', f'../images/NeuralNetwork/train_history/{version}.png', off=True)
    history = pickle.load(open(f'train_history/v{version}', "rb"))
    # Dont plot the first 5 epochs they are dumb

# %%
run_all(data, version)
# Out:
# 2022-03-10 10:02:50.118988: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-10 10:02:50.134624: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-03-10 10:02:50.563172: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-10 10:02:50.578736: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2400145000 Hz
# Epoch 1/100
# 43/43 [==============================] - 4s 33ms/step - loss: 0.9348 - binary_accuracy: 0.7970 - auc: 0.8729 - true_positives: 9088.0000 - true_negatives: 8312.0000 - false_positives: 2599.0000 - false_negatives: 1833.0000 - val_loss: 0.9285 - val_binary_accuracy: 0.8975 - val_auc: 0.9590 - val_true_positives: 3222.0000 - val_true_negatives: 3310.0000 - val_false_positives: 316.0000 - val_false_negatives: 430.0000
# Epoch 2/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.7504 - binary_accuracy: 0.8735 - auc: 0.9394 - true_positives: 9812.0000 - true_negatives: 9259.0000 - false_positives: 1652.0000 - false_negatives: 1109.0000 - val_loss: 0.7533 - val_binary_accuracy: 0.9151 - val_auc: 0.9715 - val_true_positives: 3336.0000 - val_true_negatives: 3324.0000 - val_false_positives: 302.0000 - val_false_negatives: 316.0000
# Epoch 3/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.6552 - binary_accuracy: 0.8941 - auc: 0.9551 - true_positives: 9888.0000 - true_negatives: 9632.0000 - false_positives: 1279.0000 - false_negatives: 1033.0000 - val_loss: 0.6341 - val_binary_accuracy: 0.9200 - val_auc: 0.9752 - val_true_positives: 3395.0000 - val_true_negatives: 3301.0000 - val_false_positives: 325.0000 - val_false_negatives: 257.0000
# Epoch 4/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.5865 - binary_accuracy: 0.9039 - auc: 0.9616 - true_positives: 9946.0000 - true_negatives: 9789.0000 - false_positives: 1122.0000 - false_negatives: 975.0000 - val_loss: 0.5566 - val_binary_accuracy: 0.9195 - val_auc: 0.9770 - val_true_positives: 3451.0000 - val_true_negatives: 3241.0000 - val_false_positives: 385.0000 - val_false_negatives: 201.0000
# Epoch 5/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.5307 - binary_accuracy: 0.9074 - auc: 0.9654 - true_positives: 9977.0000 - true_negatives: 9833.0000 - false_positives: 1078.0000 - false_negatives: 944.0000 - val_loss: 0.4987 - val_binary_accuracy: 0.9235 - val_auc: 0.9778 - val_true_positives: 3407.0000 - val_true_negatives: 3314.0000 - val_false_positives: 312.0000 - val_false_negatives: 245.0000
# Epoch 6/100
# 43/43 [==============================] - 1s 25ms/step - loss: 0.4847 - binary_accuracy: 0.9128 - auc: 0.9676 - true_positives: 10006.0000 - true_negatives: 9922.0000 - false_positives: 989.0000 - false_negatives: 915.0000 - val_loss: 0.4589 - val_binary_accuracy: 0.9242 - val_auc: 0.9790 - val_true_positives: 3452.0000 - val_true_negatives: 3274.0000 - val_false_positives: 352.0000 - val_false_negatives: 200.0000
# Epoch 7/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.4446 - binary_accuracy: 0.9149 - auc: 0.9698 - true_positives: 10019.0000 - true_negatives: 9956.0000 - false_positives: 955.0000 - false_negatives: 902.0000 - val_loss: 0.4309 - val_binary_accuracy: 0.9270 - val_auc: 0.9797 - val_true_positives: 3452.0000 - val_true_negatives: 3295.0000 - val_false_positives: 331.0000 - val_false_negatives: 200.0000
# Epoch 8/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.4126 - binary_accuracy: 0.9179 - auc: 0.9709 - true_positives: 10043.0000 - true_negatives: 9996.0000 - false_positives: 915.0000 - false_negatives: 878.0000 - val_loss: 0.3965 - val_binary_accuracy: 0.9297 - val_auc: 0.9801 - val_true_positives: 3421.0000 - val_true_negatives: 3345.0000 - val_false_positives: 281.0000 - val_false_negatives: 231.0000
# Epoch 9/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.3805 - binary_accuracy: 0.9214 - auc: 0.9733 - true_positives: 10090.0000 - true_negatives: 10027.0000 - false_positives: 884.0000 - false_negatives: 831.0000 - val_loss: 0.3752 - val_binary_accuracy: 0.9288 - val_auc: 0.9809 - val_true_positives: 3459.0000 - val_true_negatives: 3301.0000 - val_false_positives: 325.0000 - val_false_negatives: 193.0000
# Epoch 10/100
# 43/43 [==============================] - 1s 24ms/step - loss: 0.3607 - binary_accuracy: 0.9219 - auc: 0.9732 - true_positives: 10096.0000 - true_negatives: 10032.0000 - false_positives: 879.0000 - false_negatives: 825.0000 - val_loss: 0.3510 - val_binary_accuracy: 0.9301 - val_auc: 0.9812 - val_true_positives: 3435.0000 - val_true_negatives: 3334.0000 - val_false_positives: 292.0000 - val_false_negatives: 217.0000
# Epoch 11/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.3392 - binary_accuracy: 0.9222 - auc: 0.9745 - true_positives: 10084.0000 - true_negatives: 10050.0000 - false_positives: 861.0000 - false_negatives: 837.0000 - val_loss: 0.3377 - val_binary_accuracy: 0.9268 - val_auc: 0.9819 - val_true_positives: 3494.0000 - val_true_negatives: 3251.0000 - val_false_positives: 375.0000 - val_false_negatives: 158.0000
# Epoch 12/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.3232 - binary_accuracy: 0.9233 - auc: 0.9747 - true_positives: 10097.0000 - true_negatives: 10061.0000 - false_positives: 850.0000 - false_negatives: 824.0000 - val_loss: 0.3350 - val_binary_accuracy: 0.9250 - val_auc: 0.9820 - val_true_positives: 3516.0000 - val_true_negatives: 3216.0000 - val_false_positives: 410.0000 - val_false_negatives: 136.0000
# Epoch 13/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.3069 - binary_accuracy: 0.9242 - auc: 0.9759 - true_positives: 10121.0000 - true_negatives: 10057.0000 - false_positives: 854.0000 - false_negatives: 800.0000 - val_loss: 0.3212 - val_binary_accuracy: 0.9309 - val_auc: 0.9822 - val_true_positives: 3474.0000 - val_true_negatives: 3301.0000 - val_false_positives: 325.0000 - val_false_negatives: 178.0000
# Epoch 14/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2946 - binary_accuracy: 0.9247 - auc: 0.9761 - true_positives: 10114.0000 - true_negatives: 10074.0000 - false_positives: 837.0000 - false_negatives: 807.0000 - val_loss: 0.3124 - val_binary_accuracy: 0.9323 - val_auc: 0.9823 - val_true_positives: 3473.0000 - val_true_negatives: 3312.0000 - val_false_positives: 314.0000 - val_false_negatives: 179.0000
# Epoch 15/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2855 - binary_accuracy: 0.9261 - auc: 0.9760 - true_positives: 10134.0000 - true_negatives: 10085.0000 - false_positives: 826.0000 - false_negatives: 787.0000 - val_loss: 0.2850 - val_binary_accuracy: 0.9306 - val_auc: 0.9827 - val_true_positives: 3487.0000 - val_true_negatives: 3286.0000 - val_false_positives: 340.0000 - val_false_negatives: 165.0000
# Epoch 16/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2769 - binary_accuracy: 0.9257 - auc: 0.9766 - true_positives: 10137.0000 - true_negatives: 10073.0000 - false_positives: 838.0000 - false_negatives: 784.0000 - val_loss: 0.2788 - val_binary_accuracy: 0.9334 - val_auc: 0.9830 - val_true_positives: 3448.0000 - val_true_negatives: 3345.0000 - val_false_positives: 281.0000 - val_false_negatives: 204.0000
# Epoch 17/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2693 - binary_accuracy: 0.9265 - auc: 0.9766 - true_positives: 10150.0000 - true_negatives: 10078.0000 - false_positives: 833.0000 - false_negatives: 771.0000 - val_loss: 0.2739 - val_binary_accuracy: 0.9365 - val_auc: 0.9832 - val_true_positives: 3394.0000 - val_true_negatives: 3422.0000 - val_false_positives: 204.0000 - val_false_negatives: 258.0000
# Epoch 18/100
# 43/43 [==============================] - 1s 26ms/step - loss: 0.2627 - binary_accuracy: 0.9270 - auc: 0.9768 - true_positives: 10126.0000 - true_negatives: 10112.0000 - false_positives: 799.0000 - false_negatives: 795.0000 - val_loss: 0.2667 - val_binary_accuracy: 0.9301 - val_auc: 0.9834 - val_true_positives: 3496.0000 - val_true_negatives: 3273.0000 - val_false_positives: 353.0000 - val_false_negatives: 156.0000
# Epoch 19/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.2553 - binary_accuracy: 0.9282 - auc: 0.9773 - true_positives: 10170.0000 - true_negatives: 10095.0000 - false_positives: 816.0000 - false_negatives: 751.0000 - val_loss: 0.2475 - val_binary_accuracy: 0.9345 - val_auc: 0.9837 - val_true_positives: 3435.0000 - val_true_negatives: 3366.0000 - val_false_positives: 260.0000 - val_false_negatives: 217.0000
# Epoch 20/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2466 - binary_accuracy: 0.9296 - auc: 0.9783 - true_positives: 10173.0000 - true_negatives: 10121.0000 - false_positives: 790.0000 - false_negatives: 748.0000 - val_loss: 0.2440 - val_binary_accuracy: 0.9339 - val_auc: 0.9841 - val_true_positives: 3465.0000 - val_true_negatives: 3332.0000 - val_false_positives: 294.0000 - val_false_negatives: 187.0000
# Epoch 21/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2431 - binary_accuracy: 0.9301 - auc: 0.9781 - true_positives: 10192.0000 - true_negatives: 10113.0000 - false_positives: 798.0000 - false_negatives: 729.0000 - val_loss: 0.2522 - val_binary_accuracy: 0.9306 - val_auc: 0.9844 - val_true_positives: 3535.0000 - val_true_negatives: 3238.0000 - val_false_positives: 388.0000 - val_false_negatives: 117.0000
# Epoch 22/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2388 - binary_accuracy: 0.9297 - auc: 0.9782 - true_positives: 10183.0000 - true_negatives: 10114.0000 - false_positives: 797.0000 - false_negatives: 738.0000 - val_loss: 0.2384 - val_binary_accuracy: 0.9336 - val_auc: 0.9843 - val_true_positives: 3488.0000 - val_true_negatives: 3307.0000 - val_false_positives: 319.0000 - val_false_negatives: 164.0000
# Epoch 23/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2341 - binary_accuracy: 0.9283 - auc: 0.9786 - true_positives: 10162.0000 - true_negatives: 10105.0000 - false_positives: 806.0000 - false_negatives: 759.0000 - val_loss: 0.2272 - val_binary_accuracy: 0.9358 - val_auc: 0.9843 - val_true_positives: 3469.0000 - val_true_negatives: 3342.0000 - val_false_positives: 284.0000 - val_false_negatives: 183.0000
# Epoch 24/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.2338 - binary_accuracy: 0.9283 - auc: 0.9782 - true_positives: 10162.0000 - true_negatives: 10105.0000 - false_positives: 806.0000 - false_negatives: 759.0000 - val_loss: 0.2300 - val_binary_accuracy: 0.9389 - val_auc: 0.9845 - val_true_positives: 3430.0000 - val_true_negatives: 3403.0000 - val_false_positives: 223.0000 - val_false_negatives: 222.0000
# Epoch 25/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2285 - binary_accuracy: 0.9297 - auc: 0.9788 - true_positives: 10184.0000 - true_negatives: 10113.0000 - false_positives: 798.0000 - false_negatives: 737.0000 - val_loss: 0.2202 - val_binary_accuracy: 0.9353 - val_auc: 0.9837 - val_true_positives: 3423.0000 - val_true_negatives: 3384.0000 - val_false_positives: 242.0000 - val_false_negatives: 229.0000
# Epoch 26/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2268 - binary_accuracy: 0.9296 - auc: 0.9787 - true_positives: 10174.0000 - true_negatives: 10121.0000 - false_positives: 790.0000 - false_negatives: 747.0000 - val_loss: 0.2097 - val_binary_accuracy: 0.9336 - val_auc: 0.9846 - val_true_positives: 3496.0000 - val_true_negatives: 3299.0000 - val_false_positives: 327.0000 - val_false_negatives: 156.0000
# Epoch 27/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2261 - binary_accuracy: 0.9293 - auc: 0.9786 - true_positives: 10162.0000 - true_negatives: 10126.0000 - false_positives: 785.0000 - false_negatives: 759.0000 - val_loss: 0.2150 - val_binary_accuracy: 0.9334 - val_auc: 0.9845 - val_true_positives: 3514.0000 - val_true_negatives: 3279.0000 - val_false_positives: 347.0000 - val_false_negatives: 138.0000
# Epoch 28/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2241 - binary_accuracy: 0.9283 - auc: 0.9785 - true_positives: 10169.0000 - true_negatives: 10097.0000 - false_positives: 814.0000 - false_negatives: 752.0000 - val_loss: 0.2209 - val_binary_accuracy: 0.9357 - val_auc: 0.9845 - val_true_positives: 3477.0000 - val_true_negatives: 3333.0000 - val_false_positives: 293.0000 - val_false_negatives: 175.0000
# Epoch 29/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2201 - binary_accuracy: 0.9307 - auc: 0.9793 - true_positives: 10192.0000 - true_negatives: 10127.0000 - false_positives: 784.0000 - false_negatives: 729.0000 - val_loss: 0.2001 - val_binary_accuracy: 0.9378 - val_auc: 0.9845 - val_true_positives: 3468.0000 - val_true_negatives: 3357.0000 - val_false_positives: 269.0000 - val_false_negatives: 184.0000
# Epoch 30/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2191 - binary_accuracy: 0.9304 - auc: 0.9790 - true_positives: 10196.0000 - true_negatives: 10116.0000 - false_positives: 795.0000 - false_negatives: 725.0000 - val_loss: 0.2000 - val_binary_accuracy: 0.9397 - val_auc: 0.9845 - val_true_positives: 3438.0000 - val_true_negatives: 3401.0000 - val_false_positives: 225.0000 - val_false_negatives: 214.0000
# Epoch 31/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2164 - binary_accuracy: 0.9316 - auc: 0.9793 - true_positives: 10193.0000 - true_negatives: 10146.0000 - false_positives: 765.0000 - false_negatives: 728.0000 - val_loss: 0.1965 - val_binary_accuracy: 0.9371 - val_auc: 0.9845 - val_true_positives: 3401.0000 - val_true_negatives: 3419.0000 - val_false_positives: 207.0000 - val_false_negatives: 251.0000
# Epoch 32/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2164 - binary_accuracy: 0.9309 - auc: 0.9792 - true_positives: 10186.0000 - true_negatives: 10138.0000 - false_positives: 773.0000 - false_negatives: 735.0000 - val_loss: 0.1943 - val_binary_accuracy: 0.9395 - val_auc: 0.9850 - val_true_positives: 3411.0000 - val_true_negatives: 3427.0000 - val_false_positives: 199.0000 - val_false_negatives: 241.0000
# Epoch 33/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2128 - binary_accuracy: 0.9304 - auc: 0.9798 - true_positives: 10174.0000 - true_negatives: 10138.0000 - false_positives: 773.0000 - false_negatives: 747.0000 - val_loss: 0.1919 - val_binary_accuracy: 0.9382 - val_auc: 0.9852 - val_true_positives: 3470.0000 - val_true_negatives: 3358.0000 - val_false_positives: 268.0000 - val_false_negatives: 182.0000
# Epoch 34/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2085 - binary_accuracy: 0.9319 - auc: 0.9805 - true_positives: 10207.0000 - true_negatives: 10138.0000 - false_positives: 773.0000 - false_negatives: 714.0000 - val_loss: 0.1967 - val_binary_accuracy: 0.9376 - val_auc: 0.9851 - val_true_positives: 3397.0000 - val_true_negatives: 3427.0000 - val_false_positives: 199.0000 - val_false_negatives: 255.0000
# Epoch 35/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2125 - binary_accuracy: 0.9318 - auc: 0.9793 - true_positives: 10197.0000 - true_negatives: 10146.0000 - false_positives: 765.0000 - false_negatives: 724.0000 - val_loss: 0.1922 - val_binary_accuracy: 0.9354 - val_auc: 0.9849 - val_true_positives: 3462.0000 - val_true_negatives: 3346.0000 - val_false_positives: 280.0000 - val_false_negatives: 190.0000
# Epoch 36/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2109 - binary_accuracy: 0.9301 - auc: 0.9797 - true_positives: 10183.0000 - true_negatives: 10124.0000 - false_positives: 787.0000 - false_negatives: 738.0000 - val_loss: 0.1906 - val_binary_accuracy: 0.9384 - val_auc: 0.9853 - val_true_positives: 3419.0000 - val_true_negatives: 3411.0000 - val_false_positives: 215.0000 - val_false_negatives: 233.0000
# Epoch 37/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2104 - binary_accuracy: 0.9300 - auc: 0.9796 - true_positives: 10169.0000 - true_negatives: 10134.0000 - false_positives: 777.0000 - false_negatives: 752.0000 - val_loss: 0.1902 - val_binary_accuracy: 0.9386 - val_auc: 0.9853 - val_true_positives: 3376.0000 - val_true_negatives: 3455.0000 - val_false_positives: 171.0000 - val_false_negatives: 276.0000
# Epoch 38/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2032 - binary_accuracy: 0.9316 - auc: 0.9811 - true_positives: 10204.0000 - true_negatives: 10135.0000 - false_positives: 776.0000 - false_negatives: 717.0000 - val_loss: 0.1866 - val_binary_accuracy: 0.9390 - val_auc: 0.9853 - val_true_positives: 3380.0000 - val_true_negatives: 3454.0000 - val_false_positives: 172.0000 - val_false_negatives: 272.0000
# Epoch 39/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.2044 - binary_accuracy: 0.9326 - auc: 0.9807 - true_positives: 10195.0000 - true_negatives: 10165.0000 - false_positives: 746.0000 - false_negatives: 726.0000 - val_loss: 0.1843 - val_binary_accuracy: 0.9401 - val_auc: 0.9852 - val_true_positives: 3449.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 203.0000
# Epoch 40/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.2047 - binary_accuracy: 0.9317 - auc: 0.9805 - true_positives: 10199.0000 - true_negatives: 10141.0000 - false_positives: 770.0000 - false_negatives: 722.0000 - val_loss: 0.1836 - val_binary_accuracy: 0.9409 - val_auc: 0.9855 - val_true_positives: 3429.0000 - val_true_negatives: 3419.0000 - val_false_positives: 207.0000 - val_false_negatives: 223.0000
# Epoch 41/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2051 - binary_accuracy: 0.9329 - auc: 0.9800 - true_positives: 10213.0000 - true_negatives: 10155.0000 - false_positives: 756.0000 - false_negatives: 708.0000 - val_loss: 0.1841 - val_binary_accuracy: 0.9369 - val_auc: 0.9855 - val_true_positives: 3493.0000 - val_true_negatives: 3326.0000 - val_false_positives: 300.0000 - val_false_negatives: 159.0000
# Epoch 42/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.2028 - binary_accuracy: 0.9319 - auc: 0.9806 - true_positives: 10197.0000 - true_negatives: 10149.0000 - false_positives: 762.0000 - false_negatives: 724.0000 - val_loss: 0.1836 - val_binary_accuracy: 0.9378 - val_auc: 0.9852 - val_true_positives: 3435.0000 - val_true_negatives: 3390.0000 - val_false_positives: 236.0000 - val_false_negatives: 217.0000
# Epoch 43/100
# 43/43 [==============================] - 1s 14ms/step - loss: 0.2031 - binary_accuracy: 0.9324 - auc: 0.9804 - true_positives: 10196.0000 - true_negatives: 10160.0000 - false_positives: 751.0000 - false_negatives: 725.0000 - val_loss: 0.1842 - val_binary_accuracy: 0.9395 - val_auc: 0.9856 - val_true_positives: 3431.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 221.0000
# Epoch 44/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.2016 - binary_accuracy: 0.9332 - auc: 0.9807 - true_positives: 10196.0000 - true_negatives: 10177.0000 - false_positives: 734.0000 - false_negatives: 725.0000 - val_loss: 0.1877 - val_binary_accuracy: 0.9397 - val_auc: 0.9850 - val_true_positives: 3411.0000 - val_true_negatives: 3428.0000 - val_false_positives: 198.0000 - val_false_negatives: 241.0000
# Epoch 45/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.2009 - binary_accuracy: 0.9326 - auc: 0.9807 - true_positives: 10188.0000 - true_negatives: 10172.0000 - false_positives: 739.0000 - false_negatives: 733.0000 - val_loss: 0.1784 - val_binary_accuracy: 0.9394 - val_auc: 0.9858 - val_true_positives: 3453.0000 - val_true_negatives: 3384.0000 - val_false_positives: 242.0000 - val_false_negatives: 199.0000
# Epoch 46/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2015 - binary_accuracy: 0.9333 - auc: 0.9801 - true_positives: 10229.0000 - true_negatives: 10147.0000 - false_positives: 764.0000 - false_negatives: 692.0000 - val_loss: 0.1806 - val_binary_accuracy: 0.9382 - val_auc: 0.9853 - val_true_positives: 3399.0000 - val_true_negatives: 3429.0000 - val_false_positives: 197.0000 - val_false_negatives: 253.0000
# Epoch 47/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.2029 - binary_accuracy: 0.9308 - auc: 0.9800 - true_positives: 10171.0000 - true_negatives: 10150.0000 - false_positives: 761.0000 - false_negatives: 750.0000 - val_loss: 0.1825 - val_binary_accuracy: 0.9382 - val_auc: 0.9853 - val_true_positives: 3435.0000 - val_true_negatives: 3393.0000 - val_false_positives: 233.0000 - val_false_negatives: 217.0000
# Epoch 48/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1983 - binary_accuracy: 0.9350 - auc: 0.9808 - true_positives: 10230.0000 - true_negatives: 10183.0000 - false_positives: 728.0000 - false_negatives: 691.0000 - val_loss: 0.1776 - val_binary_accuracy: 0.9401 - val_auc: 0.9857 - val_true_positives: 3444.0000 - val_true_negatives: 3398.0000 - val_false_positives: 228.0000 - val_false_negatives: 208.0000
# Epoch 49/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1968 - binary_accuracy: 0.9344 - auc: 0.9812 - true_positives: 10210.0000 - true_negatives: 10189.0000 - false_positives: 722.0000 - false_negatives: 711.0000 - val_loss: 0.1767 - val_binary_accuracy: 0.9391 - val_auc: 0.9858 - val_true_positives: 3449.0000 - val_true_negatives: 3386.0000 - val_false_positives: 240.0000 - val_false_negatives: 203.0000
# Epoch 50/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1985 - binary_accuracy: 0.9335 - auc: 0.9808 - true_positives: 10207.0000 - true_negatives: 10174.0000 - false_positives: 737.0000 - false_negatives: 714.0000 - val_loss: 0.1820 - val_binary_accuracy: 0.9362 - val_auc: 0.9852 - val_true_positives: 3470.0000 - val_true_negatives: 3344.0000 - val_false_positives: 282.0000 - val_false_negatives: 182.0000
# Epoch 51/100
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1989 - binary_accuracy: 0.9330 - auc: 0.9808 - true_positives: 10215.0000 - true_negatives: 10155.0000 - false_positives: 756.0000 - false_negatives: 706.0000 - val_loss: 0.1750 - val_binary_accuracy: 0.9409 - val_auc: 0.9861 - val_true_positives: 3422.0000 - val_true_negatives: 3426.0000 - val_false_positives: 200.0000 - val_false_negatives: 230.0000
# Epoch 52/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1974 - binary_accuracy: 0.9345 - auc: 0.9809 - true_positives: 10205.0000 - true_negatives: 10197.0000 - false_positives: 714.0000 - false_negatives: 716.0000 - val_loss: 0.1787 - val_binary_accuracy: 0.9394 - val_auc: 0.9856 - val_true_positives: 3452.0000 - val_true_negatives: 3385.0000 - val_false_positives: 241.0000 - val_false_negatives: 200.0000
# Epoch 53/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1975 - binary_accuracy: 0.9337 - auc: 0.9807 - true_positives: 10203.0000 - true_negatives: 10181.0000 - false_positives: 730.0000 - false_negatives: 718.0000 - val_loss: 0.1782 - val_binary_accuracy: 0.9408 - val_auc: 0.9856 - val_true_positives: 3413.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 239.0000
# Epoch 54/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1945 - binary_accuracy: 0.9337 - auc: 0.9817 - true_positives: 10201.0000 - true_negatives: 10183.0000 - false_positives: 728.0000 - false_negatives: 720.0000 - val_loss: 0.1744 - val_binary_accuracy: 0.9401 - val_auc: 0.9858 - val_true_positives: 3438.0000 - val_true_negatives: 3404.0000 - val_false_positives: 222.0000 - val_false_negatives: 214.0000
# Epoch 55/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1942 - binary_accuracy: 0.9345 - auc: 0.9814 - true_positives: 10218.0000 - true_negatives: 10184.0000 - false_positives: 727.0000 - false_negatives: 703.0000 - val_loss: 0.1739 - val_binary_accuracy: 0.9409 - val_auc: 0.9855 - val_true_positives: 3423.0000 - val_true_negatives: 3425.0000 - val_false_positives: 201.0000 - val_false_negatives: 229.0000
# Epoch 56/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1961 - binary_accuracy: 0.9331 - auc: 0.9809 - true_positives: 10210.0000 - true_negatives: 10162.0000 - false_positives: 749.0000 - false_negatives: 711.0000 - val_loss: 0.1732 - val_binary_accuracy: 0.9406 - val_auc: 0.9859 - val_true_positives: 3445.0000 - val_true_negatives: 3401.0000 - val_false_positives: 225.0000 - val_false_negatives: 207.0000
# Epoch 57/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1950 - binary_accuracy: 0.9355 - auc: 0.9812 - true_positives: 10214.0000 - true_negatives: 10209.0000 - false_positives: 702.0000 - false_negatives: 707.0000 - val_loss: 0.1737 - val_binary_accuracy: 0.9416 - val_auc: 0.9858 - val_true_positives: 3428.0000 - val_true_negatives: 3425.0000 - val_false_positives: 201.0000 - val_false_negatives: 224.0000
# Epoch 58/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1949 - binary_accuracy: 0.9350 - auc: 0.9812 - true_positives: 10201.0000 - true_negatives: 10212.0000 - false_positives: 699.0000 - false_negatives: 720.0000 - val_loss: 0.1781 - val_binary_accuracy: 0.9405 - val_auc: 0.9865 - val_true_positives: 3473.0000 - val_true_negatives: 3372.0000 - val_false_positives: 254.0000 - val_false_negatives: 179.0000
# Epoch 59/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1959 - binary_accuracy: 0.9343 - auc: 0.9809 - true_positives: 10232.0000 - true_negatives: 10166.0000 - false_positives: 745.0000 - false_negatives: 689.0000 - val_loss: 0.1712 - val_binary_accuracy: 0.9435 - val_auc: 0.9858 - val_true_positives: 3437.0000 - val_true_negatives: 3430.0000 - val_false_positives: 196.0000 - val_false_negatives: 215.0000
# Epoch 60/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1957 - binary_accuracy: 0.9344 - auc: 0.9808 - true_positives: 10207.0000 - true_negatives: 10193.0000 - false_positives: 718.0000 - false_negatives: 714.0000 - val_loss: 0.1726 - val_binary_accuracy: 0.9413 - val_auc: 0.9858 - val_true_positives: 3417.0000 - val_true_negatives: 3434.0000 - val_false_positives: 192.0000 - val_false_negatives: 235.0000
# Epoch 61/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1954 - binary_accuracy: 0.9340 - auc: 0.9810 - true_positives: 10216.0000 - true_negatives: 10174.0000 - false_positives: 737.0000 - false_negatives: 705.0000 - val_loss: 0.1738 - val_binary_accuracy: 0.9411 - val_auc: 0.9855 - val_true_positives: 3391.0000 - val_true_negatives: 3458.0000 - val_false_positives: 168.0000 - val_false_negatives: 261.0000
# Epoch 62/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1950 - binary_accuracy: 0.9330 - auc: 0.9811 - true_positives: 10192.0000 - true_negatives: 10178.0000 - false_positives: 733.0000 - false_negatives: 729.0000 - val_loss: 0.1708 - val_binary_accuracy: 0.9415 - val_auc: 0.9862 - val_true_positives: 3428.0000 - val_true_negatives: 3424.0000 - val_false_positives: 202.0000 - val_false_negatives: 224.0000
# Epoch 63/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1943 - binary_accuracy: 0.9315 - auc: 0.9814 - true_positives: 10191.0000 - true_negatives: 10145.0000 - false_positives: 766.0000 - false_negatives: 730.0000 - val_loss: 0.1709 - val_binary_accuracy: 0.9411 - val_auc: 0.9866 - val_true_positives: 3450.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 202.0000
# Epoch 64/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1940 - binary_accuracy: 0.9334 - auc: 0.9811 - true_positives: 10211.0000 - true_negatives: 10166.0000 - false_positives: 745.0000 - false_negatives: 710.0000 - val_loss: 0.1712 - val_binary_accuracy: 0.9415 - val_auc: 0.9865 - val_true_positives: 3395.0000 - val_true_negatives: 3457.0000 - val_false_positives: 169.0000 - val_false_negatives: 257.0000
# Epoch 65/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1925 - binary_accuracy: 0.9353 - auc: 0.9813 - true_positives: 10224.0000 - true_negatives: 10196.0000 - false_positives: 715.0000 - false_negatives: 697.0000 - val_loss: 0.1702 - val_binary_accuracy: 0.9408 - val_auc: 0.9862 - val_true_positives: 3405.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 247.0000
# Epoch 66/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1940 - binary_accuracy: 0.9344 - auc: 0.9809 - true_positives: 10208.0000 - true_negatives: 10191.0000 - false_positives: 720.0000 - false_negatives: 713.0000 - val_loss: 0.1701 - val_binary_accuracy: 0.9415 - val_auc: 0.9862 - val_true_positives: 3409.0000 - val_true_negatives: 3443.0000 - val_false_positives: 183.0000 - val_false_negatives: 243.0000
# Epoch 67/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1929 - binary_accuracy: 0.9353 - auc: 0.9813 - true_positives: 10228.0000 - true_negatives: 10191.0000 - false_positives: 720.0000 - false_negatives: 693.0000 - val_loss: 0.1698 - val_binary_accuracy: 0.9405 - val_auc: 0.9861 - val_true_positives: 3430.0000 - val_true_negatives: 3415.0000 - val_false_positives: 211.0000 - val_false_negatives: 222.0000
# Epoch 68/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1928 - binary_accuracy: 0.9335 - auc: 0.9814 - true_positives: 10201.0000 - true_negatives: 10179.0000 - false_positives: 732.0000 - false_negatives: 720.0000 - val_loss: 0.1713 - val_binary_accuracy: 0.9416 - val_auc: 0.9856 - val_true_positives: 3459.0000 - val_true_negatives: 3394.0000 - val_false_positives: 232.0000 - val_false_negatives: 193.0000
# Epoch 69/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1932 - binary_accuracy: 0.9331 - auc: 0.9812 - true_positives: 10225.0000 - true_negatives: 10147.0000 - false_positives: 764.0000 - false_negatives: 696.0000 - val_loss: 0.1691 - val_binary_accuracy: 0.9412 - val_auc: 0.9860 - val_true_positives: 3418.0000 - val_true_negatives: 3432.0000 - val_false_positives: 194.0000 - val_false_negatives: 234.0000
# Epoch 70/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1917 - binary_accuracy: 0.9350 - auc: 0.9814 - true_positives: 10224.0000 - true_negatives: 10188.0000 - false_positives: 723.0000 - false_negatives: 697.0000 - val_loss: 0.1721 - val_binary_accuracy: 0.9412 - val_auc: 0.9859 - val_true_positives: 3451.0000 - val_true_negatives: 3399.0000 - val_false_positives: 227.0000 - val_false_negatives: 201.0000
# Epoch 71/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1923 - binary_accuracy: 0.9347 - auc: 0.9812 - true_positives: 10201.0000 - true_negatives: 10206.0000 - false_positives: 705.0000 - false_negatives: 720.0000 - val_loss: 0.1714 - val_binary_accuracy: 0.9401 - val_auc: 0.9858 - val_true_positives: 3414.0000 - val_true_negatives: 3428.0000 - val_false_positives: 198.0000 - val_false_negatives: 238.0000
# Epoch 72/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1941 - binary_accuracy: 0.9325 - auc: 0.9808 - true_positives: 10189.0000 - true_negatives: 10169.0000 - false_positives: 742.0000 - false_negatives: 732.0000 - val_loss: 0.1692 - val_binary_accuracy: 0.9417 - val_auc: 0.9857 - val_true_positives: 3422.0000 - val_true_negatives: 3432.0000 - val_false_positives: 194.0000 - val_false_negatives: 230.0000
# Epoch 73/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1900 - binary_accuracy: 0.9354 - auc: 0.9818 - true_positives: 10216.0000 - true_negatives: 10206.0000 - false_positives: 705.0000 - false_negatives: 705.0000 - val_loss: 0.1705 - val_binary_accuracy: 0.9394 - val_auc: 0.9860 - val_true_positives: 3409.0000 - val_true_negatives: 3428.0000 - val_false_positives: 198.0000 - val_false_negatives: 243.0000
# Epoch 74/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1928 - binary_accuracy: 0.9337 - auc: 0.9812 - true_positives: 10214.0000 - true_negatives: 10171.0000 - false_positives: 740.0000 - false_negatives: 707.0000 - val_loss: 0.1722 - val_binary_accuracy: 0.9400 - val_auc: 0.9857 - val_true_positives: 3418.0000 - val_true_negatives: 3423.0000 - val_false_positives: 203.0000 - val_false_negatives: 234.0000
# Epoch 75/100
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1926 - binary_accuracy: 0.9323 - auc: 0.9812 - true_positives: 10189.0000 - true_negatives: 10164.0000 - false_positives: 747.0000 - false_negatives: 732.0000 - val_loss: 0.1685 - val_binary_accuracy: 0.9412 - val_auc: 0.9859 - val_true_positives: 3440.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 212.0000
# Epoch 76/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1916 - binary_accuracy: 0.9343 - auc: 0.9812 - true_positives: 10219.0000 - true_negatives: 10179.0000 - false_positives: 732.0000 - false_negatives: 702.0000 - val_loss: 0.1690 - val_binary_accuracy: 0.9413 - val_auc: 0.9862 - val_true_positives: 3418.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 234.0000
# Epoch 77/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1899 - binary_accuracy: 0.9336 - auc: 0.9815 - true_positives: 10193.0000 - true_negatives: 10190.0000 - false_positives: 721.0000 - false_negatives: 728.0000 - val_loss: 0.1697 - val_binary_accuracy: 0.9416 - val_auc: 0.9859 - val_true_positives: 3446.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 206.0000
# Epoch 78/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1882 - binary_accuracy: 0.9367 - auc: 0.9819 - true_positives: 10250.0000 - true_negatives: 10201.0000 - false_positives: 710.0000 - false_negatives: 671.0000 - val_loss: 0.1693 - val_binary_accuracy: 0.9427 - val_auc: 0.9859 - val_true_positives: 3416.0000 - val_true_negatives: 3445.0000 - val_false_positives: 181.0000 - val_false_negatives: 236.0000
# Epoch 79/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1882 - binary_accuracy: 0.9342 - auc: 0.9820 - true_positives: 10199.0000 - true_negatives: 10197.0000 - false_positives: 714.0000 - false_negatives: 722.0000 - val_loss: 0.1690 - val_binary_accuracy: 0.9411 - val_auc: 0.9861 - val_true_positives: 3409.0000 - val_true_negatives: 3440.0000 - val_false_positives: 186.0000 - val_false_negatives: 243.0000
# Epoch 80/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1879 - binary_accuracy: 0.9334 - auc: 0.9820 - true_positives: 10168.0000 - true_negatives: 10211.0000 - false_positives: 700.0000 - false_negatives: 753.0000 - val_loss: 0.1670 - val_binary_accuracy: 0.9442 - val_auc: 0.9862 - val_true_positives: 3460.0000 - val_true_negatives: 3412.0000 - val_false_positives: 214.0000 - val_false_negatives: 192.0000
# Epoch 81/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1893 - binary_accuracy: 0.9347 - auc: 0.9817 - true_positives: 10217.0000 - true_negatives: 10189.0000 - false_positives: 722.0000 - false_negatives: 704.0000 - val_loss: 0.1680 - val_binary_accuracy: 0.9426 - val_auc: 0.9859 - val_true_positives: 3418.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 234.0000
# Epoch 82/100
# 43/43 [==============================] - 1s 16ms/step - loss: 0.1900 - binary_accuracy: 0.9340 - auc: 0.9816 - true_positives: 10186.0000 - true_negatives: 10204.0000 - false_positives: 707.0000 - false_negatives: 735.0000 - val_loss: 0.1676 - val_binary_accuracy: 0.9411 - val_auc: 0.9860 - val_true_positives: 3420.0000 - val_true_negatives: 3429.0000 - val_false_positives: 197.0000 - val_false_negatives: 232.0000
# Epoch 83/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1880 - binary_accuracy: 0.9350 - auc: 0.9819 - true_positives: 10225.0000 - true_negatives: 10188.0000 - false_positives: 723.0000 - false_negatives: 696.0000 - val_loss: 0.1690 - val_binary_accuracy: 0.9427 - val_auc: 0.9859 - val_true_positives: 3451.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 201.0000
# Epoch 84/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1906 - binary_accuracy: 0.9349 - auc: 0.9813 - true_positives: 10205.0000 - true_negatives: 10206.0000 - false_positives: 705.0000 - false_negatives: 716.0000 - val_loss: 0.1683 - val_binary_accuracy: 0.9404 - val_auc: 0.9861 - val_true_positives: 3449.0000 - val_true_negatives: 3395.0000 - val_false_positives: 231.0000 - val_false_negatives: 203.0000
# Epoch 85/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1867 - binary_accuracy: 0.9353 - auc: 0.9823 - true_positives: 10224.0000 - true_negatives: 10195.0000 - false_positives: 716.0000 - false_negatives: 697.0000 - val_loss: 0.1674 - val_binary_accuracy: 0.9427 - val_auc: 0.9863 - val_true_positives: 3412.0000 - val_true_negatives: 3449.0000 - val_false_positives: 177.0000 - val_false_negatives: 240.0000
# Epoch 86/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1885 - binary_accuracy: 0.9335 - auc: 0.9818 - true_positives: 10174.0000 - true_negatives: 10207.0000 - false_positives: 704.0000 - false_negatives: 747.0000 - val_loss: 0.1673 - val_binary_accuracy: 0.9411 - val_auc: 0.9859 - val_true_positives: 3422.0000 - val_true_negatives: 3427.0000 - val_false_positives: 199.0000 - val_false_negatives: 230.0000
# Epoch 87/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1886 - binary_accuracy: 0.9351 - auc: 0.9820 - true_positives: 10196.0000 - true_negatives: 10220.0000 - false_positives: 691.0000 - false_negatives: 725.0000 - val_loss: 0.1666 - val_binary_accuracy: 0.9406 - val_auc: 0.9864 - val_true_positives: 3436.0000 - val_true_negatives: 3410.0000 - val_false_positives: 216.0000 - val_false_negatives: 216.0000
# Epoch 88/100
# 43/43 [==============================] - 1s 15ms/step - loss: 0.1883 - binary_accuracy: 0.9347 - auc: 0.9818 - true_positives: 10226.0000 - true_negatives: 10181.0000 - false_positives: 730.0000 - false_negatives: 695.0000 - val_loss: 0.1705 - val_binary_accuracy: 0.9394 - val_auc: 0.9860 - val_true_positives: 3371.0000 - val_true_negatives: 3466.0000 - val_false_positives: 160.0000 - val_false_negatives: 281.0000
# Epoch 89/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1881 - binary_accuracy: 0.9352 - auc: 0.9817 - true_positives: 10225.0000 - true_negatives: 10193.0000 - false_positives: 718.0000 - false_negatives: 696.0000 - val_loss: 0.1681 - val_binary_accuracy: 0.9433 - val_auc: 0.9858 - val_true_positives: 3456.0000 - val_true_negatives: 3409.0000 - val_false_positives: 217.0000 - val_false_negatives: 196.0000
# Epoch 90/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1891 - binary_accuracy: 0.9348 - auc: 0.9816 - true_positives: 10205.0000 - true_negatives: 10203.0000 - false_positives: 708.0000 - false_negatives: 716.0000 - val_loss: 0.1693 - val_binary_accuracy: 0.9401 - val_auc: 0.9858 - val_true_positives: 3433.0000 - val_true_negatives: 3409.0000 - val_false_positives: 217.0000 - val_false_negatives: 219.0000
# Epoch 91/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1901 - binary_accuracy: 0.9353 - auc: 0.9813 - true_positives: 10212.0000 - true_negatives: 10207.0000 - false_positives: 704.0000 - false_negatives: 709.0000 - val_loss: 0.1683 - val_binary_accuracy: 0.9423 - val_auc: 0.9863 - val_true_positives: 3477.0000 - val_true_negatives: 3381.0000 - val_false_positives: 245.0000 - val_false_negatives: 175.0000
# Epoch 92/100
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1908 - binary_accuracy: 0.9340 - auc: 0.9811 - true_positives: 10199.0000 - true_negatives: 10191.0000 - false_positives: 720.0000 - false_negatives: 722.0000 - val_loss: 0.1658 - val_binary_accuracy: 0.9427 - val_auc: 0.9865 - val_true_positives: 3448.0000 - val_true_negatives: 3413.0000 - val_false_positives: 213.0000 - val_false_negatives: 204.0000
# Epoch 93/100
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1891 - binary_accuracy: 0.9344 - auc: 0.9815 - true_positives: 10198.0000 - true_negatives: 10202.0000 - false_positives: 709.0000 - false_negatives: 723.0000 - val_loss: 0.1726 - val_binary_accuracy: 0.9404 - val_auc: 0.9848 - val_true_positives: 3437.0000 - val_true_negatives: 3407.0000 - val_false_positives: 219.0000 - val_false_negatives: 215.0000
# Epoch 94/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1886 - binary_accuracy: 0.9351 - auc: 0.9817 - true_positives: 10190.0000 - true_negatives: 10226.0000 - false_positives: 685.0000 - false_negatives: 731.0000 - val_loss: 0.1844 - val_binary_accuracy: 0.9379 - val_auc: 0.9845 - val_true_positives: 3482.0000 - val_true_negatives: 3344.0000 - val_false_positives: 282.0000 - val_false_negatives: 170.0000
# Epoch 95/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1889 - binary_accuracy: 0.9360 - auc: 0.9813 - true_positives: 10250.0000 - true_negatives: 10185.0000 - false_positives: 726.0000 - false_negatives: 671.0000 - val_loss: 0.1705 - val_binary_accuracy: 0.9430 - val_auc: 0.9861 - val_true_positives: 3448.0000 - val_true_negatives: 3415.0000 - val_false_positives: 211.0000 - val_false_negatives: 204.0000
# Epoch 96/100
# 43/43 [==============================] - 1s 17ms/step - loss: 0.1875 - binary_accuracy: 0.9357 - auc: 0.9817 - true_positives: 10240.0000 - true_negatives: 10188.0000 - false_positives: 723.0000 - false_negatives: 681.0000 - val_loss: 0.1699 - val_binary_accuracy: 0.9415 - val_auc: 0.9859 - val_true_positives: 3409.0000 - val_true_negatives: 3443.0000 - val_false_positives: 183.0000 - val_false_negatives: 243.0000
# Epoch 97/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1880 - binary_accuracy: 0.9346 - auc: 0.9817 - true_positives: 10227.0000 - true_negatives: 10177.0000 - false_positives: 734.0000 - false_negatives: 694.0000 - val_loss: 0.1688 - val_binary_accuracy: 0.9409 - val_auc: 0.9860 - val_true_positives: 3412.0000 - val_true_negatives: 3436.0000 - val_false_positives: 190.0000 - val_false_negatives: 240.0000
# Epoch 98/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1897 - binary_accuracy: 0.9356 - auc: 0.9814 - true_positives: 10208.0000 - true_negatives: 10217.0000 - false_positives: 694.0000 - false_negatives: 713.0000 - val_loss: 0.1676 - val_binary_accuracy: 0.9420 - val_auc: 0.9863 - val_true_positives: 3414.0000 - val_true_negatives: 3442.0000 - val_false_positives: 184.0000 - val_false_negatives: 238.0000
# Epoch 99/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1899 - binary_accuracy: 0.9337 - auc: 0.9811 - true_positives: 10206.0000 - true_negatives: 10178.0000 - false_positives: 733.0000 - false_negatives: 715.0000 - val_loss: 0.1652 - val_binary_accuracy: 0.9433 - val_auc: 0.9866 - val_true_positives: 3432.0000 - val_true_negatives: 3433.0000 - val_false_positives: 193.0000 - val_false_negatives: 220.0000
# Epoch 100/100
# 43/43 [==============================] - 1s 18ms/step - loss: 0.1899 - binary_accuracy: 0.9338 - auc: 0.9814 - true_positives: 10204.0000 - true_negatives: 10183.0000 - false_positives: 728.0000 - false_negatives: 717.0000 - val_loss: 0.1757 - val_binary_accuracy: 0.9391 - val_auc: 0.9852 - val_true_positives: 3503.0000 - val_true_negatives: 3332.0000 - val_false_positives: 294.0000 - val_false_negatives: 149.0000
# 2022-03-10 10:04:08.846887: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/v6.0.5/assets

# %% [markdown]
# ## Plot Prediction Distribution
# Now we plot the distribution of the assigned probabilities across the train, validation and test data. Split colours via the dataset and solid or dashed being either signal or bakground.

# %%
model = tf.keras.models.load_model(f'models/v{version}')
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split()

X_test_sig = X_test[y_test == 1]
X_test_bg = X_test[y_test == 0]

X_val_sig = X_val[y_val == 1]
X_val_bg = X_val[y_val == 0]

X_train_sig = X_train[y_train == 1]
X_train_bg = X_train[y_train == 0]

tests = model.predict(X_test_sig)
vals = model.predict(X_val_sig)
trains = model.predict(X_train_sig)
testb = model.predict(X_test_bg)
valb = model.predict(X_val_bg)
trainb = model.predict(X_train_bg)

# %%
sets = [(trainb, trains), (valb, vals), (testb, tests)]
bins = np.linspace(0, 1, 41)
bin_centres = 0.5*(bins[1:] + bins[:-1])
fonts = {'fontname':'Arial'}
labs = ['Train', 'Val', 'Test']
colors = ['b', '#f40000', '#008000']

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
fig.patch.set_facecolor('#FFFFFF')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
for i, set in enumerate(sets):

    ftb = ax.hist(set[0], bins=bins, histtype='step', label=f'{labs[i]} Bg.', density=True, color=colors[i], linewidth=2)[0]
    fts = ax.hist(set[1], bins=bins, histtype='step', label=f'{labs[i]} Sg.', density=True, linestyle='dashed', color=colors[i], linewidth=2)[0]

    ax.fill_between(bins[:-1], ftb-np.sqrt(ftb), ftb+np.sqrt(ftb), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')
    ax.fill_between(bins[:-1], fts-np.sqrt(fts), fts+np.sqrt(fts), alpha=0.1, color=colors[i], edgecolor=None, step='post', hatch='//')

ax.set_ylim(bottom=0)
plt.ylabel('Normalised Frequency', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.title(f'Prob. Dist. (NN) for Model {version}')
plt.legend(loc='upper center', bbox_to_anchor=(0.7, 0.95), ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/prob_dists/{version}_prob_dist.png')
plt.show()

# %% [markdown]
# # Punzi FOM Scan
# Now we have a model which is producing a reasonable set of predictions that are fairly stable (hence the U-shaped graph) and are common for the training, validation and test features. As such we can now evaluate the Punzi FOM across the probability space to define where our cut point should be to maximise signal selection and background rejection efficiency.

# %%
def calculate_punzi(model, labelled_data, prob_range=[0.3, 0.9], dpoints=150, significance=5, mass_range=[5200, 5800]):
    import numpy as np
    import pandas as pd
    
    probability_space = np.linspace(prob_range[0], prob_range[1], dpoints)
    # A region over which the Punzi FOM will be calculated
    
    labels = labelled_data['category'].to_numpy()
    nsignal_before = labelled_data['category'].value_counts()[1]
    # How many signal events are in the original data sample
    
    feature_cols = labelled_data.columns.to_list()
    feature_cols.remove('category')
    # Get all the columns with features and not the category
    predictions = model.predict(labelled_data[feature_cols])
    # Make predictions on the labelled data using the trained MVA model
    
    punzis = []
    for p in probability_space:
        # Iterate through each point in probability space
        
        # Each event is predicted a probability P. If P < p we say that,
        # it is background, else it is signal. I.e. p -> 1 in limit of high
        # background rejection, high purity sample 
        
        preds = np.squeeze(np.where(predictions < p, 0, 1))
        all = np.array([preds, labels]).T
        
        efficiency = len(np.squeeze(np.where((all == [1, 1]).all(axis=1)))) / nsignal_before
        # Truth matched signal i.e. model said it was signal and it actually was 
        
        background = len(np.squeeze(np.where((all == [1, 0]).all(axis=1))))
        # background you thought was signal, so did not reject i.e. it got through 
        
        #print(f'{p:.4f} {efficiency:.5f} {background}')
        # Background is how much background is left after the cut i.e. how much REAL background is left (incorrectly identified as signal)
        
        punzi = efficiency / (significance/2 + np.sqrt(background))
        # Calculate the Punzi as defined by LHCb 
        
        punzis.append(punzi)
        # Add this point to the array of Punzis
    return np.array(punzis), probability_space

# %%
test_df = X_test
test_df['category'] = y_test

val_df = X_val
val_df['category'] = y_val

train_df = X_train
train_df['category'] = y_train

# %%
p1, probs1 = calculate_punzi(model, train_df, prob_range=[0.4, 0.98], dpoints=1000)
p2, probs2 = calculate_punzi(model, val_df, prob_range=[0.4, 0.98], dpoints=1000)
p3, probs3 = calculate_punzi(model, test_df, prob_range=[0.4, 0.98], dpoints=1000)

fig, ax = plt.subplots(1, 1, figsize=(7, 6))
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

fonts = {'fontname':'Arial'}

ax.scatter(probs1, p1, s=2, label='Train Punzi')
ax.scatter(probs2, p2, s=2, label='Validation Punzi')
ax.scatter(probs3, p3, s=2, label='Test Punzi')

plt.ylabel('Punzi FOM Value', horizontalalignment='right', y=1.0, fontsize=14, **fonts)
plt.xlabel('Probability Cut Value', horizontalalignment='right', x=1.0, fontsize=14, **fonts)
plt.legend(loc='upper left', ncol=1, fancybox=False, shadow=True, frameon=False)
plt.savefig(f'../images/NeuralNetwork/train_history/{version}_punzi_scan.png')
plt.show()

# %% [markdown]
# The probability cut value, $P$ says that for $P_{pred}\lt P$ it is classed as background and if it is above then it is classed as signal. This means that for very high values of $P$ we have a very high purity sample but end up throwing away most events. Conversely a low value means we keep most data at the sacrifice of more background events leaking through.
