# %% [markdown]
# # Equal Event Ratio Network
# This notebook will use an equal event ratio along with the revised pre-selection criteria and suggested features from Dan and Paul. Hopefully this will vastly reduce any overfitting and massively improve generality of our model. We expect it to do worse in training because this is now a much more complex task. To speed things up we called in all the data and generated new features in the notebook reduced_feature_network and saved it as a CSV.

# %%
import pickle
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from dataflow import Flow

# %%
data = Flow(None, None, None, 'csv/preselected_pKmue_fullFeatures_unequalRatio.csv')
data.set_event_ratio(1)
data.drop_features(['p_PZ', 'p_P', 'K_PZ', 'K_P', 'K_PY', 'K_PT', 'p_PY', 'p_PT', 'L2_IPCHI2_OWNPV', 'L1_IPCHI2_OWNPV', 'Lb_L1_cc_asy_PT_0.5ConeISO',
  'Lb_L2_cc_asy_PT_0.5ConeISO', 'Lb_p_cc_asy_PT_0.5ConeISO', 'Lb_K_cc_asy_PT_0.5ConeISO',], target='all')
# Remove features called in for feature engineering

data1 = Flow(None, None, None, "csv/preselected_pKmue_fullFeatures_equalRatio.csv")

# %% [markdown]
# ## Network Architecture Setup
# We will now move onto building our network. This requires us to define a network architecture. We will use a similar architecture to what was working well with the many features from before but simplify it a little. We will monitor the accuracy, loss, AUC and ROC curves for the network as it trains. Then we can start analysing features further and see how much each impacts event selection.

# %%
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras import callbacks, layers, Sequential

# %%
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.get_train_val_test_split(0.6, 0.2, 0.2)
(X_train1, y_train1), (X_val1, y_val1), (X_test1, y_test1) = data1.get_train_val_test_split(0.6, 0.2, 0.2)

# %%
custom_callbacks = [
    callbacks.EarlyStopping(patience=20, min_delta=0.0005, restore_best_weights=True), 
    callbacks.ReduceLROnPlateau(patience=5, factor=0.2, min_lr=0.001)
    ]

def compile_model(input_shape):
    model = Sequential([
        layers.Dense(16, activation='relu', input_shape=input_shape, kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Dense(32, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Dense(64, activation='relu', kernel_regularizer=l1_l2(0.001, 0.001)),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['binary_accuracy', 'AUC', 'TruePositives', 'TrueNegatives', 'FalsePositives', 'FalseNegatives'])
    
    return model

# %% [markdown]
# ## Fitting the Model
# Now we can start training the model. I will wrap it all up in a function so we can repeatedly call the same or very similar model architecture and thus compare models easily. For example adding a few features will only chnage the first layers input shape.

# %%
def fit_model(model, train_data, val_data, model_version, callbacks=None, epochs=100, batch_size=512):
    model_history = model.fit(train_data[0], train_data[1], epochs=epochs, batch_size=batch_size, validation_data=val_data, callbacks=callbacks)
    with open(f'train_history/v{model_version}', 'wb') as file_pi:
        pickle.dump(model_history.history, file_pi)
    model.save(f'models/v{model_version}')

# %%
model = compile_model((X_train.shape[1],))
fit_model(model, (X_train, y_train), (X_val, y_val), '3.0.0', callbacks=custom_callbacks)
# Out:
# 2022-02-17 08:23:53.770922: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-17 08:23:53.788845: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-02-17 08:23:54.242850: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-02-17 08:23:54.267745: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2400145000 Hz
# Epoch 1/100
# 56/56 [==============================] - 5s 29ms/step - loss: 0.8704 - binary_accuracy: 0.8064 - auc: 0.8842 - true_positives: 11602.0000 - true_negatives: 11249.0000 - false_positives: 2908.0000 - false_negatives: 2579.0000 - val_loss: 0.9195 - val_binary_accuracy: 0.8613 - val_auc: 0.9377 - val_true_positives: 3981.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 756.0000
# Epoch 2/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.7192 - binary_accuracy: 0.8596 - auc: 0.9277 - true_positives: 12372.0000 - true_negatives: 11988.0000 - false_positives: 2169.0000 - false_negatives: 1809.0000 - val_loss: 0.7625 - val_binary_accuracy: 0.8711 - val_auc: 0.9446 - val_true_positives: 4122.0000 - val_true_negatives: 4107.0000 - val_false_positives: 603.0000 - val_false_negatives: 615.0000
# Epoch 3/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.6381 - binary_accuracy: 0.8707 - auc: 0.9363 - true_positives: 12503.0000 - true_negatives: 12172.0000 - false_positives: 1985.0000 - false_negatives: 1678.0000 - val_loss: 0.6563 - val_binary_accuracy: 0.8748 - val_auc: 0.9466 - val_true_positives: 4164.0000 - val_true_negatives: 4100.0000 - val_false_positives: 610.0000 - val_false_negatives: 573.0000
# Epoch 4/100
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5809 - binary_accuracy: 0.8739 - auc: 0.9394 - true_positives: 12552.0000 - true_negatives: 12213.0000 - false_positives: 1944.0000 - false_negatives: 1629.0000 - val_loss: 0.5877 - val_binary_accuracy: 0.8764 - val_auc: 0.9488 - val_true_positives: 4123.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 614.0000
# Epoch 5/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.5337 - binary_accuracy: 0.8746 - auc: 0.9421 - true_positives: 12575.0000 - true_negatives: 12210.0000 - false_positives: 1947.0000 - false_negatives: 1606.0000 - val_loss: 0.5317 - val_binary_accuracy: 0.8795 - val_auc: 0.9499 - val_true_positives: 4134.0000 - val_true_negatives: 4175.0000 - val_false_positives: 535.0000 - val_false_negatives: 603.0000
# Epoch 6/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.5001 - binary_accuracy: 0.8763 - auc: 0.9427 - true_positives: 12597.0000 - true_negatives: 12236.0000 - false_positives: 1921.0000 - false_negatives: 1584.0000 - val_loss: 0.5003 - val_binary_accuracy: 0.8775 - val_auc: 0.9503 - val_true_positives: 4066.0000 - val_true_negatives: 4224.0000 - val_false_positives: 486.0000 - val_false_negatives: 671.0000
# Epoch 7/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.4693 - binary_accuracy: 0.8798 - auc: 0.9442 - true_positives: 12662.0000 - true_negatives: 12271.0000 - false_positives: 1886.0000 - false_negatives: 1519.0000 - val_loss: 0.4605 - val_binary_accuracy: 0.8817 - val_auc: 0.9506 - val_true_positives: 4173.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 564.0000
# Epoch 8/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.4448 - binary_accuracy: 0.8810 - auc: 0.9446 - true_positives: 12660.0000 - true_negatives: 12305.0000 - false_positives: 1852.0000 - false_negatives: 1521.0000 - val_loss: 0.4433 - val_binary_accuracy: 0.8806 - val_auc: 0.9507 - val_true_positives: 4223.0000 - val_true_negatives: 4096.0000 - val_false_positives: 614.0000 - val_false_negatives: 514.0000
# Epoch 9/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.4237 - binary_accuracy: 0.8811 - auc: 0.9455 - true_positives: 12676.0000 - true_negatives: 12294.0000 - false_positives: 1863.0000 - false_negatives: 1505.0000 - val_loss: 0.4187 - val_binary_accuracy: 0.8821 - val_auc: 0.9511 - val_true_positives: 4185.0000 - val_true_negatives: 4148.0000 - val_false_positives: 562.0000 - val_false_negatives: 552.0000
# Epoch 10/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.4079 - binary_accuracy: 0.8798 - auc: 0.9456 - true_positives: 12633.0000 - true_negatives: 12298.0000 - false_positives: 1859.0000 - false_negatives: 1548.0000 - val_loss: 0.4213 - val_binary_accuracy: 0.8818 - val_auc: 0.9513 - val_true_positives: 4239.0000 - val_true_negatives: 4091.0000 - val_false_positives: 619.0000 - val_false_negatives: 498.0000
# Epoch 11/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.3931 - binary_accuracy: 0.8822 - auc: 0.9462 - true_positives: 12673.0000 - true_negatives: 12327.0000 - false_positives: 1830.0000 - false_negatives: 1508.0000 - val_loss: 0.4015 - val_binary_accuracy: 0.8805 - val_auc: 0.9515 - val_true_positives: 4152.0000 - val_true_negatives: 4166.0000 - val_false_positives: 544.0000 - val_false_negatives: 585.0000
# Epoch 12/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.3822 - binary_accuracy: 0.8816 - auc: 0.9461 - true_positives: 12651.0000 - true_negatives: 12332.0000 - false_positives: 1825.0000 - false_negatives: 1530.0000 - val_loss: 0.3906 - val_binary_accuracy: 0.8821 - val_auc: 0.9516 - val_true_positives: 4223.0000 - val_true_negatives: 4110.0000 - val_false_positives: 600.0000 - val_false_negatives: 514.0000
# Epoch 13/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.3688 - binary_accuracy: 0.8833 - auc: 0.9471 - true_positives: 12677.0000 - true_negatives: 12355.0000 - false_positives: 1802.0000 - false_negatives: 1504.0000 - val_loss: 0.3815 - val_binary_accuracy: 0.8812 - val_auc: 0.9519 - val_true_positives: 4138.0000 - val_true_negatives: 4187.0000 - val_false_positives: 523.0000 - val_false_negatives: 599.0000
# Epoch 14/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.3621 - binary_accuracy: 0.8832 - auc: 0.9466 - true_positives: 12677.0000 - true_negatives: 12351.0000 - false_positives: 1806.0000 - false_negatives: 1504.0000 - val_loss: 0.3661 - val_binary_accuracy: 0.8831 - val_auc: 0.9519 - val_true_positives: 4253.0000 - val_true_negatives: 4090.0000 - val_false_positives: 620.0000 - val_false_negatives: 484.0000
# Epoch 15/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3544 - binary_accuracy: 0.8820 - auc: 0.9472 - true_positives: 12648.0000 - true_negatives: 12346.0000 - false_positives: 1811.0000 - false_negatives: 1533.0000 - val_loss: 0.3623 - val_binary_accuracy: 0.8820 - val_auc: 0.9518 - val_true_positives: 4276.0000 - val_true_negatives: 4056.0000 - val_false_positives: 654.0000 - val_false_negatives: 461.0000
# Epoch 16/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3483 - binary_accuracy: 0.8816 - auc: 0.9470 - true_positives: 12685.0000 - true_negatives: 12299.0000 - false_positives: 1858.0000 - false_negatives: 1496.0000 - val_loss: 0.3721 - val_binary_accuracy: 0.8719 - val_auc: 0.9514 - val_true_positives: 3907.0000 - val_true_negatives: 4330.0000 - val_false_positives: 380.0000 - val_false_negatives: 830.0000
# Epoch 17/100
# 56/56 [==============================] - 1s 25ms/step - loss: 0.3404 - binary_accuracy: 0.8835 - auc: 0.9480 - true_positives: 12651.0000 - true_negatives: 12387.0000 - false_positives: 1770.0000 - false_negatives: 1530.0000 - val_loss: 0.3570 - val_binary_accuracy: 0.8812 - val_auc: 0.9519 - val_true_positives: 4133.0000 - val_true_negatives: 4192.0000 - val_false_positives: 518.0000 - val_false_negatives: 604.0000
# Epoch 18/100
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3370 - binary_accuracy: 0.8829 - auc: 0.9479 - true_positives: 12647.0000 - true_negatives: 12374.0000 - false_positives: 1783.0000 - false_negatives: 1534.0000 - val_loss: 0.3496 - val_binary_accuracy: 0.8794 - val_auc: 0.9518 - val_true_positives: 4057.0000 - val_true_negatives: 4251.0000 - val_false_positives: 459.0000 - val_false_negatives: 680.0000
# Epoch 19/100
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3313 - binary_accuracy: 0.8842 - auc: 0.9483 - true_positives: 12657.0000 - true_negatives: 12400.0000 - false_positives: 1757.0000 - false_negatives: 1524.0000 - val_loss: 0.3293 - val_binary_accuracy: 0.8824 - val_auc: 0.9521 - val_true_positives: 4170.0000 - val_true_negatives: 4166.0000 - val_false_positives: 544.0000 - val_false_negatives: 567.0000
# Epoch 20/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3280 - binary_accuracy: 0.8842 - auc: 0.9483 - true_positives: 12697.0000 - true_negatives: 12360.0000 - false_positives: 1797.0000 - false_negatives: 1484.0000 - val_loss: 0.3286 - val_binary_accuracy: 0.8825 - val_auc: 0.9516 - val_true_positives: 4212.0000 - val_true_negatives: 4125.0000 - val_false_positives: 585.0000 - val_false_negatives: 525.0000
# Epoch 21/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.3237 - binary_accuracy: 0.8833 - auc: 0.9488 - true_positives: 12683.0000 - true_negatives: 12347.0000 - false_positives: 1810.0000 - false_negatives: 1498.0000 - val_loss: 0.3402 - val_binary_accuracy: 0.8803 - val_auc: 0.9521 - val_true_positives: 4097.0000 - val_true_negatives: 4219.0000 - val_false_positives: 491.0000 - val_false_negatives: 640.0000
# Epoch 22/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3211 - binary_accuracy: 0.8837 - auc: 0.9489 - true_positives: 12683.0000 - true_negatives: 12360.0000 - false_positives: 1797.0000 - false_negatives: 1498.0000 - val_loss: 0.3280 - val_binary_accuracy: 0.8791 - val_auc: 0.9519 - val_true_positives: 4114.0000 - val_true_negatives: 4191.0000 - val_false_positives: 519.0000 - val_false_negatives: 623.0000
# Epoch 23/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3192 - binary_accuracy: 0.8831 - auc: 0.9486 - true_positives: 12723.0000 - true_negatives: 12301.0000 - false_positives: 1856.0000 - false_negatives: 1458.0000 - val_loss: 0.3250 - val_binary_accuracy: 0.8798 - val_auc: 0.9511 - val_true_positives: 4058.0000 - val_true_negatives: 4253.0000 - val_false_positives: 457.0000 - val_false_negatives: 679.0000
# Epoch 24/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3169 - binary_accuracy: 0.8855 - auc: 0.9488 - true_positives: 12732.0000 - true_negatives: 12360.0000 - false_positives: 1797.0000 - false_negatives: 1449.0000 - val_loss: 0.3392 - val_binary_accuracy: 0.8803 - val_auc: 0.9529 - val_true_positives: 4181.0000 - val_true_negatives: 4135.0000 - val_false_positives: 575.0000 - val_false_negatives: 556.0000
# Epoch 25/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3154 - binary_accuracy: 0.8837 - auc: 0.9488 - true_positives: 12696.0000 - true_negatives: 12345.0000 - false_positives: 1812.0000 - false_negatives: 1485.0000 - val_loss: 0.3127 - val_binary_accuracy: 0.8825 - val_auc: 0.9520 - val_true_positives: 4186.0000 - val_true_negatives: 4151.0000 - val_false_positives: 559.0000 - val_false_negatives: 551.0000
# Epoch 26/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3140 - binary_accuracy: 0.8841 - auc: 0.9488 - true_positives: 12721.0000 - true_negatives: 12332.0000 - false_positives: 1825.0000 - false_negatives: 1460.0000 - val_loss: 0.3143 - val_binary_accuracy: 0.8825 - val_auc: 0.9520 - val_true_positives: 4244.0000 - val_true_negatives: 4093.0000 - val_false_positives: 617.0000 - val_false_negatives: 493.0000
# Epoch 27/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3123 - binary_accuracy: 0.8831 - auc: 0.9488 - true_positives: 12682.0000 - true_negatives: 12344.0000 - false_positives: 1813.0000 - false_negatives: 1499.0000 - val_loss: 0.3115 - val_binary_accuracy: 0.8790 - val_auc: 0.9520 - val_true_positives: 4333.0000 - val_true_negatives: 3971.0000 - val_false_positives: 739.0000 - val_false_negatives: 404.0000
# Epoch 28/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3095 - binary_accuracy: 0.8849 - auc: 0.9493 - true_positives: 12751.0000 - true_negatives: 12325.0000 - false_positives: 1832.0000 - false_negatives: 1430.0000 - val_loss: 0.3084 - val_binary_accuracy: 0.8829 - val_auc: 0.9521 - val_true_positives: 4250.0000 - val_true_negatives: 4091.0000 - val_false_positives: 619.0000 - val_false_negatives: 487.0000
# Epoch 29/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3089 - binary_accuracy: 0.8839 - auc: 0.9493 - true_positives: 12707.0000 - true_negatives: 12342.0000 - false_positives: 1815.0000 - false_negatives: 1474.0000 - val_loss: 0.3244 - val_binary_accuracy: 0.8809 - val_auc: 0.9514 - val_true_positives: 4153.0000 - val_true_negatives: 4169.0000 - val_false_positives: 541.0000 - val_false_negatives: 584.0000
# Epoch 30/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3077 - binary_accuracy: 0.8832 - auc: 0.9494 - true_positives: 12708.0000 - true_negatives: 12321.0000 - false_positives: 1836.0000 - false_negatives: 1473.0000 - val_loss: 0.3204 - val_binary_accuracy: 0.8798 - val_auc: 0.9509 - val_true_positives: 4171.0000 - val_true_negatives: 4140.0000 - val_false_positives: 570.0000 - val_false_negatives: 566.0000
# Epoch 31/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3084 - binary_accuracy: 0.8824 - auc: 0.9489 - true_positives: 12665.0000 - true_negatives: 12341.0000 - false_positives: 1816.0000 - false_negatives: 1516.0000 - val_loss: 0.3079 - val_binary_accuracy: 0.8802 - val_auc: 0.9517 - val_true_positives: 4159.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 578.0000
# Epoch 32/100
# 56/56 [==============================] - 1s 19ms/step - loss: 0.3055 - binary_accuracy: 0.8834 - auc: 0.9496 - true_positives: 12722.0000 - true_negatives: 12312.0000 - false_positives: 1845.0000 - false_negatives: 1459.0000 - val_loss: 0.3156 - val_binary_accuracy: 0.8782 - val_auc: 0.9520 - val_true_positives: 4027.0000 - val_true_negatives: 4269.0000 - val_false_positives: 441.0000 - val_false_negatives: 710.0000
# Epoch 33/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3046 - binary_accuracy: 0.8847 - auc: 0.9496 - true_positives: 12704.0000 - true_negatives: 12367.0000 - false_positives: 1790.0000 - false_negatives: 1477.0000 - val_loss: 0.3078 - val_binary_accuracy: 0.8804 - val_auc: 0.9519 - val_true_positives: 4120.0000 - val_true_negatives: 4197.0000 - val_false_positives: 513.0000 - val_false_negatives: 617.0000
# Epoch 34/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3029 - binary_accuracy: 0.8847 - auc: 0.9499 - true_positives: 12707.0000 - true_negatives: 12363.0000 - false_positives: 1794.0000 - false_negatives: 1474.0000 - val_loss: 0.3097 - val_binary_accuracy: 0.8812 - val_auc: 0.9518 - val_true_positives: 4262.0000 - val_true_negatives: 4063.0000 - val_false_positives: 647.0000 - val_false_negatives: 475.0000
# Epoch 35/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3015 - binary_accuracy: 0.8846 - auc: 0.9503 - true_positives: 12709.0000 - true_negatives: 12360.0000 - false_positives: 1797.0000 - false_negatives: 1472.0000 - val_loss: 0.3083 - val_binary_accuracy: 0.8798 - val_auc: 0.9510 - val_true_positives: 4207.0000 - val_true_negatives: 4104.0000 - val_false_positives: 606.0000 - val_false_negatives: 530.0000
# Epoch 36/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3027 - binary_accuracy: 0.8842 - auc: 0.9496 - true_positives: 12743.0000 - true_negatives: 12313.0000 - false_positives: 1844.0000 - false_negatives: 1438.0000 - val_loss: 0.3079 - val_binary_accuracy: 0.8806 - val_auc: 0.9518 - val_true_positives: 4118.0000 - val_true_negatives: 4201.0000 - val_false_positives: 509.0000 - val_false_negatives: 619.0000
# Epoch 37/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3019 - binary_accuracy: 0.8837 - auc: 0.9499 - true_positives: 12700.0000 - true_negatives: 12342.0000 - false_positives: 1815.0000 - false_negatives: 1481.0000 - val_loss: 0.3048 - val_binary_accuracy: 0.8802 - val_auc: 0.9523 - val_true_positives: 4223.0000 - val_true_negatives: 4092.0000 - val_false_positives: 618.0000 - val_false_negatives: 514.0000
# Epoch 38/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2998 - binary_accuracy: 0.8843 - auc: 0.9504 - true_positives: 12710.0000 - true_negatives: 12350.0000 - false_positives: 1807.0000 - false_negatives: 1471.0000 - val_loss: 0.3059 - val_binary_accuracy: 0.8796 - val_auc: 0.9510 - val_true_positives: 4147.0000 - val_true_negatives: 4163.0000 - val_false_positives: 547.0000 - val_false_negatives: 590.0000
# Epoch 39/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.3006 - binary_accuracy: 0.8847 - auc: 0.9498 - true_positives: 12705.0000 - true_negatives: 12365.0000 - false_positives: 1792.0000 - false_negatives: 1476.0000 - val_loss: 0.2981 - val_binary_accuracy: 0.8808 - val_auc: 0.9524 - val_true_positives: 4121.0000 - val_true_negatives: 4200.0000 - val_false_positives: 510.0000 - val_false_negatives: 616.0000
# Epoch 40/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2996 - binary_accuracy: 0.8841 - auc: 0.9501 - true_positives: 12705.0000 - true_negatives: 12349.0000 - false_positives: 1808.0000 - false_negatives: 1476.0000 - val_loss: 0.3033 - val_binary_accuracy: 0.8773 - val_auc: 0.9525 - val_true_positives: 4014.0000 - val_true_negatives: 4274.0000 - val_false_positives: 436.0000 - val_false_negatives: 723.0000
# Epoch 41/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2997 - binary_accuracy: 0.8837 - auc: 0.9499 - true_positives: 12683.0000 - true_negatives: 12358.0000 - false_positives: 1799.0000 - false_negatives: 1498.0000 - val_loss: 0.3004 - val_binary_accuracy: 0.8809 - val_auc: 0.9520 - val_true_positives: 4249.0000 - val_true_negatives: 4073.0000 - val_false_positives: 637.0000 - val_false_negatives: 488.0000
# Epoch 42/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2999 - binary_accuracy: 0.8835 - auc: 0.9500 - true_positives: 12675.0000 - true_negatives: 12363.0000 - false_positives: 1794.0000 - false_negatives: 1506.0000 - val_loss: 0.3048 - val_binary_accuracy: 0.8776 - val_auc: 0.9522 - val_true_positives: 3975.0000 - val_true_negatives: 4316.0000 - val_false_positives: 394.0000 - val_false_negatives: 762.0000
# Epoch 43/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2995 - binary_accuracy: 0.8845 - auc: 0.9500 - true_positives: 12700.0000 - true_negatives: 12366.0000 - false_positives: 1791.0000 - false_negatives: 1481.0000 - val_loss: 0.2985 - val_binary_accuracy: 0.8801 - val_auc: 0.9520 - val_true_positives: 4109.0000 - val_true_negatives: 4205.0000 - val_false_positives: 505.0000 - val_false_negatives: 628.0000
# Epoch 44/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2998 - binary_accuracy: 0.8839 - auc: 0.9496 - true_positives: 12693.0000 - true_negatives: 12355.0000 - false_positives: 1802.0000 - false_negatives: 1488.0000 - val_loss: 0.3001 - val_binary_accuracy: 0.8806 - val_auc: 0.9524 - val_true_positives: 4120.0000 - val_true_negatives: 4199.0000 - val_false_positives: 511.0000 - val_false_negatives: 617.0000
# Epoch 45/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2989 - binary_accuracy: 0.8845 - auc: 0.9498 - true_positives: 12694.0000 - true_negatives: 12372.0000 - false_positives: 1785.0000 - false_negatives: 1487.0000 - val_loss: 0.3056 - val_binary_accuracy: 0.8824 - val_auc: 0.9521 - val_true_positives: 4291.0000 - val_true_negatives: 4045.0000 - val_false_positives: 665.0000 - val_false_negatives: 446.0000
# Epoch 46/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2979 - binary_accuracy: 0.8839 - auc: 0.9502 - true_positives: 12676.0000 - true_negatives: 12372.0000 - false_positives: 1785.0000 - false_negatives: 1505.0000 - val_loss: 0.2971 - val_binary_accuracy: 0.8817 - val_auc: 0.9520 - val_true_positives: 4175.0000 - val_true_negatives: 4154.0000 - val_false_positives: 556.0000 - val_false_negatives: 562.0000
# Epoch 47/100
# 56/56 [==============================] - 1s 20ms/step - loss: 0.2966 - binary_accuracy: 0.8853 - auc: 0.9508 - true_positives: 12719.0000 - true_negatives: 12370.0000 - false_positives: 1787.0000 - false_negatives: 1462.0000 - val_loss: 0.2993 - val_binary_accuracy: 0.8803 - val_auc: 0.9517 - val_true_positives: 4205.0000 - val_true_negatives: 4111.0000 - val_false_positives: 599.0000 - val_false_negatives: 532.0000
# Epoch 48/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2956 - binary_accuracy: 0.8862 - auc: 0.9508 - true_positives: 12740.0000 - true_negatives: 12374.0000 - false_positives: 1783.0000 - false_negatives: 1441.0000 - val_loss: 0.2978 - val_binary_accuracy: 0.8821 - val_auc: 0.9522 - val_true_positives: 4161.0000 - val_true_negatives: 4172.0000 - val_false_positives: 538.0000 - val_false_negatives: 576.0000
# Epoch 49/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2966 - binary_accuracy: 0.8850 - auc: 0.9505 - true_positives: 12700.0000 - true_negatives: 12379.0000 - false_positives: 1778.0000 - false_negatives: 1481.0000 - val_loss: 0.2946 - val_binary_accuracy: 0.8807 - val_auc: 0.9533 - val_true_positives: 4097.0000 - val_true_negatives: 4223.0000 - val_false_positives: 487.0000 - val_false_negatives: 640.0000
# Epoch 50/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2956 - binary_accuracy: 0.8849 - auc: 0.9509 - true_positives: 12677.0000 - true_negatives: 12398.0000 - false_positives: 1759.0000 - false_negatives: 1504.0000 - val_loss: 0.2975 - val_binary_accuracy: 0.8831 - val_auc: 0.9526 - val_true_positives: 4211.0000 - val_true_negatives: 4132.0000 - val_false_positives: 578.0000 - val_false_negatives: 526.0000
# Epoch 51/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2981 - binary_accuracy: 0.8847 - auc: 0.9498 - true_positives: 12690.0000 - true_negatives: 12381.0000 - false_positives: 1776.0000 - false_negatives: 1491.0000 - val_loss: 0.2977 - val_binary_accuracy: 0.8805 - val_auc: 0.9532 - val_true_positives: 4092.0000 - val_true_negatives: 4226.0000 - val_false_positives: 484.0000 - val_false_negatives: 645.0000
# Epoch 52/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2981 - binary_accuracy: 0.8853 - auc: 0.9497 - true_positives: 12675.0000 - true_negatives: 12413.0000 - false_positives: 1744.0000 - false_negatives: 1506.0000 - val_loss: 0.2989 - val_binary_accuracy: 0.8826 - val_auc: 0.9533 - val_true_positives: 4142.0000 - val_true_negatives: 4196.0000 - val_false_positives: 514.0000 - val_false_negatives: 595.0000
# Epoch 53/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2946 - binary_accuracy: 0.8844 - auc: 0.9509 - true_positives: 12710.0000 - true_negatives: 12353.0000 - false_positives: 1804.0000 - false_negatives: 1471.0000 - val_loss: 0.2976 - val_binary_accuracy: 0.8811 - val_auc: 0.9529 - val_true_positives: 4217.0000 - val_true_negatives: 4107.0000 - val_false_positives: 603.0000 - val_false_negatives: 520.0000
# Epoch 54/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2960 - binary_accuracy: 0.8845 - auc: 0.9502 - true_positives: 12686.0000 - true_negatives: 12379.0000 - false_positives: 1778.0000 - false_negatives: 1495.0000 - val_loss: 0.2971 - val_binary_accuracy: 0.8811 - val_auc: 0.9530 - val_true_positives: 4142.0000 - val_true_negatives: 4182.0000 - val_false_positives: 528.0000 - val_false_negatives: 595.0000
# Epoch 55/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2962 - binary_accuracy: 0.8853 - auc: 0.9501 - true_positives: 12729.0000 - true_negatives: 12359.0000 - false_positives: 1798.0000 - false_negatives: 1452.0000 - val_loss: 0.2968 - val_binary_accuracy: 0.8821 - val_auc: 0.9531 - val_true_positives: 4146.0000 - val_true_negatives: 4187.0000 - val_false_positives: 523.0000 - val_false_negatives: 591.0000
# Epoch 56/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2966 - binary_accuracy: 0.8845 - auc: 0.9499 - true_positives: 12671.0000 - true_negatives: 12393.0000 - false_positives: 1764.0000 - false_negatives: 1510.0000 - val_loss: 0.2922 - val_binary_accuracy: 0.8844 - val_auc: 0.9526 - val_true_positives: 4254.0000 - val_true_negatives: 4101.0000 - val_false_positives: 609.0000 - val_false_negatives: 483.0000
# Epoch 57/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2951 - binary_accuracy: 0.8861 - auc: 0.9503 - true_positives: 12727.0000 - true_negatives: 12382.0000 - false_positives: 1775.0000 - false_negatives: 1454.0000 - val_loss: 0.2946 - val_binary_accuracy: 0.8826 - val_auc: 0.9530 - val_true_positives: 4159.0000 - val_true_negatives: 4179.0000 - val_false_positives: 531.0000 - val_false_negatives: 578.0000
# Epoch 58/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2963 - binary_accuracy: 0.8853 - auc: 0.9498 - true_positives: 12711.0000 - true_negatives: 12377.0000 - false_positives: 1780.0000 - false_negatives: 1470.0000 - val_loss: 0.2902 - val_binary_accuracy: 0.8825 - val_auc: 0.9532 - val_true_positives: 4165.0000 - val_true_negatives: 4172.0000 - val_false_positives: 538.0000 - val_false_negatives: 572.0000
# Epoch 59/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2956 - binary_accuracy: 0.8851 - auc: 0.9501 - true_positives: 12703.0000 - true_negatives: 12378.0000 - false_positives: 1779.0000 - false_negatives: 1478.0000 - val_loss: 0.2973 - val_binary_accuracy: 0.8784 - val_auc: 0.9513 - val_true_positives: 4257.0000 - val_true_negatives: 4041.0000 - val_false_positives: 669.0000 - val_false_negatives: 480.0000
# Epoch 60/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2937 - binary_accuracy: 0.8854 - auc: 0.9507 - true_positives: 12734.0000 - true_negatives: 12357.0000 - false_positives: 1800.0000 - false_negatives: 1447.0000 - val_loss: 0.2944 - val_binary_accuracy: 0.8815 - val_auc: 0.9533 - val_true_positives: 4122.0000 - val_true_negatives: 4206.0000 - val_false_positives: 504.0000 - val_false_negatives: 615.0000
# Epoch 61/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2940 - binary_accuracy: 0.8843 - auc: 0.9506 - true_positives: 12696.0000 - true_negatives: 12363.0000 - false_positives: 1794.0000 - false_negatives: 1485.0000 - val_loss: 0.2912 - val_binary_accuracy: 0.8823 - val_auc: 0.9530 - val_true_positives: 4179.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 558.0000
# Epoch 62/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2923 - binary_accuracy: 0.8859 - auc: 0.9513 - true_positives: 12693.0000 - true_negatives: 12411.0000 - false_positives: 1746.0000 - false_negatives: 1488.0000 - val_loss: 0.2899 - val_binary_accuracy: 0.8829 - val_auc: 0.9529 - val_true_positives: 4200.0000 - val_true_negatives: 4141.0000 - val_false_positives: 569.0000 - val_false_negatives: 537.0000
# Epoch 63/100
# 56/56 [==============================] - 1s 25ms/step - loss: 0.2934 - binary_accuracy: 0.8839 - auc: 0.9508 - true_positives: 12668.0000 - true_negatives: 12379.0000 - false_positives: 1778.0000 - false_negatives: 1513.0000 - val_loss: 0.2940 - val_binary_accuracy: 0.8817 - val_auc: 0.9523 - val_true_positives: 4192.0000 - val_true_negatives: 4137.0000 - val_false_positives: 573.0000 - val_false_negatives: 545.0000
# Epoch 64/100
# 56/56 [==============================] - 1s 26ms/step - loss: 0.2939 - binary_accuracy: 0.8845 - auc: 0.9506 - true_positives: 12699.0000 - true_negatives: 12366.0000 - false_positives: 1791.0000 - false_negatives: 1482.0000 - val_loss: 0.2909 - val_binary_accuracy: 0.8831 - val_auc: 0.9534 - val_true_positives: 4172.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 565.0000
# Epoch 65/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2950 - binary_accuracy: 0.8850 - auc: 0.9502 - true_positives: 12701.0000 - true_negatives: 12377.0000 - false_positives: 1780.0000 - false_negatives: 1480.0000 - val_loss: 0.2957 - val_binary_accuracy: 0.8810 - val_auc: 0.9534 - val_true_positives: 4382.0000 - val_true_negatives: 3941.0000 - val_false_positives: 769.0000 - val_false_negatives: 355.0000
# Epoch 66/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2958 - binary_accuracy: 0.8852 - auc: 0.9498 - true_positives: 12732.0000 - true_negatives: 12352.0000 - false_positives: 1805.0000 - false_negatives: 1449.0000 - val_loss: 0.2961 - val_binary_accuracy: 0.8811 - val_auc: 0.9523 - val_true_positives: 4155.0000 - val_true_negatives: 4169.0000 - val_false_positives: 541.0000 - val_false_negatives: 582.0000
# Epoch 67/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2944 - binary_accuracy: 0.8851 - auc: 0.9502 - true_positives: 12731.0000 - true_negatives: 12351.0000 - false_positives: 1806.0000 - false_negatives: 1450.0000 - val_loss: 0.2946 - val_binary_accuracy: 0.8803 - val_auc: 0.9527 - val_true_positives: 4297.0000 - val_true_negatives: 4019.0000 - val_false_positives: 691.0000 - val_false_negatives: 440.0000
# Epoch 68/100
# 56/56 [==============================] - 1s 21ms/step - loss: 0.2940 - binary_accuracy: 0.8854 - auc: 0.9504 - true_positives: 12713.0000 - true_negatives: 12378.0000 - false_positives: 1779.0000 - false_negatives: 1468.0000 - val_loss: 0.2905 - val_binary_accuracy: 0.8817 - val_auc: 0.9532 - val_true_positives: 4203.0000 - val_true_negatives: 4126.0000 - val_false_positives: 584.0000 - val_false_negatives: 534.0000
# Epoch 69/100
# 56/56 [==============================] - 1s 20ms/step - loss: 0.2945 - binary_accuracy: 0.8862 - auc: 0.9504 - true_positives: 12721.0000 - true_negatives: 12393.0000 - false_positives: 1764.0000 - false_negatives: 1460.0000 - val_loss: 0.3194 - val_binary_accuracy: 0.8781 - val_auc: 0.9506 - val_true_positives: 4242.0000 - val_true_negatives: 4053.0000 - val_false_positives: 657.0000 - val_false_negatives: 495.0000
# Epoch 70/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2934 - binary_accuracy: 0.8859 - auc: 0.9506 - true_positives: 12728.0000 - true_negatives: 12376.0000 - false_positives: 1781.0000 - false_negatives: 1453.0000 - val_loss: 0.2888 - val_binary_accuracy: 0.8817 - val_auc: 0.9531 - val_true_positives: 4243.0000 - val_true_negatives: 4086.0000 - val_false_positives: 624.0000 - val_false_negatives: 494.0000
# Epoch 71/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2935 - binary_accuracy: 0.8854 - auc: 0.9505 - true_positives: 12706.0000 - true_negatives: 12384.0000 - false_positives: 1773.0000 - false_negatives: 1475.0000 - val_loss: 0.2901 - val_binary_accuracy: 0.8821 - val_auc: 0.9534 - val_true_positives: 4144.0000 - val_true_negatives: 4189.0000 - val_false_positives: 521.0000 - val_false_negatives: 593.0000
# Epoch 72/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2931 - binary_accuracy: 0.8853 - auc: 0.9507 - true_positives: 12705.0000 - true_negatives: 12383.0000 - false_positives: 1774.0000 - false_negatives: 1476.0000 - val_loss: 0.2899 - val_binary_accuracy: 0.8847 - val_auc: 0.9537 - val_true_positives: 4280.0000 - val_true_negatives: 4078.0000 - val_false_positives: 632.0000 - val_false_negatives: 457.0000
# Epoch 73/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2920 - binary_accuracy: 0.8875 - auc: 0.9510 - true_positives: 12745.0000 - true_negatives: 12406.0000 - false_positives: 1751.0000 - false_negatives: 1436.0000 - val_loss: 0.3019 - val_binary_accuracy: 0.8807 - val_auc: 0.9529 - val_true_positives: 4331.0000 - val_true_negatives: 3989.0000 - val_false_positives: 721.0000 - val_false_negatives: 406.0000
# Epoch 74/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2933 - binary_accuracy: 0.8849 - auc: 0.9506 - true_positives: 12730.0000 - true_negatives: 12345.0000 - false_positives: 1812.0000 - false_negatives: 1451.0000 - val_loss: 0.2896 - val_binary_accuracy: 0.8846 - val_auc: 0.9538 - val_true_positives: 4232.0000 - val_true_negatives: 4125.0000 - val_false_positives: 585.0000 - val_false_negatives: 505.0000
# Epoch 75/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2928 - binary_accuracy: 0.8851 - auc: 0.9508 - true_positives: 12698.0000 - true_negatives: 12383.0000 - false_positives: 1774.0000 - false_negatives: 1483.0000 - val_loss: 0.2953 - val_binary_accuracy: 0.8844 - val_auc: 0.9528 - val_true_positives: 4238.0000 - val_true_negatives: 4117.0000 - val_false_positives: 593.0000 - val_false_negatives: 499.0000
# Epoch 76/100
# 56/56 [==============================] - 1s 21ms/step - loss: 0.2928 - binary_accuracy: 0.8856 - auc: 0.9507 - true_positives: 12714.0000 - true_negatives: 12383.0000 - false_positives: 1774.0000 - false_negatives: 1467.0000 - val_loss: 0.2912 - val_binary_accuracy: 0.8806 - val_auc: 0.9534 - val_true_positives: 4119.0000 - val_true_negatives: 4200.0000 - val_false_positives: 510.0000 - val_false_negatives: 618.0000
# Epoch 77/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2932 - binary_accuracy: 0.8849 - auc: 0.9506 - true_positives: 12680.0000 - true_negatives: 12397.0000 - false_positives: 1760.0000 - false_negatives: 1501.0000 - val_loss: 0.2941 - val_binary_accuracy: 0.8825 - val_auc: 0.9535 - val_true_positives: 4137.0000 - val_true_negatives: 4200.0000 - val_false_positives: 510.0000 - val_false_negatives: 600.0000
# Epoch 78/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2934 - binary_accuracy: 0.8861 - auc: 0.9507 - true_positives: 12691.0000 - true_negatives: 12418.0000 - false_positives: 1739.0000 - false_negatives: 1490.0000 - val_loss: 0.2956 - val_binary_accuracy: 0.8784 - val_auc: 0.9529 - val_true_positives: 4364.0000 - val_true_negatives: 3934.0000 - val_false_positives: 776.0000 - val_false_negatives: 373.0000
# Epoch 79/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2928 - binary_accuracy: 0.8851 - auc: 0.9507 - true_positives: 12708.0000 - true_negatives: 12375.0000 - false_positives: 1782.0000 - false_negatives: 1473.0000 - val_loss: 0.2911 - val_binary_accuracy: 0.8827 - val_auc: 0.9531 - val_true_positives: 4194.0000 - val_true_negatives: 4145.0000 - val_false_positives: 565.0000 - val_false_negatives: 543.0000
# Epoch 80/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2920 - binary_accuracy: 0.8867 - auc: 0.9510 - true_positives: 12734.0000 - true_negatives: 12394.0000 - false_positives: 1763.0000 - false_negatives: 1447.0000 - val_loss: 0.2925 - val_binary_accuracy: 0.8825 - val_auc: 0.9527 - val_true_positives: 4189.0000 - val_true_negatives: 4148.0000 - val_false_positives: 562.0000 - val_false_negatives: 548.0000
# Epoch 81/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2926 - binary_accuracy: 0.8852 - auc: 0.9507 - true_positives: 12708.0000 - true_negatives: 12377.0000 - false_positives: 1780.0000 - false_negatives: 1473.0000 - val_loss: 0.2944 - val_binary_accuracy: 0.8822 - val_auc: 0.9525 - val_true_positives: 4304.0000 - val_true_negatives: 4030.0000 - val_false_positives: 680.0000 - val_false_negatives: 433.0000
# Epoch 82/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2927 - binary_accuracy: 0.8859 - auc: 0.9508 - true_positives: 12758.0000 - true_negatives: 12348.0000 - false_positives: 1809.0000 - false_negatives: 1423.0000 - val_loss: 0.2938 - val_binary_accuracy: 0.8827 - val_auc: 0.9531 - val_true_positives: 4203.0000 - val_true_negatives: 4136.0000 - val_false_positives: 574.0000 - val_false_negatives: 534.0000
# Epoch 83/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2931 - binary_accuracy: 0.8847 - auc: 0.9507 - true_positives: 12687.0000 - true_negatives: 12383.0000 - false_positives: 1774.0000 - false_negatives: 1494.0000 - val_loss: 0.2953 - val_binary_accuracy: 0.8801 - val_auc: 0.9527 - val_true_positives: 4108.0000 - val_true_negatives: 4206.0000 - val_false_positives: 504.0000 - val_false_negatives: 629.0000
# Epoch 84/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2928 - binary_accuracy: 0.8847 - auc: 0.9508 - true_positives: 12701.0000 - true_negatives: 12371.0000 - false_positives: 1786.0000 - false_negatives: 1480.0000 - val_loss: 0.2924 - val_binary_accuracy: 0.8849 - val_auc: 0.9528 - val_true_positives: 4247.0000 - val_true_negatives: 4113.0000 - val_false_positives: 597.0000 - val_false_negatives: 490.0000
# Epoch 85/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2928 - binary_accuracy: 0.8859 - auc: 0.9505 - true_positives: 12712.0000 - true_negatives: 12394.0000 - false_positives: 1763.0000 - false_negatives: 1469.0000 - val_loss: 0.2893 - val_binary_accuracy: 0.8820 - val_auc: 0.9531 - val_true_positives: 4167.0000 - val_true_negatives: 4165.0000 - val_false_positives: 545.0000 - val_false_negatives: 570.0000
# Epoch 86/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2929 - binary_accuracy: 0.8853 - auc: 0.9504 - true_positives: 12686.0000 - true_negatives: 12402.0000 - false_positives: 1755.0000 - false_negatives: 1495.0000 - val_loss: 0.2916 - val_binary_accuracy: 0.8836 - val_auc: 0.9531 - val_true_positives: 4233.0000 - val_true_negatives: 4114.0000 - val_false_positives: 596.0000 - val_false_negatives: 504.0000
# Epoch 87/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2931 - binary_accuracy: 0.8838 - auc: 0.9504 - true_positives: 12719.0000 - true_negatives: 12327.0000 - false_positives: 1830.0000 - false_negatives: 1462.0000 - val_loss: 0.2901 - val_binary_accuracy: 0.8826 - val_auc: 0.9532 - val_true_positives: 4212.0000 - val_true_negatives: 4126.0000 - val_false_positives: 584.0000 - val_false_negatives: 525.0000
# Epoch 88/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2918 - binary_accuracy: 0.8853 - auc: 0.9509 - true_positives: 12692.0000 - true_negatives: 12395.0000 - false_positives: 1762.0000 - false_negatives: 1489.0000 - val_loss: 0.2982 - val_binary_accuracy: 0.8838 - val_auc: 0.9531 - val_true_positives: 4277.0000 - val_true_negatives: 4072.0000 - val_false_positives: 638.0000 - val_false_negatives: 460.0000
# Epoch 89/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2924 - binary_accuracy: 0.8849 - auc: 0.9508 - true_positives: 12727.0000 - true_negatives: 12349.0000 - false_positives: 1808.0000 - false_negatives: 1454.0000 - val_loss: 0.2928 - val_binary_accuracy: 0.8800 - val_auc: 0.9525 - val_true_positives: 4114.0000 - val_true_negatives: 4199.0000 - val_false_positives: 511.0000 - val_false_negatives: 623.0000
# Epoch 90/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2928 - binary_accuracy: 0.8839 - auc: 0.9507 - true_positives: 12683.0000 - true_negatives: 12365.0000 - false_positives: 1792.0000 - false_negatives: 1498.0000 - val_loss: 0.2923 - val_binary_accuracy: 0.8829 - val_auc: 0.9519 - val_true_positives: 4194.0000 - val_true_negatives: 4147.0000 - val_false_positives: 563.0000 - val_false_negatives: 543.0000
# 2022-02-17 08:25:22.892869: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/v3.0.0/assets

# %%
model1 = compile_model((X_train1.shape[1],))
fit_model(model1, (X_train1, y_train1), (X_val1, y_val1), '3.0.1', callbacks=custom_callbacks)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 4s 27ms/step - loss: 0.8276 - binary_accuracy: 0.8270 - auc: 0.9041 - true_positives: 12095.0000 - true_negatives: 11340.0000 - false_positives: 2817.0000 - false_negatives: 2086.0000 - val_loss: 0.8942 - val_binary_accuracy: 0.8695 - val_auc: 0.9441 - val_true_positives: 4150.0000 - val_true_negatives: 4064.0000 - val_false_positives: 646.0000 - val_false_negatives: 587.0000
# Epoch 2/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.6804 - binary_accuracy: 0.8705 - auc: 0.9381 - true_positives: 12514.0000 - true_negatives: 12155.0000 - false_positives: 2002.0000 - false_negatives: 1667.0000 - val_loss: 0.7255 - val_binary_accuracy: 0.8804 - val_auc: 0.9521 - val_true_positives: 4322.0000 - val_true_negatives: 3995.0000 - val_false_positives: 715.0000 - val_false_negatives: 415.0000
# Epoch 3/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5982 - binary_accuracy: 0.8807 - auc: 0.9449 - true_positives: 12668.0000 - true_negatives: 12288.0000 - false_positives: 1869.0000 - false_negatives: 1513.0000 - val_loss: 0.6167 - val_binary_accuracy: 0.8877 - val_auc: 0.9563 - val_true_positives: 4324.0000 - val_true_negatives: 4062.0000 - val_false_positives: 648.0000 - val_false_negatives: 413.0000
# Epoch 4/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5361 - binary_accuracy: 0.8846 - auc: 0.9493 - true_positives: 12669.0000 - true_negatives: 12400.0000 - false_positives: 1757.0000 - false_negatives: 1512.0000 - val_loss: 0.5436 - val_binary_accuracy: 0.8916 - val_auc: 0.9583 - val_true_positives: 4327.0000 - val_true_negatives: 4096.0000 - val_false_positives: 614.0000 - val_false_negatives: 410.0000
# Epoch 5/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.4899 - binary_accuracy: 0.8881 - auc: 0.9517 - true_positives: 12731.0000 - true_negatives: 12437.0000 - false_positives: 1720.0000 - false_negatives: 1450.0000 - val_loss: 0.4931 - val_binary_accuracy: 0.8933 - val_auc: 0.9597 - val_true_positives: 4314.0000 - val_true_negatives: 4125.0000 - val_false_positives: 585.0000 - val_false_negatives: 423.0000
# Epoch 6/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.4546 - binary_accuracy: 0.8895 - auc: 0.9531 - true_positives: 12740.0000 - true_negatives: 12466.0000 - false_positives: 1691.0000 - false_negatives: 1441.0000 - val_loss: 0.4558 - val_binary_accuracy: 0.8939 - val_auc: 0.9603 - val_true_positives: 4327.0000 - val_true_negatives: 4118.0000 - val_false_positives: 592.0000 - val_false_negatives: 410.0000
# Epoch 7/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4263 - binary_accuracy: 0.8871 - auc: 0.9541 - true_positives: 12697.0000 - true_negatives: 12443.0000 - false_positives: 1714.0000 - false_negatives: 1484.0000 - val_loss: 0.4241 - val_binary_accuracy: 0.8950 - val_auc: 0.9605 - val_true_positives: 4284.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 453.0000
# Epoch 8/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3990 - binary_accuracy: 0.8921 - auc: 0.9557 - true_positives: 12786.0000 - true_negatives: 12493.0000 - false_positives: 1664.0000 - false_negatives: 1395.0000 - val_loss: 0.4095 - val_binary_accuracy: 0.8955 - val_auc: 0.9609 - val_true_positives: 4268.0000 - val_true_negatives: 4192.0000 - val_false_positives: 518.0000 - val_false_negatives: 469.0000
# Epoch 9/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3810 - binary_accuracy: 0.8915 - auc: 0.9560 - true_positives: 12750.0000 - true_negatives: 12514.0000 - false_positives: 1643.0000 - false_negatives: 1431.0000 - val_loss: 0.3980 - val_binary_accuracy: 0.8929 - val_auc: 0.9606 - val_true_positives: 4280.0000 - val_true_negatives: 4155.0000 - val_false_positives: 555.0000 - val_false_negatives: 457.0000
# Epoch 10/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3645 - binary_accuracy: 0.8924 - auc: 0.9565 - true_positives: 12802.0000 - true_negatives: 12486.0000 - false_positives: 1671.0000 - false_negatives: 1379.0000 - val_loss: 0.3928 - val_binary_accuracy: 0.8947 - val_auc: 0.9617 - val_true_positives: 4281.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 456.0000
# Epoch 11/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3520 - binary_accuracy: 0.8941 - auc: 0.9566 - true_positives: 12801.0000 - true_negatives: 12537.0000 - false_positives: 1620.0000 - false_negatives: 1380.0000 - val_loss: 0.3739 - val_binary_accuracy: 0.8950 - val_auc: 0.9621 - val_true_positives: 4317.0000 - val_true_negatives: 4138.0000 - val_false_positives: 572.0000 - val_false_negatives: 420.0000
# Epoch 12/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3390 - binary_accuracy: 0.8933 - auc: 0.9574 - true_positives: 12836.0000 - true_negatives: 12477.0000 - false_positives: 1680.0000 - false_negatives: 1345.0000 - val_loss: 0.3567 - val_binary_accuracy: 0.8926 - val_auc: 0.9615 - val_true_positives: 4339.0000 - val_true_negatives: 4093.0000 - val_false_positives: 617.0000 - val_false_negatives: 398.0000
# Epoch 13/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3284 - binary_accuracy: 0.8945 - auc: 0.9579 - true_positives: 12818.0000 - true_negatives: 12530.0000 - false_positives: 1627.0000 - false_negatives: 1363.0000 - val_loss: 0.3454 - val_binary_accuracy: 0.8939 - val_auc: 0.9620 - val_true_positives: 4318.0000 - val_true_negatives: 4127.0000 - val_false_positives: 583.0000 - val_false_negatives: 419.0000
# Epoch 14/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3205 - binary_accuracy: 0.8963 - auc: 0.9581 - true_positives: 12844.0000 - true_negatives: 12556.0000 - false_positives: 1601.0000 - false_negatives: 1337.0000 - val_loss: 0.3223 - val_binary_accuracy: 0.8947 - val_auc: 0.9622 - val_true_positives: 4274.0000 - val_true_negatives: 4178.0000 - val_false_positives: 532.0000 - val_false_negatives: 463.0000
# Epoch 15/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3155 - binary_accuracy: 0.8947 - auc: 0.9575 - true_positives: 12832.0000 - true_negatives: 12523.0000 - false_positives: 1634.0000 - false_negatives: 1349.0000 - val_loss: 0.3440 - val_binary_accuracy: 0.8936 - val_auc: 0.9619 - val_true_positives: 4180.0000 - val_true_negatives: 4262.0000 - val_false_positives: 448.0000 - val_false_negatives: 557.0000
# Epoch 16/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3119 - binary_accuracy: 0.8930 - auc: 0.9572 - true_positives: 12809.0000 - true_negatives: 12496.0000 - false_positives: 1661.0000 - false_negatives: 1372.0000 - val_loss: 0.3087 - val_binary_accuracy: 0.8955 - val_auc: 0.9622 - val_true_positives: 4196.0000 - val_true_negatives: 4264.0000 - val_false_positives: 446.0000 - val_false_negatives: 541.0000
# Epoch 17/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3044 - binary_accuracy: 0.8955 - auc: 0.9582 - true_positives: 12834.0000 - true_negatives: 12544.0000 - false_positives: 1613.0000 - false_negatives: 1347.0000 - val_loss: 0.3102 - val_binary_accuracy: 0.8934 - val_auc: 0.9620 - val_true_positives: 4350.0000 - val_true_negatives: 4090.0000 - val_false_positives: 620.0000 - val_false_negatives: 387.0000
# Epoch 18/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3008 - binary_accuracy: 0.8947 - auc: 0.9582 - true_positives: 12828.0000 - true_negatives: 12527.0000 - false_positives: 1630.0000 - false_negatives: 1353.0000 - val_loss: 0.3078 - val_binary_accuracy: 0.8931 - val_auc: 0.9620 - val_true_positives: 4331.0000 - val_true_negatives: 4106.0000 - val_false_positives: 604.0000 - val_false_negatives: 406.0000
# Epoch 19/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2950 - binary_accuracy: 0.8942 - auc: 0.9589 - true_positives: 12817.0000 - true_negatives: 12524.0000 - false_positives: 1633.0000 - false_negatives: 1364.0000 - val_loss: 0.3226 - val_binary_accuracy: 0.8948 - val_auc: 0.9622 - val_true_positives: 4336.0000 - val_true_negatives: 4117.0000 - val_false_positives: 593.0000 - val_false_negatives: 401.0000
# Epoch 20/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2932 - binary_accuracy: 0.8944 - auc: 0.9587 - true_positives: 12850.0000 - true_negatives: 12495.0000 - false_positives: 1662.0000 - false_negatives: 1331.0000 - val_loss: 0.3193 - val_binary_accuracy: 0.8929 - val_auc: 0.9613 - val_true_positives: 4105.0000 - val_true_negatives: 4330.0000 - val_false_positives: 380.0000 - val_false_negatives: 632.0000
# Epoch 21/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2926 - binary_accuracy: 0.8948 - auc: 0.9580 - true_positives: 12811.0000 - true_negatives: 12545.0000 - false_positives: 1612.0000 - false_negatives: 1370.0000 - val_loss: 0.3221 - val_binary_accuracy: 0.8965 - val_auc: 0.9622 - val_true_positives: 4240.0000 - val_true_negatives: 4229.0000 - val_false_positives: 481.0000 - val_false_negatives: 497.0000
# Epoch 22/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2905 - binary_accuracy: 0.8942 - auc: 0.9580 - true_positives: 12831.0000 - true_negatives: 12508.0000 - false_positives: 1649.0000 - false_negatives: 1350.0000 - val_loss: 0.2860 - val_binary_accuracy: 0.8950 - val_auc: 0.9622 - val_true_positives: 4214.0000 - val_true_negatives: 4241.0000 - val_false_positives: 469.0000 - val_false_negatives: 523.0000
# Epoch 23/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2891 - binary_accuracy: 0.8942 - auc: 0.9578 - true_positives: 12838.0000 - true_negatives: 12502.0000 - false_positives: 1655.0000 - false_negatives: 1343.0000 - val_loss: 0.2920 - val_binary_accuracy: 0.8973 - val_auc: 0.9626 - val_true_positives: 4203.0000 - val_true_negatives: 4274.0000 - val_false_positives: 436.0000 - val_false_negatives: 534.0000
# Epoch 24/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2863 - binary_accuracy: 0.8960 - auc: 0.9582 - true_positives: 12866.0000 - true_negatives: 12526.0000 - false_positives: 1631.0000 - false_negatives: 1315.0000 - val_loss: 0.2886 - val_binary_accuracy: 0.8945 - val_auc: 0.9627 - val_true_positives: 4361.0000 - val_true_negatives: 4089.0000 - val_false_positives: 621.0000 - val_false_negatives: 376.0000
# Epoch 25/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2844 - binary_accuracy: 0.8945 - auc: 0.9584 - true_positives: 12863.0000 - true_negatives: 12484.0000 - false_positives: 1673.0000 - false_negatives: 1318.0000 - val_loss: 0.2955 - val_binary_accuracy: 0.8952 - val_auc: 0.9623 - val_true_positives: 4155.0000 - val_true_negatives: 4302.0000 - val_false_positives: 408.0000 - val_false_negatives: 582.0000
# Epoch 26/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2821 - binary_accuracy: 0.8954 - auc: 0.9588 - true_positives: 12842.0000 - true_negatives: 12532.0000 - false_positives: 1625.0000 - false_negatives: 1339.0000 - val_loss: 0.2761 - val_binary_accuracy: 0.8951 - val_auc: 0.9629 - val_true_positives: 4269.0000 - val_true_negatives: 4187.0000 - val_false_positives: 523.0000 - val_false_negatives: 468.0000
# Epoch 27/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2806 - binary_accuracy: 0.8943 - auc: 0.9588 - true_positives: 12852.0000 - true_negatives: 12490.0000 - false_positives: 1667.0000 - false_negatives: 1329.0000 - val_loss: 0.2756 - val_binary_accuracy: 0.8948 - val_auc: 0.9623 - val_true_positives: 4297.0000 - val_true_negatives: 4156.0000 - val_false_positives: 554.0000 - val_false_negatives: 440.0000
# Epoch 28/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2789 - binary_accuracy: 0.8955 - auc: 0.9592 - true_positives: 12871.0000 - true_negatives: 12506.0000 - false_positives: 1651.0000 - false_negatives: 1310.0000 - val_loss: 0.2812 - val_binary_accuracy: 0.8946 - val_auc: 0.9622 - val_true_positives: 4205.0000 - val_true_negatives: 4246.0000 - val_false_positives: 464.0000 - val_false_negatives: 532.0000
# Epoch 29/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2783 - binary_accuracy: 0.8967 - auc: 0.9591 - true_positives: 12895.0000 - true_negatives: 12516.0000 - false_positives: 1641.0000 - false_negatives: 1286.0000 - val_loss: 0.2763 - val_binary_accuracy: 0.8955 - val_auc: 0.9630 - val_true_positives: 4184.0000 - val_true_negatives: 4276.0000 - val_false_positives: 434.0000 - val_false_negatives: 553.0000
# Epoch 30/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2769 - binary_accuracy: 0.8950 - auc: 0.9593 - true_positives: 12852.0000 - true_negatives: 12510.0000 - false_positives: 1647.0000 - false_negatives: 1329.0000 - val_loss: 0.2858 - val_binary_accuracy: 0.8964 - val_auc: 0.9635 - val_true_positives: 4172.0000 - val_true_negatives: 4296.0000 - val_false_positives: 414.0000 - val_false_negatives: 565.0000
# Epoch 31/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2783 - binary_accuracy: 0.8940 - auc: 0.9587 - true_positives: 12852.0000 - true_negatives: 12482.0000 - false_positives: 1675.0000 - false_negatives: 1329.0000 - val_loss: 0.2778 - val_binary_accuracy: 0.8959 - val_auc: 0.9628 - val_true_positives: 4191.0000 - val_true_negatives: 4273.0000 - val_false_positives: 437.0000 - val_false_negatives: 546.0000
# Epoch 32/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.2765 - binary_accuracy: 0.8950 - auc: 0.9590 - true_positives: 12861.0000 - true_negatives: 12502.0000 - false_positives: 1655.0000 - false_negatives: 1320.0000 - val_loss: 0.2809 - val_binary_accuracy: 0.8946 - val_auc: 0.9631 - val_true_positives: 4386.0000 - val_true_negatives: 4065.0000 - val_false_positives: 645.0000 - val_false_negatives: 351.0000
# Epoch 33/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2766 - binary_accuracy: 0.8948 - auc: 0.9589 - true_positives: 12892.0000 - true_negatives: 12464.0000 - false_positives: 1693.0000 - false_negatives: 1289.0000 - val_loss: 0.3017 - val_binary_accuracy: 0.8958 - val_auc: 0.9621 - val_true_positives: 4228.0000 - val_true_negatives: 4235.0000 - val_false_positives: 475.0000 - val_false_negatives: 509.0000
# Epoch 34/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2748 - binary_accuracy: 0.8963 - auc: 0.9591 - true_positives: 12890.0000 - true_negatives: 12508.0000 - false_positives: 1649.0000 - false_negatives: 1291.0000 - val_loss: 0.2724 - val_binary_accuracy: 0.8976 - val_auc: 0.9629 - val_true_positives: 4280.0000 - val_true_negatives: 4200.0000 - val_false_positives: 510.0000 - val_false_negatives: 457.0000
# Epoch 35/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2732 - binary_accuracy: 0.8969 - auc: 0.9596 - true_positives: 12893.0000 - true_negatives: 12523.0000 - false_positives: 1634.0000 - false_negatives: 1288.0000 - val_loss: 0.2749 - val_binary_accuracy: 0.8956 - val_auc: 0.9629 - val_true_positives: 4189.0000 - val_true_negatives: 4272.0000 - val_false_positives: 438.0000 - val_false_negatives: 548.0000
# Epoch 36/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2733 - binary_accuracy: 0.8972 - auc: 0.9593 - true_positives: 12883.0000 - true_negatives: 12541.0000 - false_positives: 1616.0000 - false_negatives: 1298.0000 - val_loss: 0.2655 - val_binary_accuracy: 0.8952 - val_auc: 0.9630 - val_true_positives: 4315.0000 - val_true_negatives: 4142.0000 - val_false_positives: 568.0000 - val_false_negatives: 422.0000
# Epoch 37/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2714 - binary_accuracy: 0.8975 - auc: 0.9599 - true_positives: 12928.0000 - true_negatives: 12506.0000 - false_positives: 1651.0000 - false_negatives: 1253.0000 - val_loss: 0.2702 - val_binary_accuracy: 0.8954 - val_auc: 0.9628 - val_true_positives: 4172.0000 - val_true_negatives: 4287.0000 - val_false_positives: 423.0000 - val_false_negatives: 565.0000
# Epoch 38/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2721 - binary_accuracy: 0.8952 - auc: 0.9596 - true_positives: 12884.0000 - true_negatives: 12485.0000 - false_positives: 1672.0000 - false_negatives: 1297.0000 - val_loss: 0.2749 - val_binary_accuracy: 0.8949 - val_auc: 0.9624 - val_true_positives: 4305.0000 - val_true_negatives: 4149.0000 - val_false_positives: 561.0000 - val_false_negatives: 432.0000
# Epoch 39/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2729 - binary_accuracy: 0.8959 - auc: 0.9593 - true_positives: 12890.0000 - true_negatives: 12497.0000 - false_positives: 1660.0000 - false_negatives: 1291.0000 - val_loss: 0.2664 - val_binary_accuracy: 0.8959 - val_auc: 0.9633 - val_true_positives: 4235.0000 - val_true_negatives: 4229.0000 - val_false_positives: 481.0000 - val_false_negatives: 502.0000
# Epoch 40/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.2727 - binary_accuracy: 0.8964 - auc: 0.9591 - true_positives: 12887.0000 - true_negatives: 12516.0000 - false_positives: 1641.0000 - false_negatives: 1294.0000 - val_loss: 0.2685 - val_binary_accuracy: 0.8985 - val_auc: 0.9631 - val_true_positives: 4258.0000 - val_true_negatives: 4230.0000 - val_false_positives: 480.0000 - val_false_negatives: 479.0000
# Epoch 41/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2709 - binary_accuracy: 0.8966 - auc: 0.9596 - true_positives: 12895.0000 - true_negatives: 12513.0000 - false_positives: 1644.0000 - false_negatives: 1286.0000 - val_loss: 0.2656 - val_binary_accuracy: 0.8961 - val_auc: 0.9622 - val_true_positives: 4242.0000 - val_true_negatives: 4223.0000 - val_false_positives: 487.0000 - val_false_negatives: 495.0000
# Epoch 42/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2726 - binary_accuracy: 0.8958 - auc: 0.9590 - true_positives: 12851.0000 - true_negatives: 12533.0000 - false_positives: 1624.0000 - false_negatives: 1330.0000 - val_loss: 0.2803 - val_binary_accuracy: 0.8974 - val_auc: 0.9635 - val_true_positives: 4307.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 430.0000
# Epoch 43/100
# 56/56 [==============================] - 1s 19ms/step - loss: 0.2717 - binary_accuracy: 0.8944 - auc: 0.9594 - true_positives: 12840.0000 - true_negatives: 12505.0000 - false_positives: 1652.0000 - false_negatives: 1341.0000 - val_loss: 0.2718 - val_binary_accuracy: 0.8934 - val_auc: 0.9622 - val_true_positives: 4197.0000 - val_true_negatives: 4243.0000 - val_false_positives: 467.0000 - val_false_negatives: 540.0000
# Epoch 44/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2704 - binary_accuracy: 0.8964 - auc: 0.9597 - true_positives: 12880.0000 - true_negatives: 12522.0000 - false_positives: 1635.0000 - false_negatives: 1301.0000 - val_loss: 0.2655 - val_binary_accuracy: 0.8949 - val_auc: 0.9621 - val_true_positives: 4263.0000 - val_true_negatives: 4191.0000 - val_false_positives: 519.0000 - val_false_negatives: 474.0000
# Epoch 45/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2721 - binary_accuracy: 0.8944 - auc: 0.9592 - true_positives: 12846.0000 - true_negatives: 12500.0000 - false_positives: 1657.0000 - false_negatives: 1335.0000 - val_loss: 0.2624 - val_binary_accuracy: 0.8976 - val_auc: 0.9632 - val_true_positives: 4214.0000 - val_true_negatives: 4266.0000 - val_false_positives: 444.0000 - val_false_negatives: 523.0000
# Epoch 46/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2706 - binary_accuracy: 0.8949 - auc: 0.9594 - true_positives: 12858.0000 - true_negatives: 12503.0000 - false_positives: 1654.0000 - false_negatives: 1323.0000 - val_loss: 0.2643 - val_binary_accuracy: 0.8974 - val_auc: 0.9628 - val_true_positives: 4202.0000 - val_true_negatives: 4276.0000 - val_false_positives: 434.0000 - val_false_negatives: 535.0000
# Epoch 47/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2703 - binary_accuracy: 0.8959 - auc: 0.9594 - true_positives: 12875.0000 - true_negatives: 12512.0000 - false_positives: 1645.0000 - false_negatives: 1306.0000 - val_loss: 0.2739 - val_binary_accuracy: 0.8955 - val_auc: 0.9618 - val_true_positives: 4255.0000 - val_true_negatives: 4205.0000 - val_false_positives: 505.0000 - val_false_negatives: 482.0000
# Epoch 48/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.2690 - binary_accuracy: 0.8966 - auc: 0.9598 - true_positives: 12889.0000 - true_negatives: 12518.0000 - false_positives: 1639.0000 - false_negatives: 1292.0000 - val_loss: 0.2620 - val_binary_accuracy: 0.8964 - val_auc: 0.9635 - val_true_positives: 4221.0000 - val_true_negatives: 4247.0000 - val_false_positives: 463.0000 - val_false_negatives: 516.0000
# Epoch 49/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2698 - binary_accuracy: 0.8956 - auc: 0.9595 - true_positives: 12899.0000 - true_negatives: 12481.0000 - false_positives: 1676.0000 - false_negatives: 1282.0000 - val_loss: 0.2695 - val_binary_accuracy: 0.8932 - val_auc: 0.9624 - val_true_positives: 4127.0000 - val_true_negatives: 4311.0000 - val_false_positives: 399.0000 - val_false_negatives: 610.0000
# Epoch 50/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2690 - binary_accuracy: 0.8963 - auc: 0.9597 - true_positives: 12883.0000 - true_negatives: 12516.0000 - false_positives: 1641.0000 - false_negatives: 1298.0000 - val_loss: 0.2709 - val_binary_accuracy: 0.8948 - val_auc: 0.9632 - val_true_positives: 4130.0000 - val_true_negatives: 4323.0000 - val_false_positives: 387.0000 - val_false_negatives: 607.0000
# Epoch 51/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2684 - binary_accuracy: 0.8952 - auc: 0.9599 - true_positives: 12852.0000 - true_negatives: 12517.0000 - false_positives: 1640.0000 - false_negatives: 1329.0000 - val_loss: 0.2683 - val_binary_accuracy: 0.8938 - val_auc: 0.9621 - val_true_positives: 4139.0000 - val_true_negatives: 4305.0000 - val_false_positives: 405.0000 - val_false_negatives: 598.0000
# Epoch 52/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2688 - binary_accuracy: 0.8954 - auc: 0.9597 - true_positives: 12839.0000 - true_negatives: 12536.0000 - false_positives: 1621.0000 - false_negatives: 1342.0000 - val_loss: 0.2698 - val_binary_accuracy: 0.8908 - val_auc: 0.9607 - val_true_positives: 4298.0000 - val_true_negatives: 4117.0000 - val_false_positives: 593.0000 - val_false_negatives: 439.0000
# Epoch 53/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2707 - binary_accuracy: 0.8961 - auc: 0.9589 - true_positives: 12897.0000 - true_negatives: 12496.0000 - false_positives: 1661.0000 - false_negatives: 1284.0000 - val_loss: 0.2686 - val_binary_accuracy: 0.8948 - val_auc: 0.9616 - val_true_positives: 4255.0000 - val_true_negatives: 4198.0000 - val_false_positives: 512.0000 - val_false_negatives: 482.0000
# Epoch 54/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2679 - binary_accuracy: 0.8958 - auc: 0.9599 - true_positives: 12873.0000 - true_negatives: 12511.0000 - false_positives: 1646.0000 - false_negatives: 1308.0000 - val_loss: 0.2627 - val_binary_accuracy: 0.8966 - val_auc: 0.9632 - val_true_positives: 4186.0000 - val_true_negatives: 4284.0000 - val_false_positives: 426.0000 - val_false_negatives: 551.0000
# Epoch 55/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2671 - binary_accuracy: 0.8966 - auc: 0.9601 - true_positives: 12871.0000 - true_negatives: 12537.0000 - false_positives: 1620.0000 - false_negatives: 1310.0000 - val_loss: 0.2639 - val_binary_accuracy: 0.8932 - val_auc: 0.9629 - val_true_positives: 4402.0000 - val_true_negatives: 4036.0000 - val_false_positives: 674.0000 - val_false_negatives: 335.0000
# Epoch 56/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2681 - binary_accuracy: 0.8959 - auc: 0.9595 - true_positives: 12932.0000 - true_negatives: 12457.0000 - false_positives: 1700.0000 - false_negatives: 1249.0000 - val_loss: 0.2703 - val_binary_accuracy: 0.8950 - val_auc: 0.9623 - val_true_positives: 4239.0000 - val_true_negatives: 4216.0000 - val_false_positives: 494.0000 - val_false_negatives: 498.0000
# Epoch 57/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2690 - binary_accuracy: 0.8950 - auc: 0.9593 - true_positives: 12867.0000 - true_negatives: 12496.0000 - false_positives: 1661.0000 - false_negatives: 1314.0000 - val_loss: 0.2650 - val_binary_accuracy: 0.8995 - val_auc: 0.9631 - val_true_positives: 4262.0000 - val_true_negatives: 4236.0000 - val_false_positives: 474.0000 - val_false_negatives: 475.0000
# Epoch 58/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2695 - binary_accuracy: 0.8948 - auc: 0.9592 - true_positives: 12881.0000 - true_negatives: 12475.0000 - false_positives: 1682.0000 - false_negatives: 1300.0000 - val_loss: 0.2627 - val_binary_accuracy: 0.8966 - val_auc: 0.9627 - val_true_positives: 4272.0000 - val_true_negatives: 4198.0000 - val_false_positives: 512.0000 - val_false_negatives: 465.0000
# Epoch 59/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2679 - binary_accuracy: 0.8960 - auc: 0.9597 - true_positives: 12870.0000 - true_negatives: 12520.0000 - false_positives: 1637.0000 - false_negatives: 1311.0000 - val_loss: 0.2595 - val_binary_accuracy: 0.8975 - val_auc: 0.9629 - val_true_positives: 4248.0000 - val_true_negatives: 4231.0000 - val_false_positives: 479.0000 - val_false_negatives: 489.0000
# Epoch 60/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2669 - binary_accuracy: 0.8966 - auc: 0.9599 - true_positives: 12874.0000 - true_negatives: 12533.0000 - false_positives: 1624.0000 - false_negatives: 1307.0000 - val_loss: 0.2800 - val_binary_accuracy: 0.8945 - val_auc: 0.9628 - val_true_positives: 4427.0000 - val_true_negatives: 4023.0000 - val_false_positives: 687.0000 - val_false_negatives: 310.0000
# Epoch 61/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2668 - binary_accuracy: 0.8953 - auc: 0.9599 - true_positives: 12881.0000 - true_negatives: 12491.0000 - false_positives: 1666.0000 - false_negatives: 1300.0000 - val_loss: 0.2613 - val_binary_accuracy: 0.8981 - val_auc: 0.9634 - val_true_positives: 4244.0000 - val_true_negatives: 4240.0000 - val_false_positives: 470.0000 - val_false_negatives: 493.0000
# Epoch 62/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2662 - binary_accuracy: 0.8963 - auc: 0.9601 - true_positives: 12878.0000 - true_negatives: 12522.0000 - false_positives: 1635.0000 - false_negatives: 1303.0000 - val_loss: 0.2589 - val_binary_accuracy: 0.8979 - val_auc: 0.9633 - val_true_positives: 4246.0000 - val_true_negatives: 4236.0000 - val_false_positives: 474.0000 - val_false_negatives: 491.0000
# Epoch 63/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2672 - binary_accuracy: 0.8962 - auc: 0.9597 - true_positives: 12873.0000 - true_negatives: 12523.0000 - false_positives: 1634.0000 - false_negatives: 1308.0000 - val_loss: 0.2622 - val_binary_accuracy: 0.8979 - val_auc: 0.9629 - val_true_positives: 4311.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 426.0000
# Epoch 64/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2678 - binary_accuracy: 0.8967 - auc: 0.9596 - true_positives: 12900.0000 - true_negatives: 12512.0000 - false_positives: 1645.0000 - false_negatives: 1281.0000 - val_loss: 0.2655 - val_binary_accuracy: 0.8953 - val_auc: 0.9621 - val_true_positives: 4197.0000 - val_true_negatives: 4261.0000 - val_false_positives: 449.0000 - val_false_negatives: 540.0000
# Epoch 65/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2657 - binary_accuracy: 0.8964 - auc: 0.9602 - true_positives: 12880.0000 - true_negatives: 12521.0000 - false_positives: 1636.0000 - false_negatives: 1301.0000 - val_loss: 0.2606 - val_binary_accuracy: 0.8957 - val_auc: 0.9631 - val_true_positives: 4160.0000 - val_true_negatives: 4302.0000 - val_false_positives: 408.0000 - val_false_negatives: 577.0000
# Epoch 66/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2679 - binary_accuracy: 0.8955 - auc: 0.9595 - true_positives: 12860.0000 - true_negatives: 12518.0000 - false_positives: 1639.0000 - false_negatives: 1321.0000 - val_loss: 0.2585 - val_binary_accuracy: 0.8971 - val_auc: 0.9632 - val_true_positives: 4221.0000 - val_true_negatives: 4254.0000 - val_false_positives: 456.0000 - val_false_negatives: 516.0000
# Epoch 67/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2682 - binary_accuracy: 0.8961 - auc: 0.9593 - true_positives: 12882.0000 - true_negatives: 12513.0000 - false_positives: 1644.0000 - false_negatives: 1299.0000 - val_loss: 0.2616 - val_binary_accuracy: 0.8969 - val_auc: 0.9626 - val_true_positives: 4258.0000 - val_true_negatives: 4215.0000 - val_false_positives: 495.0000 - val_false_negatives: 479.0000
# Epoch 68/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2654 - binary_accuracy: 0.8973 - auc: 0.9604 - true_positives: 12879.0000 - true_negatives: 12550.0000 - false_positives: 1607.0000 - false_negatives: 1302.0000 - val_loss: 0.2619 - val_binary_accuracy: 0.8973 - val_auc: 0.9635 - val_true_positives: 4306.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 431.0000
# Epoch 69/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2659 - binary_accuracy: 0.8972 - auc: 0.9601 - true_positives: 12886.0000 - true_negatives: 12539.0000 - false_positives: 1618.0000 - false_negatives: 1295.0000 - val_loss: 0.2587 - val_binary_accuracy: 0.8957 - val_auc: 0.9639 - val_true_positives: 4382.0000 - val_true_negatives: 4080.0000 - val_false_positives: 630.0000 - val_false_negatives: 355.0000
# Epoch 70/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2672 - binary_accuracy: 0.8961 - auc: 0.9596 - true_positives: 12885.0000 - true_negatives: 12509.0000 - false_positives: 1648.0000 - false_negatives: 1296.0000 - val_loss: 0.2633 - val_binary_accuracy: 0.8949 - val_auc: 0.9615 - val_true_positives: 4235.0000 - val_true_negatives: 4219.0000 - val_false_positives: 491.0000 - val_false_negatives: 502.0000
# Epoch 71/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2663 - binary_accuracy: 0.8970 - auc: 0.9598 - true_positives: 12867.0000 - true_negatives: 12553.0000 - false_positives: 1604.0000 - false_negatives: 1314.0000 - val_loss: 0.2642 - val_binary_accuracy: 0.8974 - val_auc: 0.9629 - val_true_positives: 4289.0000 - val_true_negatives: 4189.0000 - val_false_positives: 521.0000 - val_false_negatives: 448.0000
# Epoch 72/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2646 - binary_accuracy: 0.8976 - auc: 0.9604 - true_positives: 12883.0000 - true_negatives: 12553.0000 - false_positives: 1604.0000 - false_negatives: 1298.0000 - val_loss: 0.2590 - val_binary_accuracy: 0.8969 - val_auc: 0.9630 - val_true_positives: 4389.0000 - val_true_negatives: 4084.0000 - val_false_positives: 626.0000 - val_false_negatives: 348.0000
# Epoch 73/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2655 - binary_accuracy: 0.8955 - auc: 0.9601 - true_positives: 12849.0000 - true_negatives: 12527.0000 - false_positives: 1630.0000 - false_negatives: 1332.0000 - val_loss: 0.2604 - val_binary_accuracy: 0.8949 - val_auc: 0.9626 - val_true_positives: 4307.0000 - val_true_negatives: 4147.0000 - val_false_positives: 563.0000 - val_false_negatives: 430.0000
# Epoch 74/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2652 - binary_accuracy: 0.8973 - auc: 0.9601 - true_positives: 12901.0000 - true_negatives: 12528.0000 - false_positives: 1629.0000 - false_negatives: 1280.0000 - val_loss: 0.2665 - val_binary_accuracy: 0.8917 - val_auc: 0.9620 - val_true_positives: 4446.0000 - val_true_negatives: 3978.0000 - val_false_positives: 732.0000 - val_false_negatives: 291.0000
# Epoch 75/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2649 - binary_accuracy: 0.8963 - auc: 0.9602 - true_positives: 12950.0000 - true_negatives: 12449.0000 - false_positives: 1708.0000 - false_negatives: 1231.0000 - val_loss: 0.2559 - val_binary_accuracy: 0.8967 - val_auc: 0.9638 - val_true_positives: 4219.0000 - val_true_negatives: 4252.0000 - val_false_positives: 458.0000 - val_false_negatives: 518.0000
# Epoch 76/100
# 56/56 [==============================] - 1s 18ms/step - loss: 0.2656 - binary_accuracy: 0.8965 - auc: 0.9600 - true_positives: 12881.0000 - true_negatives: 12523.0000 - false_positives: 1634.0000 - false_negatives: 1300.0000 - val_loss: 0.2577 - val_binary_accuracy: 0.8970 - val_auc: 0.9630 - val_true_positives: 4300.0000 - val_true_negatives: 4174.0000 - val_false_positives: 536.0000 - val_false_negatives: 437.0000
# Epoch 77/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2660 - binary_accuracy: 0.8960 - auc: 0.9599 - true_positives: 12903.0000 - true_negatives: 12487.0000 - false_positives: 1670.0000 - false_negatives: 1278.0000 - val_loss: 0.2729 - val_binary_accuracy: 0.8926 - val_auc: 0.9620 - val_true_positives: 4422.0000 - val_true_negatives: 4010.0000 - val_false_positives: 700.0000 - val_false_negatives: 315.0000
# Epoch 78/100
# 56/56 [==============================] - 1s 19ms/step - loss: 0.2652 - binary_accuracy: 0.8973 - auc: 0.9603 - true_positives: 12927.0000 - true_negatives: 12500.0000 - false_positives: 1657.0000 - false_negatives: 1254.0000 - val_loss: 0.2602 - val_binary_accuracy: 0.8970 - val_auc: 0.9633 - val_true_positives: 4248.0000 - val_true_negatives: 4226.0000 - val_false_positives: 484.0000 - val_false_negatives: 489.0000
# Epoch 79/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2674 - binary_accuracy: 0.8948 - auc: 0.9593 - true_positives: 12864.0000 - true_negatives: 12494.0000 - false_positives: 1663.0000 - false_negatives: 1317.0000 - val_loss: 0.2644 - val_binary_accuracy: 0.8964 - val_auc: 0.9625 - val_true_positives: 4313.0000 - val_true_negatives: 4155.0000 - val_false_positives: 555.0000 - val_false_negatives: 424.0000
# Epoch 80/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2664 - binary_accuracy: 0.8979 - auc: 0.9597 - true_positives: 12915.0000 - true_negatives: 12530.0000 - false_positives: 1627.0000 - false_negatives: 1266.0000 - val_loss: 0.2555 - val_binary_accuracy: 0.8977 - val_auc: 0.9639 - val_true_positives: 4247.0000 - val_true_negatives: 4234.0000 - val_false_positives: 476.0000 - val_false_negatives: 490.0000
# Epoch 81/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2662 - binary_accuracy: 0.8959 - auc: 0.9599 - true_positives: 12897.0000 - true_negatives: 12490.0000 - false_positives: 1667.0000 - false_negatives: 1284.0000 - val_loss: 0.2621 - val_binary_accuracy: 0.8971 - val_auc: 0.9635 - val_true_positives: 4304.0000 - val_true_negatives: 4171.0000 - val_false_positives: 539.0000 - val_false_negatives: 433.0000
# Epoch 82/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2650 - binary_accuracy: 0.8959 - auc: 0.9602 - true_positives: 12875.0000 - true_negatives: 12512.0000 - false_positives: 1645.0000 - false_negatives: 1306.0000 - val_loss: 0.2605 - val_binary_accuracy: 0.8952 - val_auc: 0.9636 - val_true_positives: 4440.0000 - val_true_negatives: 4017.0000 - val_false_positives: 693.0000 - val_false_negatives: 297.0000
# Epoch 83/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2669 - binary_accuracy: 0.8966 - auc: 0.9596 - true_positives: 12910.0000 - true_negatives: 12497.0000 - false_positives: 1660.0000 - false_negatives: 1271.0000 - val_loss: 0.2615 - val_binary_accuracy: 0.8932 - val_auc: 0.9631 - val_true_positives: 4411.0000 - val_true_negatives: 4027.0000 - val_false_positives: 683.0000 - val_false_negatives: 326.0000
# Epoch 84/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2648 - binary_accuracy: 0.8979 - auc: 0.9600 - true_positives: 12949.0000 - true_negatives: 12495.0000 - false_positives: 1662.0000 - false_negatives: 1232.0000 - val_loss: 0.2597 - val_binary_accuracy: 0.8961 - val_auc: 0.9631 - val_true_positives: 4278.0000 - val_true_negatives: 4187.0000 - val_false_positives: 523.0000 - val_false_negatives: 459.0000
# Epoch 85/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2662 - binary_accuracy: 0.8966 - auc: 0.9597 - true_positives: 12869.0000 - true_negatives: 12538.0000 - false_positives: 1619.0000 - false_negatives: 1312.0000 - val_loss: 0.2610 - val_binary_accuracy: 0.8935 - val_auc: 0.9630 - val_true_positives: 4363.0000 - val_true_negatives: 4078.0000 - val_false_positives: 632.0000 - val_false_negatives: 374.0000
# Epoch 86/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2649 - binary_accuracy: 0.8966 - auc: 0.9603 - true_positives: 12896.0000 - true_negatives: 12512.0000 - false_positives: 1645.0000 - false_negatives: 1285.0000 - val_loss: 0.2606 - val_binary_accuracy: 0.8964 - val_auc: 0.9628 - val_true_positives: 4317.0000 - val_true_negatives: 4151.0000 - val_false_positives: 559.0000 - val_false_negatives: 420.0000
# Epoch 87/100
# 56/56 [==============================] - 1s 16ms/step - loss: 0.2656 - binary_accuracy: 0.8968 - auc: 0.9599 - true_positives: 12905.0000 - true_negatives: 12509.0000 - false_positives: 1648.0000 - false_negatives: 1276.0000 - val_loss: 0.2619 - val_binary_accuracy: 0.8957 - val_auc: 0.9619 - val_true_positives: 4304.0000 - val_true_negatives: 4158.0000 - val_false_positives: 552.0000 - val_false_negatives: 433.0000
# Epoch 88/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2646 - binary_accuracy: 0.8970 - auc: 0.9602 - true_positives: 12885.0000 - true_negatives: 12535.0000 - false_positives: 1622.0000 - false_negatives: 1296.0000 - val_loss: 0.2563 - val_binary_accuracy: 0.8998 - val_auc: 0.9636 - val_true_positives: 4290.0000 - val_true_negatives: 4210.0000 - val_false_positives: 500.0000 - val_false_negatives: 447.0000
# Epoch 89/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2652 - binary_accuracy: 0.8960 - auc: 0.9600 - true_positives: 12898.0000 - true_negatives: 12493.0000 - false_positives: 1664.0000 - false_negatives: 1283.0000 - val_loss: 0.2572 - val_binary_accuracy: 0.8975 - val_auc: 0.9635 - val_true_positives: 4256.0000 - val_true_negatives: 4223.0000 - val_false_positives: 487.0000 - val_false_negatives: 481.0000
# Epoch 90/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2661 - binary_accuracy: 0.8962 - auc: 0.9597 - true_positives: 12891.0000 - true_negatives: 12505.0000 - false_positives: 1652.0000 - false_negatives: 1290.0000 - val_loss: 0.2635 - val_binary_accuracy: 0.8945 - val_auc: 0.9620 - val_true_positives: 4313.0000 - val_true_negatives: 4137.0000 - val_false_positives: 573.0000 - val_false_negatives: 424.0000
# Epoch 91/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2660 - binary_accuracy: 0.8957 - auc: 0.9598 - true_positives: 12866.0000 - true_negatives: 12515.0000 - false_positives: 1642.0000 - false_negatives: 1315.0000 - val_loss: 0.2579 - val_binary_accuracy: 0.8961 - val_auc: 0.9631 - val_true_positives: 4318.0000 - val_true_negatives: 4147.0000 - val_false_positives: 563.0000 - val_false_negatives: 419.0000
# Epoch 92/100
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2652 - binary_accuracy: 0.8973 - auc: 0.9600 - true_positives: 12927.0000 - true_negatives: 12501.0000 - false_positives: 1656.0000 - false_negatives: 1254.0000 - val_loss: 0.2565 - val_binary_accuracy: 0.8979 - val_auc: 0.9640 - val_true_positives: 4218.0000 - val_true_negatives: 4264.0000 - val_false_positives: 446.0000 - val_false_negatives: 519.0000
# Epoch 93/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2658 - binary_accuracy: 0.8953 - auc: 0.9599 - true_positives: 12880.0000 - true_negatives: 12491.0000 - false_positives: 1666.0000 - false_negatives: 1301.0000 - val_loss: 0.2611 - val_binary_accuracy: 0.8943 - val_auc: 0.9622 - val_true_positives: 4252.0000 - val_true_negatives: 4196.0000 - val_false_positives: 514.0000 - val_false_negatives: 485.0000
# Epoch 94/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.2654 - binary_accuracy: 0.8974 - auc: 0.9600 - true_positives: 12893.0000 - true_negatives: 12537.0000 - false_positives: 1620.0000 - false_negatives: 1288.0000 - val_loss: 0.2683 - val_binary_accuracy: 0.8908 - val_auc: 0.9605 - val_true_positives: 4361.0000 - val_true_negatives: 4054.0000 - val_false_positives: 656.0000 - val_false_negatives: 376.0000
# Epoch 95/100
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2665 - binary_accuracy: 0.8951 - auc: 0.9597 - true_positives: 12884.0000 - true_negatives: 12481.0000 - false_positives: 1676.0000 - false_negatives: 1297.0000 - val_loss: 0.2649 - val_binary_accuracy: 0.8932 - val_auc: 0.9636 - val_true_positives: 4114.0000 - val_true_negatives: 4324.0000 - val_false_positives: 386.0000 - val_false_negatives: 623.0000
# INFO:tensorflow:Assets written to: models/v3.0.1/assets

# %%
def plot_history_curves(history, epochs, model_version='No version'):
    if type(history) != dict:
        history = history.history
    
    loss = history['loss']
    val_loss = history['val_loss']
    accuracy = history['binary_accuracy']
    val_accuracy = history['val_binary_accuracy']
    auc = history['auc']
    val_auc = history['val_auc']
    epoch_range = range(1, epochs+1, 1)    

    fig, ax = plt.subplots(1, 3, figsize=(22, 6))
    ax[0].plot(epoch_range, loss, 'r.', label='Training Loss')
    ax[0].plot(epoch_range, val_loss, 'b.', label='Validation Loss')
    ax[1].plot(epoch_range, accuracy, 'r.', label='Training Accuracy')
    ax[1].plot(epoch_range, val_accuracy, 'b.', label='Validation Accuracy')
    ax[2].plot(epoch_range, auc, 'r.', label='Training AUC')
    ax[2].plot(epoch_range, val_auc, 'b.', label='Validation AUC')
    ax[0].legend()
    ax[1].legend()
    ax[2].legend()
    plt.title(model_version)
    plt.legend(frameon=False)
    plt.show()

def plot_history(model_version):
    history = pickle.load(open(f'train_history/v{model_version}', "rb"))
    nepochs = len(history['loss'])
    plot_history_curves(history, nepochs, model_version)

# %%
plot_history('3.0.0')
plot_history('3.0.1')

# %% [markdown]
# ## Restricted Sidebands
# Now we will investigate by further reducing our dataset size by restricting the mass region of the background sideband we include in our data.
