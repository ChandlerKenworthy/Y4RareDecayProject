# %% [markdown]
# # Exploring ROOT Tuples
# This notebook will use the examples given by Dan in his notebook and play around and look at some other variables. This could be considered 'having a play'. The first part of this is to ensure we are using the lb-dog kernel and then import all the necessary libaries.

# %%
import uproot as up
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import os
import sys
import copy
import loadCutPlot as lcp

# %% [markdown]
# ## Reading in the Tuple
# Firstly we need to read in the tuple. We define the fileLoc variable to be the absolute path to this file. Maybe this is less redundant but resolves some complexities for now.

# %%
fName="/disk/moose/lhcb/djdt/Lb2L1520mueTuples/MC/2016MD/100FilesCheck/job185-CombDVntuple-15314000-MC2016MD_100F-pKmue-MC.root"

# %% [markdown]
# Now we can open the file in the standard way. Note that using the with keyword is reccomended on the UpRoot documentation.

# %%
with up.open(fName) as f:
    print(f.keys())
# Out:
# ['DTT1520me;1', 'DTT1520me/DecayTree;1']

# %% [markdown]
# Now we look at some different branches within the DTT1520me/DecayTree tree. That is all the keys associated with said tree.

# %%
with up.open(fName + ":DTT1520me/DecayTree") as f:
    # print(f.keys())
    print(f.show())
    # It is better to use f.show() as this provides some *much needed* formatting.
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# Lb_MINIP             | double                   | AsDtype('>f8')
# Lb_MINIPCHI2         | double                   | AsDtype('>f8')
# Lb_MINIPNEXTBEST     | double                   | AsDtype('>f8')
# Lb_MINIPCHI2NEXTBEST | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_X       | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_Y       | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_Z       | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_XERR    | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_YERR    | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_ZERR    | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_CHI2    | double                   | AsDtype('>f8')
# Lb_ENDVERTEX_NDOF    | int32_t                  | AsDtype('>i4')
# Lb_ENDVERTEX_COV_    | float[3][3]              | AsDtype("('>f4', (3, 3))")
# Lb_OWNPV_X           | double                   | AsDtype('>f8')
# Lb_OWNPV_Y           | double                   | AsDtype('>f8')
# Lb_OWNPV_Z           | double                   | AsDtype('>f8')
# Lb_OWNPV_XERR        | double                   | AsDtype('>f8')
# Lb_OWNPV_YERR        | double                   | AsDtype('>f8')
# Lb_OWNPV_ZERR        | double                   | AsDtype('>f8')
# Lb_OWNPV_CHI2        | double                   | AsDtype('>f8')
# Lb_OWNPV_NDOF        | int32_t                  | AsDtype('>i4')
# Lb_OWNPV_COV_        | float[3][3]              | AsDtype("('>f4', (3, 3))")
# Lb_IP_OWNPV          | double                   | AsDtype('>f8')
# Lb_IPCHI2_OWNPV      | double                   | AsDtype('>f8')
# Lb_FD_OWNPV          | double                   | AsDtype('>f8')
# Lb_FDCHI2_OWNPV      | double                   | AsDtype('>f8')
# Lb_DIRA_OWNPV        | double                   | AsDtype('>f8')
# Lb_TOPPV_X           | double                   | AsDtype('>f8')
# Lb_TOPPV_Y           | double                   | AsDtype('>f8')
# Lb_TOPPV_Z           | double                   | AsDtype('>f8')
# Lb_TOPPV_XERR        | double                   | AsDtype('>f8')
# Lb_TOPPV_YERR        | double                   | AsDtype('>f8')
# Lb_TOPPV_ZERR        | double                   | AsDtype('>f8')
# Lb_TOPPV_CHI2        | double                   | AsDtype('>f8')
# Lb_TOPPV_NDOF        | int32_t                  | AsDtype('>i4')
# Lb_TOPPV_COV_        | float[3][3]              | AsDtype("('>f4', (3, 3))")
# Lb_IP_TOPPV          | double                   | AsDtype('>f8')
# Lb_IPCHI2_TOPPV      | double                   | AsDtype('>f8')
# Lb_FD_TOPPV          | double                   | AsDtype('>f8')
# Lb_FDCHI2_TOPPV      | double                   | AsDtype('>f8')
# Lb_DIRA_TOPPV        | double                   | AsDtype('>f8')
# Lb_HOP               | double                   | AsDtype('>f8')
# Lb_HOP_MASS          | double                   | AsDtype('>f8')
# Lb_HOP_ELECTRON_MASS | double                   | AsDtype('>f8')
# Lb_P                 | double                   | AsDtype('>f8')
# Lb_PT                | double                   | AsDtype('>f8')
# Lb_PE                | double                   | AsDtype('>f8')
# Lb_PX                | double                   | AsDtype('>f8')
# Lb_PY                | double                   | AsDtype('>f8')
# Lb_PZ                | double                   | AsDtype('>f8')
# Lb_REFPX             | double                   | AsDtype('>f8')
# Lb_REFPY             | double                   | AsDtype('>f8')
# Lb_REFPZ             | double                   | AsDtype('>f8')
# Lb_MM                | double                   | AsDtype('>f8')
# Lb_MMERR             | double                   | AsDtype('>f8')
# Lb_M                 | double                   | AsDtype('>f8')
# Lb_TRUEID            | int32_t                  | AsDtype('>i4')
# Lb_MC_MOTHER_ID      | int32_t                  | AsDtype('>i4')
# Lb_MC_MOTHER_KEY     | int32_t                  | AsDtype('>i4')
# Lb_MC_GD_MOTHER_ID   | int32_t                  | AsDtype('>i4')
# Lb_MC_GD_MOTHER_KEY  | int32_t                  | AsDtype('>i4')
# Lb_MC_GD_GD_MOTHE... | int32_t                  | AsDtype('>i4')
# Lb_MC_GD_GD_MOTHE... | int32_t                  | AsDtype('>i4')
# Lb_TRUEP_E           | double                   | AsDtype('>f8')
# Lb_TRUEP_X           | double                   | AsDtype('>f8')
# Lb_TRUEP_Y           | double                   | AsDtype('>f8')
# Lb_TRUEP_Z           | double                   | AsDtype('>f8')
# Lb_TRUEPT            | double                   | AsDtype('>f8')
# Lb_TRUEORIGINVERT... | double                   | AsDtype('>f8')
# Lb_TRUEORIGINVERT... | double                   | AsDtype('>f8')
# Lb_TRUEORIGINVERT... | double                   | AsDtype('>f8')
# Lb_TRUEENDVERTEX_X   | double                   | AsDtype('>f8')
# Lb_TRUEENDVERTEX_Y   | double                   | AsDtype('>f8')
# Lb_TRUEENDVERTEX_Z   | double                   | AsDtype('>f8')
# Lb_TRUEISSTABLE      | bool                     | AsDtype('bool')
# Lb_TRUETAU           | double                   | AsDtype('>f8')
# Lb_ID                | int32_t                  | AsDtype('>i4')
# Lb_TAU               | double                   | AsDtype('>f8')
# Lb_TAUERR            | double                   | AsDtype('>f8')
# Lb_TAUCHI2           | double                   | AsDtype('>f8')
# Lb_DTF_PV_JPs_M012   | double                   | AsDtype('>f8')
# Lb_DTF_PV_JPs_M013   | double                   | AsDtype('>f8')
# Lb_JPs_1ST_TrkISOBDT | double                   | AsDtype('>f8')
# Lb_JPs_2ND_TrkISOBDT | double                   | AsDtype('>f8')
# Lb_JPs_3RD_TrkISOBDT | double                   | AsDtype('>f8')
# Lb_JPs_cc_IT_0.5C... | double                   | AsDtype('>f8')
# Lb_JPs_cc_VPT_0.5... | double                   | AsDtype('>f8')
# Lb_JPs_cc_asy_PT_... | double                   | AsDtype('>f8')
# Lb_JPs_cc_asy_P_0... | double                   | AsDtype('>f8')
# Lb_JPs_cc_deltaEt... | double                   | AsDtype('>f8')
# Lb_JPs_cc_deltaPh... | double                   | AsDtype('>f8')
# Lb_JPs_cc_maxPt_P... | double                   | AsDtype('>f8')
# Lb_JPs_cc_maxPt_P... | double                   | AsDtype('>f8')
# Lb_JPs_cc_maxPt_P... | double                   | AsDtype('>f8')
# Lb_JPs_cc_maxPt_Q... | double                   | AsDtype('>f8')
# Lb_JPs_cc_mult_0.... | double                   | AsDtype('>f8')
# Lb_JPs_cc_sPT_0.5... | double                   | AsDtype('>f8')
# Lb_JPs_cmult_0.5T... | double                   | AsDtype('>f8')
# Lb_JPs_cp_0.5TrkISO  | double                   | AsDtype('>f8')
# Lb_JPs_cpt_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_JPs_deltaEta_0... | double                   | AsDtype('>f8')
# Lb_JPs_deltaPhi_0... | double                   | AsDtype('>f8')
# Lb_JPs_nc_IT_0.5C... | double                   | AsDtype('>f8')
# Lb_JPs_nc_VPT_0.5... | double                   | AsDtype('>f8')
# Lb_JPs_nc_asy_PT_... | double                   | AsDtype('>f8')
# Lb_JPs_nc_asy_P_0... | double                   | AsDtype('>f8')
# Lb_JPs_nc_deltaEt... | double                   | AsDtype('>f8')
# Lb_JPs_nc_deltaPh... | double                   | AsDtype('>f8')
# Lb_JPs_nc_maxPt_P... | double                   | AsDtype('>f8')
# Lb_JPs_nc_maxPt_P... | double                   | AsDtype('>f8')
# Lb_JPs_nc_mult_0.... | double                   | AsDtype('>f8')
# Lb_JPs_nc_sPT_0.5... | double                   | AsDtype('>f8')
# Lb_JPs_pasy_0.5Tr... | double                   | AsDtype('>f8')
# Lb_JPs_ptasy_0.5T... | double                   | AsDtype('>f8')
# Lb_K_1ST_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_K_2ND_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_K_3RD_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_K_cc_IT_0.5Con... | double                   | AsDtype('>f8')
# Lb_K_cc_VPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_K_cc_asy_PT_0.... | double                   | AsDtype('>f8')
# Lb_K_cc_asy_P_0.5... | double                   | AsDtype('>f8')
# Lb_K_cc_deltaEta_... | double                   | AsDtype('>f8')
# Lb_K_cc_deltaPhi_... | double                   | AsDtype('>f8')
# Lb_K_cc_maxPt_PE_... | double                   | AsDtype('>f8')
# Lb_K_cc_maxPt_PT_... | double                   | AsDtype('>f8')
# Lb_K_cc_maxPt_PZ_... | double                   | AsDtype('>f8')
# Lb_K_cc_maxPt_Q_0... | double                   | AsDtype('>f8')
# Lb_K_cc_mult_0.5C... | double                   | AsDtype('>f8')
# Lb_K_cc_sPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_K_cmult_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_K_cp_0.5TrkISO    | double                   | AsDtype('>f8')
# Lb_K_cpt_0.5TrkISO   | double                   | AsDtype('>f8')
# Lb_K_deltaEta_0.5... | double                   | AsDtype('>f8')
# Lb_K_deltaPhi_0.5... | double                   | AsDtype('>f8')
# Lb_K_nc_IT_0.5Con... | double                   | AsDtype('>f8')
# Lb_K_nc_VPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_K_nc_asy_PT_0.... | double                   | AsDtype('>f8')
# Lb_K_nc_asy_P_0.5... | double                   | AsDtype('>f8')
# Lb_K_nc_deltaEta_... | double                   | AsDtype('>f8')
# Lb_K_nc_deltaPhi_... | double                   | AsDtype('>f8')
# Lb_K_nc_maxPt_PT_... | double                   | AsDtype('>f8')
# Lb_K_nc_maxPt_PZ_... | double                   | AsDtype('>f8')
# Lb_K_nc_mult_0.5C... | double                   | AsDtype('>f8')
# Lb_K_nc_sPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_K_pasy_0.5TrkISO  | double                   | AsDtype('>f8')
# Lb_K_ptasy_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_L1_1ST_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L1_2ND_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L1_3RD_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L1_cc_IT_0.5Co... | double                   | AsDtype('>f8')
# Lb_L1_cc_VPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L1_cc_asy_PT_0... | double                   | AsDtype('>f8')
# Lb_L1_cc_asy_P_0.... | double                   | AsDtype('>f8')
# Lb_L1_cc_deltaEta... | double                   | AsDtype('>f8')
# Lb_L1_cc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_L1_cc_maxPt_PE... | double                   | AsDtype('>f8')
# Lb_L1_cc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_L1_cc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_L1_cc_maxPt_Q_... | double                   | AsDtype('>f8')
# Lb_L1_cc_mult_0.5... | double                   | AsDtype('>f8')
# Lb_L1_cc_sPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L1_cmult_0.5Tr... | double                   | AsDtype('>f8')
# Lb_L1_cp_0.5TrkISO   | double                   | AsDtype('>f8')
# Lb_L1_cpt_0.5TrkISO  | double                   | AsDtype('>f8')
# Lb_L1_deltaEta_0.... | double                   | AsDtype('>f8')
# Lb_L1_deltaPhi_0.... | double                   | AsDtype('>f8')
# Lb_L1_nc_IT_0.5Co... | double                   | AsDtype('>f8')
# Lb_L1_nc_VPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L1_nc_asy_PT_0... | double                   | AsDtype('>f8')
# Lb_L1_nc_asy_P_0.... | double                   | AsDtype('>f8')
# Lb_L1_nc_deltaEta... | double                   | AsDtype('>f8')
# Lb_L1_nc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_L1_nc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_L1_nc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_L1_nc_mult_0.5... | double                   | AsDtype('>f8')
# Lb_L1_nc_sPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L1_pasy_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_L1_ptasy_0.5Tr... | double                   | AsDtype('>f8')
# Lb_L2_1ST_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L2_2ND_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L2_3RD_TrkISOBDT  | double                   | AsDtype('>f8')
# Lb_L2_cc_IT_0.5Co... | double                   | AsDtype('>f8')
# Lb_L2_cc_VPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L2_cc_asy_PT_0... | double                   | AsDtype('>f8')
# Lb_L2_cc_asy_P_0.... | double                   | AsDtype('>f8')
# Lb_L2_cc_deltaEta... | double                   | AsDtype('>f8')
# Lb_L2_cc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_L2_cc_maxPt_PE... | double                   | AsDtype('>f8')
# Lb_L2_cc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_L2_cc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_L2_cc_maxPt_Q_... | double                   | AsDtype('>f8')
# Lb_L2_cc_mult_0.5... | double                   | AsDtype('>f8')
# Lb_L2_cc_sPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L2_cmult_0.5Tr... | double                   | AsDtype('>f8')
# Lb_L2_cp_0.5TrkISO   | double                   | AsDtype('>f8')
# Lb_L2_cpt_0.5TrkISO  | double                   | AsDtype('>f8')
# Lb_L2_deltaEta_0.... | double                   | AsDtype('>f8')
# Lb_L2_deltaPhi_0.... | double                   | AsDtype('>f8')
# Lb_L2_nc_IT_0.5Co... | double                   | AsDtype('>f8')
# Lb_L2_nc_VPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L2_nc_asy_PT_0... | double                   | AsDtype('>f8')
# Lb_L2_nc_asy_P_0.... | double                   | AsDtype('>f8')
# Lb_L2_nc_deltaEta... | double                   | AsDtype('>f8')
# Lb_L2_nc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_L2_nc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_L2_nc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_L2_nc_mult_0.5... | double                   | AsDtype('>f8')
# Lb_L2_nc_sPT_0.5C... | double                   | AsDtype('>f8')
# Lb_L2_pasy_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_L2_ptasy_0.5Tr... | double                   | AsDtype('>f8')
# Lb_LStar_1ST_TrkI... | double                   | AsDtype('>f8')
# Lb_LStar_2ND_TrkI... | double                   | AsDtype('>f8')
# Lb_LStar_3RD_TrkI... | double                   | AsDtype('>f8')
# Lb_LStar_cc_IT_0.... | double                   | AsDtype('>f8')
# Lb_LStar_cc_VPT_0... | double                   | AsDtype('>f8')
# Lb_LStar_cc_asy_P... | double                   | AsDtype('>f8')
# Lb_LStar_cc_asy_P... | double                   | AsDtype('>f8')
# Lb_LStar_cc_delta... | double                   | AsDtype('>f8')
# Lb_LStar_cc_delta... | double                   | AsDtype('>f8')
# Lb_LStar_cc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_cc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_cc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_cc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_cc_mult_... | double                   | AsDtype('>f8')
# Lb_LStar_cc_sPT_0... | double                   | AsDtype('>f8')
# Lb_LStar_cmult_0.... | double                   | AsDtype('>f8')
# Lb_LStar_cp_0.5Tr... | double                   | AsDtype('>f8')
# Lb_LStar_cpt_0.5T... | double                   | AsDtype('>f8')
# Lb_LStar_deltaEta... | double                   | AsDtype('>f8')
# Lb_LStar_deltaPhi... | double                   | AsDtype('>f8')
# Lb_LStar_nc_IT_0.... | double                   | AsDtype('>f8')
# Lb_LStar_nc_VPT_0... | double                   | AsDtype('>f8')
# Lb_LStar_nc_asy_P... | double                   | AsDtype('>f8')
# Lb_LStar_nc_asy_P... | double                   | AsDtype('>f8')
# Lb_LStar_nc_delta... | double                   | AsDtype('>f8')
# Lb_LStar_nc_delta... | double                   | AsDtype('>f8')
# Lb_LStar_nc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_nc_maxPt... | double                   | AsDtype('>f8')
# Lb_LStar_nc_mult_... | double                   | AsDtype('>f8')
# Lb_LStar_nc_sPT_0... | double                   | AsDtype('>f8')
# Lb_LStar_pasy_0.5... | double                   | AsDtype('>f8')
# Lb_LStar_ptasy_0.... | double                   | AsDtype('>f8')
# Lb_Lb_1ST_VtxISOBDT  | double                   | AsDtype('>f8')
# Lb_Lb_2ND_VtxISOBDT  | double                   | AsDtype('>f8')
# Lb_Lb_3RD_VtxISOBDT  | double                   | AsDtype('>f8')
# Lb_Lb_NumVtxWithi... | double                   | AsDtype('>f8')
# Lb_Lb_SmallestDel... | double                   | AsDtype('>f8')
# Lb_Lb_SmallestDel... | double                   | AsDtype('>f8')
# Lb_Lb_SmallestDel... | double                   | AsDtype('>f8')
# Lb_Lb_SmallestDel... | double                   | AsDtype('>f8')
# Lb_Lb_cc_IT_1.0Co... | double                   | AsDtype('>f8')
# Lb_Lb_cc_IT_2.0Co... | double                   | AsDtype('>f8')
# Lb_Lb_cc_VPT_1.0C... | double                   | AsDtype('>f8')
# Lb_Lb_cc_VPT_2.0C... | double                   | AsDtype('>f8')
# Lb_Lb_cc_asy_PT_1... | double                   | AsDtype('>f8')
# Lb_Lb_cc_asy_PT_2... | double                   | AsDtype('>f8')
# Lb_Lb_cc_asy_P_1.... | double                   | AsDtype('>f8')
# Lb_Lb_cc_asy_P_2.... | double                   | AsDtype('>f8')
# Lb_Lb_cc_deltaEta... | double                   | AsDtype('>f8')
# Lb_Lb_cc_deltaEta... | double                   | AsDtype('>f8')
# Lb_Lb_cc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_Lb_cc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PE... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PE... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_Q_... | double                   | AsDtype('>f8')
# Lb_Lb_cc_maxPt_Q_... | double                   | AsDtype('>f8')
# Lb_Lb_cc_mult_1.0... | double                   | AsDtype('>f8')
# Lb_Lb_cc_mult_2.0... | double                   | AsDtype('>f8')
# Lb_Lb_cc_sPT_1.0C... | double                   | AsDtype('>f8')
# Lb_Lb_cc_sPT_2.0C... | double                   | AsDtype('>f8')
# Lb_Lb_cmult_1.0Tr... | double                   | AsDtype('>f8')
# Lb_Lb_cmult_2.0Tr... | double                   | AsDtype('>f8')
# Lb_Lb_cp_1.0TrkISO   | double                   | AsDtype('>f8')
# Lb_Lb_cp_2.0TrkISO   | double                   | AsDtype('>f8')
# Lb_Lb_cpt_1.0TrkISO  | double                   | AsDtype('>f8')
# Lb_Lb_cpt_2.0TrkISO  | double                   | AsDtype('>f8')
# Lb_Lb_deltaEta_1.... | double                   | AsDtype('>f8')
# Lb_Lb_deltaEta_2.... | double                   | AsDtype('>f8')
# Lb_Lb_deltaPhi_1.... | double                   | AsDtype('>f8')
# Lb_Lb_deltaPhi_2.... | double                   | AsDtype('>f8')
# Lb_Lb_nc_IT_1.0Co... | double                   | AsDtype('>f8')
# Lb_Lb_nc_IT_2.0Co... | double                   | AsDtype('>f8')
# Lb_Lb_nc_VPT_1.0C... | double                   | AsDtype('>f8')
# Lb_Lb_nc_VPT_2.0C... | double                   | AsDtype('>f8')
# Lb_Lb_nc_asy_PT_1... | double                   | AsDtype('>f8')
# Lb_Lb_nc_asy_PT_2... | double                   | AsDtype('>f8')
# Lb_Lb_nc_asy_P_1.... | double                   | AsDtype('>f8')
# Lb_Lb_nc_asy_P_2.... | double                   | AsDtype('>f8')
# Lb_Lb_nc_deltaEta... | double                   | AsDtype('>f8')
# Lb_Lb_nc_deltaEta... | double                   | AsDtype('>f8')
# Lb_Lb_nc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_Lb_nc_deltaPhi... | double                   | AsDtype('>f8')
# Lb_Lb_nc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_Lb_nc_maxPt_PT... | double                   | AsDtype('>f8')
# Lb_Lb_nc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_Lb_nc_maxPt_PZ... | double                   | AsDtype('>f8')
# Lb_Lb_nc_mult_1.0... | double                   | AsDtype('>f8')
# Lb_Lb_nc_mult_2.0... | double                   | AsDtype('>f8')
# Lb_Lb_nc_sPT_1.0C... | double                   | AsDtype('>f8')
# Lb_Lb_nc_sPT_2.0C... | double                   | AsDtype('>f8')
# Lb_Lb_pasy_1.0TrkISO | double                   | AsDtype('>f8')
# Lb_Lb_pasy_2.0TrkISO | double                   | AsDtype('>f8')
# Lb_Lb_ptasy_1.0Tr... | double                   | AsDtype('>f8')
# Lb_Lb_ptasy_2.0Tr... | double                   | AsDtype('>f8')
# Lb_p_1ST_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_p_2ND_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_p_3RD_TrkISOBDT   | double                   | AsDtype('>f8')
# Lb_p_cc_IT_0.5Con... | double                   | AsDtype('>f8')
# Lb_p_cc_VPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_p_cc_asy_PT_0.... | double                   | AsDtype('>f8')
# Lb_p_cc_asy_P_0.5... | double                   | AsDtype('>f8')
# Lb_p_cc_deltaEta_... | double                   | AsDtype('>f8')
# Lb_p_cc_deltaPhi_... | double                   | AsDtype('>f8')
# Lb_p_cc_maxPt_PE_... | double                   | AsDtype('>f8')
# Lb_p_cc_maxPt_PT_... | double                   | AsDtype('>f8')
# Lb_p_cc_maxPt_PZ_... | double                   | AsDtype('>f8')
# Lb_p_cc_maxPt_Q_0... | double                   | AsDtype('>f8')
# Lb_p_cc_mult_0.5C... | double                   | AsDtype('>f8')
# Lb_p_cc_sPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_p_cmult_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_p_cp_0.5TrkISO    | double                   | AsDtype('>f8')
# Lb_p_cpt_0.5TrkISO   | double                   | AsDtype('>f8')
# Lb_p_deltaEta_0.5... | double                   | AsDtype('>f8')
# Lb_p_deltaPhi_0.5... | double                   | AsDtype('>f8')
# Lb_p_nc_IT_0.5Con... | double                   | AsDtype('>f8')
# Lb_p_nc_VPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_p_nc_asy_PT_0.... | double                   | AsDtype('>f8')
# Lb_p_nc_asy_P_0.5... | double                   | AsDtype('>f8')
# Lb_p_nc_deltaEta_... | double                   | AsDtype('>f8')
# Lb_p_nc_deltaPhi_... | double                   | AsDtype('>f8')
# Lb_p_nc_maxPt_PT_... | double                   | AsDtype('>f8')
# Lb_p_nc_maxPt_PZ_... | double                   | AsDtype('>f8')
# Lb_p_nc_mult_0.5C... | double                   | AsDtype('>f8')
# Lb_p_nc_sPT_0.5Co... | double                   | AsDtype('>f8')
# Lb_p_pasy_0.5TrkISO  | double                   | AsDtype('>f8')
# Lb_p_ptasy_0.5TrkISO | double                   | AsDtype('>f8')
# Lb_DTF_JPs_nPV       | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_J_psi_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Lambda... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_M         | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_MERR      | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_P         | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_PERR      | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_chi2      | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_nDOF      | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_nIter     | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_status    | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2pi_M | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2pi_P | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubK2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K_M  | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K_P  | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2K... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2pi_M | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2pi_P | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_Subp2p... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | int32_t                  | AsDtype('>i4')
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_JPs_SubpK2... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_nPV     | int32_t                  | AsDtype('>i4')
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_J_ps... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_Lamb... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_M       | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_MERR    | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_P       | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_PERR    | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_chi2    | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_nDOF    | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_nIter   | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520_status  | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_nPV | int32_t                  | AsDtype('>i4')
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# Lb_DTF_L1520-JPs_... | float[]                  | AsJagged(AsDtype('>f4'))
# ...
# L2_EcalPIDe          | double                   | AsDtype('>f8')
# L2_EcalPIDmu         | double                   | AsDtype('>f8')
# L2_InAccHcal         | bool                     | AsDtype('bool')
# L2_CaloHcalE         | double                   | AsDtype('>f8')
# L2_HcalPIDe          | double                   | AsDtype('>f8')
# L2_HcalPIDmu         | double                   | AsDtype('>f8')
# L2_InAccPrs          | bool                     | AsDtype('bool')
# L2_PrsPIDe           | double                   | AsDtype('>f8')
# L2_CaloPrsE          | double                   | AsDtype('>f8')
# L2_InAccSpd          | bool                     | AsDtype('bool')
# L2_CaloSpdE          | double                   | AsDtype('>f8')
# L2_InAccBrem         | bool                     | AsDtype('bool')
# L2_BremPIDe          | double                   | AsDtype('>f8')
# L2_VeloCharge        | double                   | AsDtype('>f8')
# L2_TRACK_Type        | int32_t                  | AsDtype('>i4')
# L2_TRACK_Key         | int32_t                  | AsDtype('>i4')
# L2_TRACK_CHI2        | double                   | AsDtype('>f8')
# L2_TRACK_NDOF        | int32_t                  | AsDtype('>i4')
# L2_TRACK_CHI2NDOF    | double                   | AsDtype('>f8')
# L2_TRACK_PCHI2       | double                   | AsDtype('>f8')
# L2_TRACK_VeloCHI2... | double                   | AsDtype('>f8')
# L2_TRACK_TCHI2NDOF   | double                   | AsDtype('>f8')
# L2_TRACK_VELO_UTID   | double                   | AsDtype('>f8')
# L2_TRACK_TT_UTID     | double                   | AsDtype('>f8')
# L2_TRACK_IT_UTID     | double                   | AsDtype('>f8')
# L2_TRACK_OT_UTID     | double                   | AsDtype('>f8')
# L2_TRACK_nVeloHits   | int32_t                  | AsDtype('>i4')
# L2_TRACK_nVeloRHits  | int32_t                  | AsDtype('>i4')
# L2_TRACK_nVeloPhi... | int32_t                  | AsDtype('>i4')
# L2_TRACK_nVeloPil... | int32_t                  | AsDtype('>i4')
# L2_TRACK_nTTHits     | int32_t                  | AsDtype('>i4')
# L2_TRACK_nITHits     | int32_t                  | AsDtype('>i4')
# L2_TRACK_nOTHits     | int32_t                  | AsDtype('>i4')
# L2_TRACK_History     | int32_t                  | AsDtype('>i4')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_FirstMea... | double                   | AsDtype('>f8')
# L2_TRACK_MatchCHI2   | double                   | AsDtype('>f8')
# L2_TRACK_GhostProb   | double                   | AsDtype('>f8')
# L2_TRACK_CloneDist   | double                   | AsDtype('>f8')
# L2_TRACK_Likelihood  | double                   | AsDtype('>f8')
# L2_CaloBremMatch     | double                   | AsDtype('>f8')
# L2_CaloElectronMatch | double                   | AsDtype('>f8')
# L2_CaloTrMatch       | double                   | AsDtype('>f8')
# L2_LoKi_InAccBrem    | double                   | AsDtype('>f8')
# L2_TRACK_PX          | double                   | AsDtype('>f8')
# L2_TRACK_PY          | double                   | AsDtype('>f8')
# L2_TRACK_PZ          | double                   | AsDtype('>f8')
# L2_TrP               | double                   | AsDtype('>f8')
# L2_TrQ               | double                   | AsDtype('>f8')
# L2_ETA               | double                   | AsDtype('>f8')
# L2_PERR2             | double                   | AsDtype('>f8')
# L2_PHI               | double                   | AsDtype('>f8')
# L2_PTERR2            | double                   | AsDtype('>f8')
# L2_inMuon            | double                   | AsDtype('>f8')
# L2_nIT               | double                   | AsDtype('>f8')
# L2_nMuonShared       | double                   | AsDtype('>f8')
# L2_nOT               | double                   | AsDtype('>f8')
# L2_nST               | double                   | AsDtype('>f8')
# L2_nTT               | double                   | AsDtype('>f8')
# L2_nVelo             | double                   | AsDtype('>f8')
# L2_nVeloPL           | double                   | AsDtype('>f8')
# L2_nVeloPhi          | double                   | AsDtype('>f8')
# L2_nVeloR            | double                   | AsDtype('>f8')
# L2_PCOV00            | double                   | AsDtype('>f8')
# L2_PCOV01            | double                   | AsDtype('>f8')
# L2_PCOV02            | double                   | AsDtype('>f8')
# L2_PCOV03            | double                   | AsDtype('>f8')
# L2_PCOV10            | double                   | AsDtype('>f8')
# L2_PCOV11            | double                   | AsDtype('>f8')
# L2_PCOV12            | double                   | AsDtype('>f8')
# L2_PCOV13            | double                   | AsDtype('>f8')
# L2_PCOV20            | double                   | AsDtype('>f8')
# L2_PCOV21            | double                   | AsDtype('>f8')
# L2_PCOV22            | double                   | AsDtype('>f8')
# L2_PCOV23            | double                   | AsDtype('>f8')
# L2_PCOV30            | double                   | AsDtype('>f8')
# L2_PCOV31            | double                   | AsDtype('>f8')
# L2_PCOV32            | double                   | AsDtype('>f8')
# L2_PCOV33            | double                   | AsDtype('>f8')
# L2_TrCOV00           | double                   | AsDtype('>f8')
# L2_TrCOV01           | double                   | AsDtype('>f8')
# L2_TrCOV02           | double                   | AsDtype('>f8')
# L2_TrCOV03           | double                   | AsDtype('>f8')
# L2_TrCOV04           | double                   | AsDtype('>f8')
# L2_TrCOV10           | double                   | AsDtype('>f8')
# L2_TrCOV11           | double                   | AsDtype('>f8')
# L2_TrCOV12           | double                   | AsDtype('>f8')
# L2_TrCOV13           | double                   | AsDtype('>f8')
# L2_TrCOV14           | double                   | AsDtype('>f8')
# L2_TrCOV20           | double                   | AsDtype('>f8')
# L2_TrCOV21           | double                   | AsDtype('>f8')
# L2_TrCOV22           | double                   | AsDtype('>f8')
# L2_TrCOV23           | double                   | AsDtype('>f8')
# L2_TrCOV24           | double                   | AsDtype('>f8')
# L2_TrCOV30           | double                   | AsDtype('>f8')
# L2_TrCOV31           | double                   | AsDtype('>f8')
# L2_TrCOV32           | double                   | AsDtype('>f8')
# L2_TrCOV33           | double                   | AsDtype('>f8')
# L2_TrCOV34           | double                   | AsDtype('>f8')
# L2_TrCOV40           | double                   | AsDtype('>f8')
# L2_TrCOV41           | double                   | AsDtype('>f8')
# L2_TrCOV42           | double                   | AsDtype('>f8')
# L2_TrCOV43           | double                   | AsDtype('>f8')
# L2_TrCOV44           | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_re... | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_xP... | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_yP... | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_re... | int32_t                  | AsDtype('>i4')
# L2_L0Calo_ECAL_Tr... | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_xT... | double                   | AsDtype('>f8')
# L2_L0Calo_ECAL_yT... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_re... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_xP... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_yP... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_re... | int32_t                  | AsDtype('>i4')
# L2_L0Calo_HCAL_Tr... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_Tr... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_xT... | double                   | AsDtype('>f8')
# L2_L0Calo_HCAL_yT... | double                   | AsDtype('>f8')
# L2_L0Global_Dec      | bool                     | AsDtype('bool')
# L2_L0Global_TIS      | bool                     | AsDtype('bool')
# L2_L0Global_TOS      | bool                     | AsDtype('bool')
# L2_Hlt1Global_Dec    | bool                     | AsDtype('bool')
# L2_Hlt1Global_TIS    | bool                     | AsDtype('bool')
# L2_Hlt1Global_TOS    | bool                     | AsDtype('bool')
# L2_Hlt1Phys_Dec      | bool                     | AsDtype('bool')
# L2_Hlt1Phys_TIS      | bool                     | AsDtype('bool')
# L2_Hlt1Phys_TOS      | bool                     | AsDtype('bool')
# L2_Hlt2Global_Dec    | bool                     | AsDtype('bool')
# L2_Hlt2Global_TIS    | bool                     | AsDtype('bool')
# L2_Hlt2Global_TOS    | bool                     | AsDtype('bool')
# L2_Hlt2Phys_Dec      | bool                     | AsDtype('bool')
# L2_Hlt2Phys_TIS      | bool                     | AsDtype('bool')
# L2_Hlt2Phys_TOS      | bool                     | AsDtype('bool')
# L2_L0ElectronDeci... | bool                     | AsDtype('bool')
# L2_L0ElectronDeci... | bool                     | AsDtype('bool')
# L2_L0ElectronDeci... | bool                     | AsDtype('bool')
# L2_L0MuonDecision... | bool                     | AsDtype('bool')
# L2_L0MuonDecision... | bool                     | AsDtype('bool')
# L2_L0MuonDecision... | bool                     | AsDtype('bool')
# L2_L0HadronDecisi... | bool                     | AsDtype('bool')
# L2_L0HadronDecisi... | bool                     | AsDtype('bool')
# L2_L0HadronDecisi... | bool                     | AsDtype('bool')
# L2_L0PhotonDecisi... | bool                     | AsDtype('bool')
# L2_L0PhotonDecisi... | bool                     | AsDtype('bool')
# L2_L0PhotonDecisi... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMVADe... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMVADe... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMVADe... | bool                     | AsDtype('bool')
# L2_Hlt1TwoTrackMV... | bool                     | AsDtype('bool')
# L2_Hlt1TwoTrackMV... | bool                     | AsDtype('bool')
# L2_Hlt1TwoTrackMV... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonD... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonD... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonD... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonM... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonM... | bool                     | AsDtype('bool')
# L2_Hlt1TrackMuonM... | bool                     | AsDtype('bool')
# nCandidate           | uint32_t                 | AsDtype('>u4')
# totCandidates        | uint64_t                 | AsDtype('>u8')
# EventInSequence      | uint64_t                 | AsDtype('>u8')
# runNumber            | uint32_t                 | AsDtype('>u4')
# eventNumber          | uint64_t                 | AsDtype('>u8')
# BCID                 | uint32_t                 | AsDtype('>u4')
# BCType               | int32_t                  | AsDtype('>i4')
# OdinTCK              | uint32_t                 | AsDtype('>u4')
# L0DUTCK              | uint32_t                 | AsDtype('>u4')
# HLT1TCK              | uint32_t                 | AsDtype('>u4')
# HLT2TCK              | uint32_t                 | AsDtype('>u4')
# GpsTime              | uint64_t                 | AsDtype('>u8')
# GpsYear              | int32_t                  | AsDtype('>i4')
# GpsMonth             | int32_t                  | AsDtype('>i4')
# GpsDay               | int32_t                  | AsDtype('>i4')
# GpsHour              | int32_t                  | AsDtype('>i4')
# GpsMinute            | int32_t                  | AsDtype('>i4')
# GpsSecond            | double                   | AsDtype('>f8')
# TriggerType          | int32_t                  | AsDtype('>i4')
# Polarity             | int16_t                  | AsDtype('>i2')
# L0Data_DiMuon_Pt     | int32_t                  | AsDtype('>i4')
# L0Data_DiMuonProd... | int32_t                  | AsDtype('>i4')
# L0Data_Electron_Et   | int32_t                  | AsDtype('>i4')
# L0Data_GlobalPi0_Et  | int32_t                  | AsDtype('>i4')
# L0Data_Hadron_Et     | int32_t                  | AsDtype('>i4')
# L0Data_LocalPi0_Et   | int32_t                  | AsDtype('>i4')
# L0Data_Muon1_Pt      | int32_t                  | AsDtype('>i4')
# L0Data_Muon1_Sgn     | int32_t                  | AsDtype('>i4')
# L0Data_Muon2_Pt      | int32_t                  | AsDtype('>i4')
# L0Data_Muon2_Sgn     | int32_t                  | AsDtype('>i4')
# L0Data_Muon3_Pt      | int32_t                  | AsDtype('>i4')
# L0Data_Muon3_Sgn     | int32_t                  | AsDtype('>i4')
# L0Data_PUHits_Mult   | int32_t                  | AsDtype('>i4')
# L0Data_PUPeak1_Cont  | int32_t                  | AsDtype('>i4')
# L0Data_PUPeak1_Pos   | int32_t                  | AsDtype('>i4')
# L0Data_PUPeak2_Cont  | int32_t                  | AsDtype('>i4')
# L0Data_PUPeak2_Pos   | int32_t                  | AsDtype('>i4')
# L0Data_Photon_Et     | int32_t                  | AsDtype('>i4')
# L0Data_Spd_Mult      | int32_t                  | AsDtype('>i4')
# L0Data_Sum_Et        | int32_t                  | AsDtype('>i4')
# L0Data_Sum_Et,Next1  | int32_t                  | AsDtype('>i4')
# L0Data_Sum_Et,Next2  | int32_t                  | AsDtype('>i4')
# L0Data_Sum_Et,Prev1  | int32_t                  | AsDtype('>i4')
# L0Data_Sum_Et,Prev2  | int32_t                  | AsDtype('>i4')
# nPV                  | int32_t                  | AsDtype('>i4')
# PVX                  | float[]                  | AsJagged(AsDtype('>f4'))
# PVY                  | float[]                  | AsJagged(AsDtype('>f4'))
# PVZ                  | float[]                  | AsJagged(AsDtype('>f4'))
# PVXERR               | float[]                  | AsJagged(AsDtype('>f4'))
# PVYERR               | float[]                  | AsJagged(AsDtype('>f4'))
# PVZERR               | float[]                  | AsJagged(AsDtype('>f4'))
# PVCHI2               | float[]                  | AsJagged(AsDtype('>f4'))
# PVNDOF               | float[]                  | AsJagged(AsDtype('>f4'))
# PVNTRACKS            | float[]                  | AsJagged(AsDtype('>f4'))
# PVsumPT              | float[]                  | AsJagged(AsDtype('>f4'))
# nPVs                 | int32_t                  | AsDtype('>i4')
# nTracks              | int32_t                  | AsDtype('>i4')
# nLongTracks          | int32_t                  | AsDtype('>i4')
# nDownstreamTracks    | int32_t                  | AsDtype('>i4')
# nUpstreamTracks      | int32_t                  | AsDtype('>i4')
# nVeloTracks          | int32_t                  | AsDtype('>i4')
# nTTracks             | int32_t                  | AsDtype('>i4')
# nBackTracks          | int32_t                  | AsDtype('>i4')
# nRich1Hits           | int32_t                  | AsDtype('>i4')
# nRich2Hits           | int32_t                  | AsDtype('>i4')
# nVeloClusters        | int32_t                  | AsDtype('>i4')
# nITClusters          | int32_t                  | AsDtype('>i4')
# nTTClusters          | int32_t                  | AsDtype('>i4')
# nOTClusters          | int32_t                  | AsDtype('>i4')
# nSPDHits             | int32_t                  | AsDtype('>i4')
# nMuonCoordsS0        | int32_t                  | AsDtype('>i4')
# nMuonCoordsS1        | int32_t                  | AsDtype('>i4')
# nMuonCoordsS2        | int32_t                  | AsDtype('>i4')
# nMuonCoordsS3        | int32_t                  | AsDtype('>i4')
# nMuonCoordsS4        | int32_t                  | AsDtype('>i4')
# nMuonTracks          | int32_t                  | AsDtype('>i4')
# L0Global             | int32_t                  | AsDtype('>i4')
# Hlt1Global           | uint32_t                 | AsDtype('>u4')
# Hlt2Global           | uint32_t                 | AsDtype('>u4')
# MaxRoutingBits       | int32_t                  | AsDtype('>i4')
# RoutingBits          | float[]                  | AsJagged(AsDtype('>f4'))
# None

# %% [markdown]
# Now we can open a particular variables data as either a numpy array or a Pandas dataframe. We elect to use both some of the functions Dan wrote are numpy only but can probably be adapted for use in Pandas.

# %%
with up.open(fName + ":DTT1520me/DecayTree") as f:
    eventNum = f["eventNumber"].array(library="pd") # Using 'np' here will give you a numpy version
    
print(eventNum.head(), type(eventNum))
# Out:
# 0    4826
# 1    4826
# 2    4826
# 3    4826
# 4    4826
# dtype: uint64 <class 'pandas.core.series.Series'>

# %% [markdown]
# As can be seen we have a lovely Pandas series object with the index column and then the event number in the next column. You should probably rename the columns in the above just to keep things pretty and tidy.
#
# ### Reading Multiple Arrays at Once
# We can also read in multiple variables or arrays at once, which is significantly faster and easier than doing it one at a time. An example is given below where the eventNumber, runNumber and arbitrarily the PVNTRACKS are read in.

# %%
with up.open(fName + ":DTT1520me/DecayTree") as f:
    df = f.arrays(["eventNumber", "runNumber", "PVNTRACKS"], library="pd")
    # You can also use Wildcards to call in particular sets of varialbles the example is commented out below
    # allPT=f.arrays(filter_name="*_PT",library="pd")
    
print(df.head())
# Out:
#                 eventNumber  runNumber  PVNTRACKS
# entry subentry
# 0     0                4826   14469097       91.0
#       1                4826   14469097       10.0
# 1     0                4826   14469097       91.0
#       1                4826   14469097       10.0
# 2     0                4826   14469097       91.0

# %% [markdown]
# Now consider doing calculations with Pandas maybe a little more strenuous but I love the organisation of the dataframes.

# %%
with up.open(fName + ":DTT1520me/DecayTree") as f:
    df = f.arrays(["Lb_PX","Lb_PY","Lb_PZ", 'Lb_P'], library="pd")
    # You can also use Wildcards to call in particular sets of varialbles the example is commented out below
    # allPT=f.arrays(filter_name="*_PT",library="pd")
    
print(df.head())

"Lb_PX","Lb_PY","Lb_PZ"
